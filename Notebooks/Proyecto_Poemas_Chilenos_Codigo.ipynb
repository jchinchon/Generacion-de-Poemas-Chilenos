# %% [markdown]
# # 1. Requerimientos

# %%
# !pip install einops
# !pip install transformers
# !pip install tiktoken
# !pip install openai
# !pip install wordcloud
# Out:
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 820.7 kB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting tiktoken
#   Downloading tiktoken-0.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2023.11.17)
# Installing collected packages: tiktoken
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# Successfully installed tiktoken-0.5.2
# Collecting openai
#   Downloading openai-1.3.8-py3-none-any.whl (221 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.5/221.5 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.10.13)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.10/dist-packages (from openai) (4.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 5.9 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# Successfully installed h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 openai-1.3.8
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# # 2. Librerias

# %%
import torch
from transformers import AutoModel, AutoTokenizer, RobertaTokenizerFast
import os
from torch.utils.data.dataset import Dataset
from transformers.tokenization_utils import PreTrainedTokenizer
from filelock import FileLock
from transformers.utils import logging
from typing import Dict, List, Optional
import pickle
import random
import time
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from pathlib import Path
import numpy as np
from einops import rearrange
import math
import random
import tiktoken
import copy
import time
import datetime
from wordcloud import WordCloud
import matplotlib.pyplot as plt

from transformers import Trainer, TrainingArguments, GPT2Config, GPT2LMHeadModel,GPT2Model, GPT2Tokenizer,get_linear_schedule_with_warmup
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import RandomSampler

# %% [markdown]
# #3. Arquitecturas

# %% [markdown]
# ## Red Recurrente + Atención

# %%
class ScaleDotProductAttention(nn.Module):
    def __init__(self):
        super(ScaleDotProductAttention, self).__init__()
    # Inicialización de la capa con la función softmax para normalizar los pesos de atención
        self.softmax = nn.Softmax(dim=-1)

    # Método forward que realiza la operación de atención
    def forward(self, q, k, v, mask=None, e=1e-12):
        # Obtiene las dimensiones del lote, número de cabezas, longitud de la secuencia y dimensión del tensor clave
        batch_size, head, length, d_tensor = k.size()

        # Producto tensorial entre queries y keys usando la notación de Einstein
        score = torch.einsum("bhid,bhjd->bhij", q, k)

        # Escalamiento de valores de atención
        score = score / math.sqrt(d_tensor)

        # Máscara opcional
        if mask is not None:
            score = score.masked_fill(mask == 0, -e)

        # Softmax pesos normalizados de atención
        score = self.softmax(score)

        # Score por pesos de atención
        v = score @ v

        # Salida ponderada y pesos de atención
        return v, score

# %%
# Capa de atención con múltiples cabezas
class MultiHeadAttentionLSTM(nn.Module):
    def __init__(self, d_model, n_head):
        super(MultiHeadAttentionLSTM, self).__init__()

        # Número de cabezas de atención
        self.n_head = n_head

        # Capa de atención con producto punto escalado
        self.attention = ScaleDotProductAttention()

        # Capas lineales para transformar entradas en (q,k,v) para cada cabeza de atención
        self.w_q = nn.Linear(d_model, d_model)
        self.w_k = nn.Linear(d_model, d_model)
        self.w_v = nn.Linear(d_model, d_model)

        # Capa lineal salidas
        self.w_concat = nn.Linear(d_model, d_model)

    # Método forward atención múltiples cabezas
    def forward(self, x, mask=None):
        q, k, v = self.w_q(x), self.w_k(x), self.w_v(x)
        # Reorganización de dimensiones
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h=self.n_head), (q, k, v))

        out, attention = self.attention(q, k, v, mask=mask)

        # Reorganización de salida y aplicación capa lineal de concatenación y proyección
        out = rearrange(out, 'b h n d -> b n (h d)')
        out = self.w_concat(out)

        return out

# %%
#Red Self-attention con LSTM
class SelfAttentionLstm(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, n_head):
        super(SelfAttentionLstm, self).__init__()

        self.hidden_size = hidden_size
        self.num_layers = num_layers

        # Capa de atención con múltiples cabezas
        self.multi_attention = MultiHeadAttentionLSTM(d_model=input_size, n_head=n_head)

        # Capa LSTM
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)

    def forward(self, x):
        x = self.multi_attention(x)

        # Inicializar estados ocultos y de celda para la capa LSTM
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to("cuda")
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to('cuda')

        # Capa LSTM
        out, _ = self.lstm(x, (h0, c0))
        out = out[:, -1, :]

        return out

# %% [markdown]
# ### Funciones de obtención de 2 estrofas

# %%
def get_idx_two_line(token, newline_token_id):
    '''
    Función que recibe los tokens del modelo GPT2.
    Luego busca donde se predice un doble salto de línea, que marca el fin e inicio de una estrofa.
    El output es una lista del estilo [[0, 5], [10, 40], [70, block_size]] donde cada par de índices es el inicio y fin de una estrofa del input.
    '''
    token = token[0].tolist()
    index_token = [0]
    consecutive_count = 0
    for i in range(len(token)):
        # Verificar si el token actual es un token de salto de línea
        if token[i] == newline_token_id:
            # Si es el inicio de tokens consecutivos, guardar el índice
            if consecutive_count == 0:
                consecutive_start_index = i
            # Incrementar el conteo de tokens consecutivos
            consecutive_count += 1
        else:
            # Si se encuentran tokens consecutivos de salto de línea
            if consecutive_count >= 2:
                # Guardar los índices de inicio y fin de tokens consecutivos de salto de línea
                index_token.append(consecutive_start_index)
                index_token.append(i)
            # Reiniciar el conteo consecutivo y el índice de inicio
            consecutive_count = 0
            consecutive_start_index = None
    if token[-1] == padding_token_id:
        index_token.append(token.index(padding_token_id))
    else:
        index_token.append(len(token))
    # Crear pares de índices donde comienza y termina una estrofa de X número de líneas
    index_khotho = [index_token[i:i+2] for i in range(0, len(index_token), 2)]
    index_khotho = [i for i in index_khotho if len(i) == 2]
    index_khotho = [index_khotho]
    return index_khotho

# %% [markdown]
# ### Función de perdida de la LSTM

# %%
def loss_kho_tho(tokens, embedding, modelo_lstm, newline_token_id):

    '''
    Función que calcula la pérdida de la LSTM entre 2 vectores contextuales, cada uno de estrofas consecutivas.
    Esta función llama a la función anterior que entrega los indices donde comienzan y terminan las estrofas.
    De esta forma extrae los embeddings de cada estrofa, los hace pasar por la LSTM y extrae el vector contextual.
    Se procede a comparar los vectores contextuales de estrofas consecutivas. Ej: E1 vs E2, y E2 vs E3.
    Si solo hay 1 estrofa no se calcula la loss.
    '''

    tokens = torch.unsqueeze(tokens,0)
    pair_list = get_idx_two_line(tokens, newline_token_id)[0]
    embedding = torch.unsqueeze(embedding,0)

    total_lost = 0
    loss = nn.MSELoss().to(device)

    #se calcula la loss para estrofas consecutivas
    for i in range(len(pair_list) - 1):
      #Extract indices de los segmentos
      one_start, one_end = pair_list[i][0], pair_list[i][1]
      two_start, two_end = pair_list[i + 1][0], pair_list[i + 1][1]
      #Extraer embeddings usando los indices
      embedd_one = modelo_lstm(embedding[:, one_start: one_end + 1, :])
      embedd_two = modelo_lstm(embedding[:, two_start: two_end + 1, :])

      total_lost += loss(embedd_one,embedd_two)

    return total_lost

# %% [markdown]
# # 4. Data de Entrenamiento y Validación

# %% [markdown]
# ---
#
# Se proporcionan tres opciones de archivos de texto: "poemas_mistral.txt", "poemas_neruda.txt" y "poemas_total.txt". Se utiliza el último por defecto, pero se pueden cambiar los nombres de archivo para procesar diferentes conjuntos de poemas.
#
# ---

# %%
#archivo_texto = "poemas_mistral.txt"
#archivo_texto = "poemas_neruda.txt"
archivo_texto = "poemas_total.txt"

# Leer el contenido del archivo
with open(archivo_texto, "r", encoding="utf-8") as file:
    texto = file.read()

print(f"Tamaño del corpus: {len(texto):,} caracteres \n\n")

# Separar en poemas individuales
poemas = texto.split("\n\n\n")

# Eliminar espacios en blanco o poemas nulos, y convertir a minúsculas
poemas = [poema for poema in poemas if len(poema) > 0]
poemas = [poema.strip() for poema in poemas]
poemas = [poema.lower() for poema in poemas]

#dividir en estrofas por poema
estrofas_por_poema = [poema.split("\n\n") for poema in poemas]

#unir 2 estrofas consecutivas, dentro de cada poema.
pares_de_estrofas = []
for estrofa in estrofas_por_poema:
    for i in range(0,len(estrofa)-1):
        pares_de_estrofas.append(estrofa[i]+"\n\n"+estrofa[i+1])


#renombrar a poemas por facilidad
poemas = pares_de_estrofas

#desordenar los grupos de estrofas
random.shuffle(poemas)

# Separar en train y validacion en proporción 90-10%
train_poemas = poemas[:int(len(poemas)*0.9)]
valid_poemas = poemas[int(len(poemas)*0.9):]

# Guardar en archivos
with open("poemas.txt", "w", encoding="utf-8") as file:
    file.write("\n\n".join(poemas))

with open("train_poemas.txt", "w", encoding="utf-8") as file:
    file.write("\n\n".join(train_poemas))

with open("valid_poemas.txt", "w", encoding="utf-8") as file:
    file.write("\n\n".join(valid_poemas))

print(f"Ejemplo de Grupo de Estrofa que se le ingresará al modelo: \n\n {poemas[0]}")
# Out:
# Tamaño del corpus: 664,551 caracteres
#
#
# Ejemplo de Grupo de Estrofa que se le ingresará al modelo:
#
#  hablan demás los que nunca
# tuvieron madre tan blanca,
# y nunca la verde gea
# fue así de angélica y blanca
# ni así de sustentadora
# y misteriosa y callada.
# ¡qué madre dulce te dieron,
# patagonia, la lejana!
# sólo sabida del padre
# polo sur, que te declara,
# que te hizo, y que te mira
# de eterna y mansa mirada.
#
# oye mentir a los tontos
# y suelta tu carcajada.
# yo me la viví y la llevo
# en potencias y en mirada.

# %%
import nltk
from nltk.corpus import stopwords

# Descarga la lista de stopwords en español
nltk.download('stopwords')
stopwords_espanol = set(stopwords.words('spanish'))

# Especifica la ruta del archivo que deseas leer
archivo_path = 'poemas.txt'  # Reemplaza 'ruta_del_archivo.txt' con la ruta correcta

# Lee el contenido del archivo
with open(archivo_path, 'r', encoding='utf-8') as file:
    contenido = file.read()

# Crea la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color="white", stopwords = stopwords_espanol).generate(contenido)

# Muestra la nube de palabras utilizando matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # 5. Tokenizadores y Creación de Datasets

# %% [markdown]
# ## 5.1. Tokenizador SubPalabra: Tiktoken

# %%
import tiktoken

# Cargar la codificación "gpt2" de tiktoken
tokenizer = tiktoken.get_encoding("gpt2")

# Obtener los tokens del texto
tokens = tokenizer.encode(poemas[0])

# Decodificar los tokens a bytes
tokens_bytes = [tokenizer.decode_single_token_bytes(token) for token in tokens]

# Convertir los bytes a cadenas de texto
tokens_texto = [bytes.decode("utf-8", errors="replace") for bytes in tokens_bytes]

# Tamaño del vocabulario
#vocab_size = len(set(tokens))
vocab_size = tokenizer.n_vocab

# Imprimir el número de tokens y los tokens en bytes y texto
print("Poema:", poemas[0])
print("Número de tokens:", len(tokens))
print("Tokens:", tokens)
print("Tokens en bytes:", tokens_bytes)
print("Tokens en texto:", tokens_texto)
print("Tamaño del vocabulario:", vocab_size)

# añadirle caracteres especiales
tokenizer = tiktoken.Encoding(
    name="tiktoken",
    pat_str=tokenizer._pat_str,
    mergeable_ranks=tokenizer._mergeable_ranks,
    special_tokens={
        **tokenizer._special_tokens,
        '<BOS>': vocab_size,
        '<EOS>': vocab_size + 1,
        '<PAD>': vocab_size + 2
    }
)

newline_token_id = tokenizer.encode('\n')[0]
padding_token_id = tokenizer.encode("<PAD>", allowed_special="all")[0]
eos_token_id =  tokenizer.encode("<EOS>", allowed_special="all")[0]
vocab_size = tokenizer.n_vocab
print("Tamaño del vocabulario actualizado:", vocab_size)
print("Id de la nueva linea:", newline_token_id)
print("Caracteres especiales:", tokenizer._special_tokens)
# Out:
# Poema: pasa como lianas y musgos
# pasa la flora de los sueños,
# tan baja que tocan mi cara
# algas y helechos estupendos.
#
# pasa la fauna de las fiebres
# a ras de mí y a ras del suelo,
# chacalillos con ojos rojos,
# con salamandras en los cuellos
# y cobras de badanas vivas
# enredando patas de ciervos.
# Número de tokens: 119
# Tokens: [79, 15462, 401, 78, 300, 666, 292, 331, 1928, 70, 418, 198, 79, 15462, 8591, 48037, 390, 22346, 20889, 12654, 418, 11, 198, 38006, 275, 27792, 8358, 284, 5171, 21504, 1097, 64, 198, 14016, 292, 331, 339, 293, 354, 418, 1556, 929, 437, 418, 13, 198, 198, 79, 15462, 8591, 277, 32837, 390, 39990, 277, 494, 65, 411, 198, 64, 374, 292, 390, 285, 8836, 331, 257, 374, 292, 1619, 424, 22126, 11, 198, 354, 330, 282, 359, 418, 369, 267, 73, 418, 686, 73, 418, 11, 198, 1102, 3664, 321, 392, 8847, 551, 22346, 28381, 297, 418, 198, 88, 22843, 8847, 390, 2089, 15991, 410, 38630, 198, 268, 445, 25440, 1458, 292, 390, 269, 72, 712, 418, 13]
# Tokens en bytes: [b'p', b'asa', b' com', b'o', b' l', b'ian', b'as', b' y', b' mus', b'g', b'os', b'\n', b'p', b'asa', b' la', b' flora', b' de', b' los', b' sue', b'\xc3\xb1', b'os', b',', b'\n', b'tan', b' b', b'aja', b' que', b' to', b'can', b' mi', b' car', b'a', b'\n', b'alg', b'as', b' y', b' he', b'le', b'ch', b'os', b' est', b'up', b'end', b'os', b'.', b'\n', b'\n', b'p', b'asa', b' la', b' f', b'auna', b' de', b' las', b' f', b'ie', b'b', b'res', b'\n', b'a', b' r', b'as', b' de', b' m', b'\xc3\xad', b' y', b' a', b' r', b'as', b' del', b' su', b'elo', b',', b'\n', b'ch', b'ac', b'al', b'ill', b'os', b' con', b' o', b'j', b'os', b' ro', b'j', b'os', b',', b'\n', b'con', b' sal', b'am', b'and', b'ras', b' en', b' los', b' cue', b'll', b'os', b'\n', b'y', b' cob', b'ras', b' de', b' bad', b'anas', b' v', b'ivas', b'\n', b'en', b'red', b'ando', b' pat', b'as', b' de', b' c', b'i', b'erv', b'os', b'.']
# Tokens en texto: ['p', 'asa', ' com', 'o', ' l', 'ian', 'as', ' y', ' mus', 'g', 'os', '\n', 'p', 'asa', ' la', ' flora', ' de', ' los', ' sue', 'ñ', 'os', ',', '\n', 'tan', ' b', 'aja', ' que', ' to', 'can', ' mi', ' car', 'a', '\n', 'alg', 'as', ' y', ' he', 'le', 'ch', 'os', ' est', 'up', 'end', 'os', '.', '\n', '\n', 'p', 'asa', ' la', ' f', 'auna', ' de', ' las', ' f', 'ie', 'b', 'res', '\n', 'a', ' r', 'as', ' de', ' m', 'í', ' y', ' a', ' r', 'as', ' del', ' su', 'elo', ',', '\n', 'ch', 'ac', 'al', 'ill', 'os', ' con', ' o', 'j', 'os', ' ro', 'j', 'os', ',', '\n', 'con', ' sal', 'am', 'and', 'ras', ' en', ' los', ' cue', 'll', 'os', '\n', 'y', ' cob', 'ras', ' de', ' bad', 'anas', ' v', 'ivas', '\n', 'en', 'red', 'ando', ' pat', 'as', ' de', ' c', 'i', 'erv', 'os', '.']
# Tamaño del vocabulario: 50257
# Tamaño del vocabulario actualizado: 50260
# Id de la nueva linea: 198
# Caracteres especiales: {'<|endoftext|>': 50256, '<BOS>': 50257, '<EOS>': 50258, '<PAD>': 50259}

# %% [markdown]
# Se definirá el bloque contextual como cada grupo de estrofas, por lo tanto se requiere saber cuál es la cantidad máxima de tokens codificados en cada grupo. Luego se definirá el bloque contextual. Se truncarán los grupos de estrofan que sobrepasen el tamaño del bloque contextual.

# %%
# codificar cada estrofa de cada poema
poemas_estrofas_codificado = [tokenizer.encode(estrofa) for estrofa in poemas]

# obtener el largo de cada estrofa de cada poema
poemas_estrofas_largo = [len(estrofa) for estrofa in poemas_estrofas_codificado]

# obtener el largo maximo global de una estrofa
block_size_estrofa = max(poemas_estrofas_largo)

print(f"La estrofa más larga tiene {block_size_estrofa} tokens")

import matplotlib.pyplot as plt
plt.hist(poemas_estrofas_largo, bins=50, color='skyblue', edgecolor='black')

# Agregando etiquetas y título en español
plt.xlabel('Número de Tokens en Pares de Estrofas')
plt.ylabel('Frecuencia')
#plt.title('Distribución de Longitudes de Pa Estrofas de Poemas')

# Agregando una cuadrícula para una mejor legibilidad
plt.grid(True, linestyle='--', alpha=0.7)

# Mostrar el histograma
plt.show()

print(f"Número de inputs al modelo: {len(poemas_estrofas_codificado)}")
# Out:
# La estrofa más larga tiene 1207 tokens
# Número de inputs al modelo: 3120

# %% [markdown]
# La mayoría de estrofas tienen menos de 150 tokens. Un bloque contextual de 250 tokens parece apropiado para limitar el uso de memoria.

# %%
## Ventana contextual
MAX_LEN = 250

# %% [markdown]
# Se crea una clase que añade a cada grupo de estrofa el carácter de inicio y de fin de texto. Además se trunca si sobrepasa la ventana y se agrega padding en caso de que no.
# Por último devuelve la mascara de atención en donde se encuentran los tokens de padding, para no calcular la loss en dichos tokens

# %%
class PoemDataset(Dataset):
    def __init__(self, data, tokenizer, max_length):
        self.tokenizer = tokenizer
        self.input_ids = []
        self.attn_masks = []
        for i in data:
            # Codificar el texto con tokens '<BOS>' (inicio del poema) y '<EOS>' (fin del poema)
            token_counts = self.codificar('<BOS>' + i + '<EOS>', max_length)
            self.input_ids.append(token_counts['input_ids'])
            self.attn_masks.append(token_counts['attention_mask'])

    def codificar(self, text, max_length):
        """
        Tokenizar el texto de entrada y devolver el recuento de tokens.
        Parámetros:
            text (str): El texto de entrada que se tokenizará.
            max_length (int): Longitud máxima para el relleno.
        Devoluciones:
            dict: Un diccionario que contiene el recuento de tokens.
        """
        tokens = self.tokenizer.encode(text, allowed_special="all")
        truncated_tokens = tokens[:max_length]  # Truncar hasta max_length
        padding_length = max_length - len(truncated_tokens)
        # Agregar tokens de relleno
        padded_index = self.tokenizer.encode("<PAD>", allowed_special="all")
        end_index = self.tokenizer.encode("<EOS>", allowed_special="all")
        padded_tokens = torch.tensor(truncated_tokens + padded_index * padding_length)
        # Enmascarar los tokens de relleno y el token EOS
        attention_mask = torch.tensor((padded_tokens != padded_index[0]) & ((padded_tokens != end_index[0])))
        return {
            'input_ids': padded_tokens,
            'attention_mask': attention_mask
        }

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.attn_masks[idx]

# %%
import warnings

# Disable all warnings
warnings.simplefilter("ignore")
dataset_train = PoemDataset(train_poemas, tokenizer, MAX_LEN)
dataset_valid = PoemDataset(valid_poemas, tokenizer, MAX_LEN)

# %%
## EJEMPLO DE UN INPUT CODIFICADO Y SU MASCARA
dataset_train[0]
# Out:
# (tensor([50257,  5976,  9620,  1357, 40138, 22346,  8358, 48157,  6888,   198,
#             83, 14795,   959,   261,  8805,   260, 25706,   698, 42124,    11,
#            198,    88, 48157,  6888,  8591,  3326,  2934,  4903,    64,   198,
#             69,   518,   355,  8836,   390,  3550,  2634,   677,    64,   331,
#            698, 42124,   198,  8461,   355,  8836,   390,  5630,   298,   324,
#           5799,   198,    88,   285,  1694,  4267,    64,   331,   869,  4763,
#             13,   198,   126,    94,   421,  2634,  8805,   260,   288,   377,
#            344,   573,   288,   959,   261,    11,   198,  8071,  1840,   544,
#             11,  8591,   443,    73,  2271,     0,   198,    82, 10205,  5439,
#          17463,  3755,  1619, 14841,   260,   198,    79, 14057,   969,    11,
#           8358,   573,  2377,  3301,    11,   198,  4188,   573,   289, 41282,
#             11,   331,  8358,   573,  5720,    64,   198,  2934,   304,   759,
#             64,   331, 25045,    64,  5720,  4763,    13,   198,   198,   726,
#             68,  6229,   343,   257, 22346,   256,   756,   418,   198,    88,
#            424, 12514, 12777, 36756,  1228,  4763,    13,   198,  8226,   502,
#           8591,   410,   452,  8836,   331,  8591,   300,  2768,    78,   198,
#            268,  1787,   268,   979,   292,   331,   551,  5720,  4763,    13,
#          50258, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259,
#          50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259,
#          50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259,
#          50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259,
#          50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259,
#          50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259,
#          50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259,
#          50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259, 50259]),
#  tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False]))

# %%
# EL MISMO INPUT DECODIFICADO
print(tokenizer.decode(dataset_train[0][0].tolist()))
# Out:
# <BOS>hablan demás los que nunca
# tuvieron madre tan blanca,
# y nunca la verde gea
# fue así de angélica y blanca
# ni así de sustentadora
# y misteriosa y callada.
# ¡qué madre dulce te dieron,
# patagonia, la lejana!
# sólo sabida del padre
# polo sur, que te declara,
# que te hizo, y que te mira
# de eterna y mansa mirada.
#
# oye mentir a los tontos
# y suelta tu carcajada.
# yo me la viví y la llevo
# en potencias y en mirada.<EOS><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>

# %% [markdown]
# ## 5.2. Tokenizador preentrenado: GPT2-Español

# %%
## Ventana contextual
MAX_LEN = 200

# %% [markdown]
# Se trabajara con el tokenizador del [modelo](https://colab.research.google.com/drive/1HVt5SJ22sXwhuqZX_DKoxZ5nJF4BFGTH?authuser=5#scrollTo=1QrQvNhrBH0j&line=1&uniqifier=1) GPT2 pequeño entrenado con el corpus de wikipedia en español + libros.

# %%
model_name = "DeepESP/gpt2-spanish"

# %%
#importar tokenizador
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

#agregar los caracteres especiales
special_tokens_dict = {
    'bos_token': '<BOS>',
    'eos_token': '<EOS>',
    'pad_token': '<PAD>'}
num_added_tokens = tokenizer.add_special_tokens(special_tokens_dict)

#definir el ID de separacion de espacio, y obtener el tamaño del vocabulario
newline_token_id = tokenizer.encode('\n')[0]
padding_token_id = tokenizer.encode('<PAD>')[0]
eos_token_id = tokenizer.encode('<EOS>')[0]
vocab_size = len(tokenizer)

# %% [markdown]
# **Creación del dataset**

# %%
class PoemDataset(Dataset):
    def __init__(self, data, tokenizer, max_length, gpt2_type='gpt2'):
        self.tokenizer = tokenizer
        self.input_ids = []
        self.attn_masks = []

        for i in data:
            encodings_dict = tokenizer('<BOS>' + i + '<EOS>',
                                     truncation=True,
                                     max_length=max_length,
                                     padding='max_length')

            self.input_ids.append(torch.tensor(encodings_dict['input_ids']))
            self.attn_masks.append(torch.tensor(encodings_dict['attention_mask']))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.attn_masks[idx]

# %%
# codificar cada estrofa de cada poema
poemas_estrofas_codificado = [tokenizer.encode(estrofa) for estrofa in poemas]

# obtener el largo de cada estrofa de cada poema
poemas_estrofas_largo = [len(estrofa) for estrofa in poemas_estrofas_codificado]

# obtener el largo maximo global de una estrofa
block_size_estrofa = max(poemas_estrofas_largo)

print(f"La estrofa más larga tiene {block_size_estrofa} tokens")

import matplotlib.pyplot as plt
plt.hist(poemas_estrofas_largo, bins=50, color='skyblue', edgecolor='black')

# Agregando etiquetas y título en español
plt.xlabel('Número de Tokens en Pares de Estrofas')
plt.ylabel('Frecuencia')
#plt.title('Distribución de Longitudes de Pa Estrofas de Poemas')

# Agregando una cuadrícula para una mejor legibilidad
plt.grid(True, linestyle='--', alpha=0.7)

# Mostrar el histograma
plt.show()

print(f"Número de inputs al modelo: {len(poemas_estrofas_codificado)}")
# Out:
# La estrofa más larga tiene 791 tokens
# Número de inputs al modelo: 3120

# %%
#Ejemplo de tokenizacion
tokens_recuperados = tokenizer.convert_ids_to_tokens(poemas_estrofas_codificado[6])
tokens = [tokenizer.convert_tokens_to_string(tokens) for tokens in tokens_recuperados]
print("Tokens Recuperados:", tokens)
# Out:
# Tokens Recuperados: ['pasa', ' como', ' li', 'anas', ' y', ' mus', 'gos', '\n', 'pasa', ' la', ' flora', ' de', ' los', ' sueños', ',', '\n', 'tan', ' baja', ' que', ' tocan', ' mi', ' cara', '\n', 'al', 'gas', ' y', ' helechos', ' estupen', 'dos', '.', '\n', '\n', 'pasa', ' la', ' fauna', ' de', ' las', ' f', 'iebres', '\n', 'a', ' ras', ' de', ' mí', ' y', ' a', ' ras', ' del', ' suelo', ',', '\n', 'ch', 'acal', 'illos', ' con', ' ojos', ' rojos', ',', '\n', 'con', ' sal', 'am', 'and', 'ras', ' en', ' los', ' cuel', 'los', '\n', 'y', ' co', 'bras', ' de', ' b', 'ad', 'anas', ' vivas', '\n', 'en', 'red', 'ando', ' patas', ' de', ' ciervos', '.']

# %% [markdown]
# **Datasets**

# %%
dataset_train = PoemDataset(train_poemas, tokenizer, MAX_LEN)
dataset_valid = PoemDataset(valid_poemas, tokenizer, MAX_LEN)

# %% [markdown]
# # 6. Funciones de entrenamiento SPT-GPT2

# %% [markdown]
# **Obs: Ejecutar primero la sección de tokenizador que se quiera utilizar para construir el dataset, antes de entrenar.**

# %%
# logging time
def format_time(elapsed):
    return str(datetime.timedelta(seconds=int(round((elapsed)))))

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
# para plotear losses
def plot_losses(train_losses, valid_losses):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_losses, label='Training Loss', marker='o')
    plt.plot(epochs, valid_losses, label='Validation Loss', marker='o')

    plt.title('Training and Validation Losses per Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def train(model, model_lstm, iterator, optimizer, criterion, scheduler, newline_token_id, device, sp_gpt2 = True):

  epoch_loss = 0
  epoch_loss_lstm = 0
  loss_lstm = 0
  model.train()

  for step, batch in enumerate(iterator):

    b_input_ids = batch[0].to(device)
    b_labels = batch[0].to(device)
    b_masks = batch[1].to(device)

    b_labels[b_input_ids == padding_token_id] = -100


    optimizer.zero_grad()

    outputs = model(b_input_ids,
                    labels=b_labels,
                    attention_mask=b_masks,
                    token_type_ids=None)

    loss_gpt = outputs[0]
    logits = outputs.logits
    embedding = model.transformer(b_input_ids,
                                 attention_mask=b_masks,
                                 token_type_ids=None)[0]
    if sp_gpt2:
      loss_lstm = sum([loss_kho_tho(b_input_ids[i],embedding[i], model_lstm, newline_token_id) for i in range(b_input_ids.shape[0])])*5
    loss_total = loss_gpt + loss_lstm
    batch_loss = loss_total.item()
    epoch_loss += batch_loss
    epoch_loss_lstm += loss_lstm

    loss_total.backward()
    optimizer.step()
    scheduler.step()

  return epoch_loss / len(iterator), epoch_loss_lstm/len(iterator)

def evaluate(model, model_lstm, iterator, criterion, newline_token_id, device, sp_gpt2=True):

  epoch_loss = 0
  epoch_loss_lstm = 0
  loss_lstm = 0
  model.eval()

  with torch.no_grad():

    for step, batch in enumerate(iterator):

      b_input_ids = batch[0].to(device)
      b_labels = batch[0].to(device)
      b_masks = batch[1].to(device)

      b_labels[b_input_ids == padding_token_id] = -100

      outputs = model(b_input_ids,
                                  labels=b_labels,
                                  attention_mask=b_masks,
                                  token_type_ids=None)

      loss_gpt = outputs[0]
      logits = outputs.logits
      embedding = model.transformer(b_input_ids,
                                   attention_mask=b_masks,
                                   token_type_ids=None)[0]
      if sp_gpt2:
        loss_lstm = sum([loss_kho_tho(b_input_ids[i],embedding[i], model_lstm, newline_token_id) for i in range(b_input_ids.shape[0])])*5
      loss_total = loss_gpt + loss_lstm

      batch_loss = loss_total.item()
      epoch_loss += batch_loss
      epoch_loss_lstm += loss_lstm

  return epoch_loss / len(iterator), epoch_loss_lstm/len(iterator)

# %%
def entrenar_red(model, model_lstm, tokenizer, train_loader, valid_loader, newline_token_id, device, criterion, optimizer, scheduler, num_epochs, tipo_tokenizer = None, sp_gpt2 = True):
  best_valid_loss = float('inf')

  train_losses = []
  valid_losses = []

  train_losses_lstm = []
  valid_losses_lstm = []

  model = model.to(device)
  model_lstm = model_lstm.to(device)
  criterion = criterion.to(device)

  for epoch in range(num_epochs):

    start_time = time.time()
    #entrenamiento y validación
    train_loss, train_lstm_loss = train(model, model_lstm, train_loader, optimizer, criterion, scheduler, newline_token_id, device, sp_gpt2)
    valid_loss, valid_lstm_loss = evaluate(model, model_lstm, valid_loader, criterion, newline_token_id, device, sp_gpt2)


    train_losses.append(train_loss)
    valid_losses.append(valid_loss)

    train_losses_lstm.append(train_lstm_loss)
    valid_losses_lstm.append(valid_lstm_loss)

    if valid_loss < best_valid_loss:
      best_valid_loss = valid_loss
      best_model_wts = copy.deepcopy(model.state_dict())

    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    if (epoch+1) % 1 == 0:
        print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
        print(f'\tTrain Loss: {train_loss:.3f}, LSTM loss: {train_lstm_loss:.3f}')
        print(f'\t Test. Loss: {valid_loss:.3f}, LSTM loss: {valid_lstm_loss:.3f}')

    #cada 5 epocas generar poemas
    if (epoch + 1) % 5 == 0:
        sample_outputs = model.generate(
                                  generated,
                                  do_sample=True,
                                  top_k=10,
                                  max_length=MAX_LEN,
                                  top_p=0.95,
                                  num_return_sequences=1,
                                  suppress_tokens = [padding_token_id],
                                  renormalize_logits = True
                                  )

        for i, sample_output in enumerate(sample_outputs):
            if tipo_tokenizer == "tiktoken":
              print("\n\nPoema Generado N° {}: \n {}\n\n".format(i, tokenizer.decode(sample_output.tolist())))
            else:
              print("\n\nPoema Generado N° {}: \n {}\n\n".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))


  return model, train_losses, valid_losses

# %% [markdown]
# Función para evaluar la creatividad de un poema generado

# %%
def evaluate_creativity(model, tokenizer, poems, temperatura, num_context_inputs=200, usar_temperatura=True):
    # Seleccionar aleatoriamente num_context_inputs poemas
    selected_poems = random.sample(poems, num_context_inputs)
    # Extraer la primera oración de cada poema seleccionado como entradas de contexto
    context_inputs = [poem.split('\n')[0].strip() for poem in selected_poems]
    context_inputs_encoded = []
    for input in context_inputs:
        if tipo_tokenizer == "tiktoken":
            context_inputs_encoded.append(torch.tensor(tokenizer.encode(input, allowed_special="all")).unsqueeze(0))
        if tipo_tokenizer == "preentrenado":
            context_inputs_encoded.append(torch.tensor(tokenizer.encode(input)).unsqueeze(0))
    # Versos del conjunto de entrenamiento
    versos = []
    for poema in poems:
        versos += poema.split("\n")
    # Inicializar variables para el cálculo del puntaje de creatividad
    total_creativity_score = 0
    # Generar poemas y calcular el puntaje de creatividad para cada entrada de contexto
    for i, prompt in enumerate(context_inputs_encoded):
        print(f"Contexto número: {i}")
        # Generar un poema utilizando el modelo
        prompt = prompt.to(device)
        if usar_temperatura:
            generated_poem = model.generate(
                prompt,
                do_sample=True,
                max_length=80,
                top_k=0,
                num_return_sequences=1,
                temperature=temperatura,
                renormalize_logits=True
            )[0]
        else:
            generated_poem = model.generate(
                prompt,
                do_sample=True,
                top_k=50,
                max_length=80,
                top_p=0.95,
                num_return_sequences=1,
                renormalize_logits=True
            )[0]
        if tipo_tokenizer == "tiktoken":
            generated_poem = tokenizer.decode(generated_poem.tolist())
        else:
            generated_poem = tokenizer.decode(generated_poem, skip_special_tokens=True)
        # Convertir el tensor del poema generado a una lista de IDs de versos
        verses_generated = generated_poem.split("\n")
        # Calcular ci (proporción de versos en el conjunto de entrenamiento respecto al total de versos en el poema generado)
        ci = sum(verse_generated in versos for verse_generated in verses_generated) / len(verses_generated)
        # Actualizar el puntaje total de creatividad
        total_creativity_score += (1 - ci)
    # Calcular el puntaje promedio de creatividad (C)
    creativity_score = total_creativity_score / num_context_inputs
    return creativity_score

# %% [markdown]
# # 7.A Entrenamiento SP-GPT2 con GPT2 sin preentrenar

# %% [markdown]
# ---
# Se importa la arquitectura desde HF, no se crea la arquitectura desde 0 pues el entrenamiento es más veloz y la generación es más intuitiva de utilizar con los parametros de temperatura. **Definir el Tokenizador 1.**
# Se utilizara un modelo más pequeño que el estándar dado el pequeño conjunto de datos, para evitar el overfitting.
#
# ---

# %% [markdown]
# ## Entrenamiento

# %%
''' ¿Qué tokenizador usar? '''

#tipo_tokenizer = "preentrenado"
tipo_tokenizer = "tiktoken"

''' ¿SP-GPT2 o sólo GPT2? '''
sp_gpt2 = True

# %%
##IMPORTAR MODELO GPT2 SIN PRE-ENTRENAMIENTO (COMO EN EL PAPER)
N_EMBD = 384
configuration = GPT2Config(vocab_size=vocab_size, n_layer=6, n_head=6, n_embd=N_EMBD, n_inner=MAX_LEN)
modelo_gpt_sinpr = GPT2LMHeadModel(configuration)
modelo_gpt_sinpr.resize_token_embeddings(vocab_size)

#MODELO LSTM CON PARAMETROS DEL PAPER
head_gpt = SelfAttentionLstm(input_size=N_EMBD,hidden_size=256, num_layers=1,n_head=2)
for param in head_gpt.parameters():
    param.require_grad = True

# %%
batch_size = 8

train_dataloader = DataLoader(dataset_train,
                              sampler=RandomSampler(dataset_train),
                              batch_size=batch_size)
valid_dataloader = DataLoader(dataset_valid,
                              sampler=RandomSampler(dataset_valid),
                              batch_size=batch_size)

# %%
# hyperparameters
learning_rate = 1e-4
eps = 1e-8
warmup_steps = 50
device = torch.device('cuda')
epocas=20
optimizer = torch.optim.AdamW(modelo_gpt_sinpr.parameters(), lr=learning_rate, eps=eps)
criterion = nn.CrossEntropyLoss().to(device)
total_steps = len(train_dataloader) * epocas
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps=warmup_steps,
                                            num_training_steps=total_steps)

# %%
# create text generation seed prompt
prompt = "<BOS>"

if tipo_tokenizer == "tiktoken":
  generated = torch.tensor(tokenizer.encode(prompt, allowed_special="all")).unsqueeze(0)

if tipo_tokenizer == "preentrenado":
  generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)

generated = generated.to(device)

# %%
# SI QUEREMOS ENTRENAR SOLO GPT2 ENTONCES SET sp_gpt2 EN FALSE

modelo_gpt_sinpr, train_loss_A, valid_loss_A = entrenar_red(modelo_gpt_sinpr,
                                                            head_gpt,
                                                            tokenizer,
                                                            train_dataloader,
                                                            valid_dataloader,
                                                            newline_token_id,
                                                            device,
                                                            criterion,
                                                            optimizer,
                                                            scheduler,
                                                            epocas,
                                                            tipo_tokenizer = tipo_tokenizer,
                                                            sp_gpt2 = sp_gpt2)
# Out:
# Epoch: 01 | Epoch Time: 1m 21s
# 	Train Loss: 6.604, LSTM loss: 0.004
# 	 Test. Loss: 5.129, LSTM loss: 0.004
# Epoch: 02 | Epoch Time: 1m 20s
# 	Train Loss: 4.784, LSTM loss: 0.007
# 	 Test. Loss: 4.430, LSTM loss: 0.006
# Epoch: 03 | Epoch Time: 1m 20s
# 	Train Loss: 4.321, LSTM loss: 0.008
# 	 Test. Loss: 4.157, LSTM loss: 0.007
# Epoch: 04 | Epoch Time: 1m 20s
# 	Train Loss: 4.084, LSTM loss: 0.008
# 	 Test. Loss: 3.997, LSTM loss: 0.007
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Epoch: 05 | Epoch Time: 1m 20s
# 	Train Loss: 3.928, LSTM loss: 0.008
# 	 Test. Loss: 3.892, LSTM loss: 0.007
#
#
# Poema Generado N° 0:
#  <BOS>hoy que la que no se me hace años
# y no es una quieron,
# que no te séndola y no quiero.
#
# y no te me donde quiere
# la pobres se me viento.
# no me lo tambiendo
# porque no lo que no lo quempre,
# y me lo eso
# que no se pino a su ció en las ojada.<EOS>de el viento
# y no quedad
# que se me luna no es la vuelo y se habla.<EOS>de mi cosa de mujerme
# la viento
# y el pecho en el viento en la mí,
# y se hombre
# que me qué me llega
#
# ¿y me habla y que señando no no me quiero no no esa,
# y la nada,<EOS>como a la tierra y no lo esta.<EOS>y me la río.<EOS>y la brazos
# la tierra no sombra
#
# el tenga que
#
#
# Epoch: 06 | Epoch Time: 1m 20s
# 	Train Loss: 3.811, LSTM loss: 0.009
# 	 Test. Loss: 3.793, LSTM loss: 0.007
# Epoch: 07 | Epoch Time: 1m 20s
# 	Train Loss: 3.713, LSTM loss: 0.009
# 	 Test. Loss: 3.721, LSTM loss: 0.007
# Epoch: 08 | Epoch Time: 1m 20s
# 	Train Loss: 3.626, LSTM loss: 0.009
# 	 Test. Loss: 3.661, LSTM loss: 0.007
# Epoch: 09 | Epoch Time: 1m 20s
# 	Train Loss: 3.547, LSTM loss: 0.010
# 	 Test. Loss: 3.613, LSTM loss: 0.007
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Epoch: 10 | Epoch Time: 1m 20s
# 	Train Loss: 3.478, LSTM loss: 0.010
# 	 Test. Loss: 3.568, LSTM loss: 0.007
#
#
# Poema Generado N° 0:
#  <BOS>todo el viento que me olvido
# de la vientras que mejé la sólo
# y me quiero que lo que te amo.
#
# no me lo que se lejólo
# y en que la ciego en tuvo
# y a mi cuerpo de la cuerpo
# que la nombre que no lo que no lo que me en tuvo,
# que la tierra que la noche,
# que me di, no me la noche, me qué me lo que me viví.<EOS>la pereza
#
# y no te dor, la piedras que me lo que me quie que tú me me la cada
# y en el alma y me habla.<EOS>que me quien lo mismo yo yo yo te me día,
# la más que no eso,
# me donde me la más la viento me la que la ciel
# y en tuvo
# y yo te ha vie, no no se la vida a mi noche que te dierno me vuelvo,
# y la nad que me
#
#
# Epoch: 11 | Epoch Time: 1m 21s
# 	Train Loss: 3.412, LSTM loss: 0.010
# 	 Test. Loss: 3.530, LSTM loss: 0.008
# Epoch: 12 | Epoch Time: 1m 21s
# 	Train Loss: 3.352, LSTM loss: 0.010
# 	 Test. Loss: 3.494, LSTM loss: 0.008
# Epoch: 13 | Epoch Time: 1m 21s
# 	Train Loss: 3.296, LSTM loss: 0.010
# 	 Test. Loss: 3.476, LSTM loss: 0.007
# Epoch: 14 | Epoch Time: 1m 21s
# 	Train Loss: 3.247, LSTM loss: 0.010
# 	 Test. Loss: 3.432, LSTM loss: 0.008
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Epoch: 15 | Epoch Time: 1m 20s
# 	Train Loss: 3.204, LSTM loss: 0.011
# 	 Test. Loss: 3.422, LSTM loss: 0.008
#
#
# Poema Generado N° 0:
#  <BOS>yo me voy de una casa
# y me me miraba;
# yo me me llevan
# y dejor, me la llega
# de mi pecho.
#
# me voy a mi casa
# que es que me olvido
# con su caso me huentro.
# pero si me lo lo que es,
# y me mejor si es mujer.<EOS>de nada vuelve
# y me vieja y mi alma
# y me lo mismo que te sombro
# que me lo que es más.
# no me me voy y no la nada
# y me quiero si me oigo
# me, si me me oí.<EOS>y si te olvido
# porque no señando
# no me sé me viva,
# y que me quiebra y de tuyo que me vivir
# y tiempre,
# que tengo si es que me otra
# y cuenta y me oío que no eso tiempo.<EOS>como el viento
# y que me viento que la que eso un c
#
#
# Epoch: 16 | Epoch Time: 1m 21s
# 	Train Loss: 3.162, LSTM loss: 0.011
# 	 Test. Loss: 3.394, LSTM loss: 0.008
# Epoch: 17 | Epoch Time: 1m 21s
# 	Train Loss: 3.130, LSTM loss: 0.011
# 	 Test. Loss: 3.388, LSTM loss: 0.008
# Epoch: 18 | Epoch Time: 1m 21s
# 	Train Loss: 3.102, LSTM loss: 0.011
# 	 Test. Loss: 3.390, LSTM loss: 0.008
# Epoch: 19 | Epoch Time: 1m 21s
# 	Train Loss: 3.080, LSTM loss: 0.011
# 	 Test. Loss: 3.376, LSTM loss: 0.008
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Epoch: 20 | Epoch Time: 1m 20s
# 	Train Loss: 3.063, LSTM loss: 0.011
# 	 Test. Loss: 3.385, LSTM loss: 0.008
#
#
# Poema Generado N° 0:
#  <BOS>la vida en las llena de la noche
# de las manzas de las rutas,
# dejada en el árboles y las vuelas,
# el corazón, las viviento,
# por las nombres, y los huesos,
# hasta los dían en la noche.
#
# piedras, la tierra nocturna
# en el mar y la luna
# las que las noche la tierra.<EOS>de la vida estrellas
# la noche y la tierra se hace
# la tierra y el tiempo.
# ¡no tanto que está la noche!<EOS>de la muerte,
# todo el mundo espa muerte.<EOS>de la tierra, y la más.<EOS>tampoco en la tierra que la muerte.
#
# ¡y en el canto que la más que mejor del mar!<EOS>a
# la luz la luna de la muerte!<EOS>la perece
# la piedra que la luna, la ciendo;

# %%
plot_losses(train_loss_A, valid_loss_A)

# %% [markdown]
# ##Generacion de Poemas: Experimentar con parámetros de Temperatura

# %%
##Experimentar con diferentes prompt
prompt = "<BOS>" #libre

if tipo_tokenizer == "tiktoken":
  generated = torch.tensor(tokenizer.encode(prompt, allowed_special="all")).unsqueeze(0)

if tipo_tokenizer == "preentrenado":
  generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)

generated = generated.to(device)

# %% [markdown]
# 2 estilos de sampling: con temperatura o con Top-k y Top-p

# %%
modelo_gpt_sinpr.eval()

TEMPERATURA = 0.6

# sample_outputs = modelo_gpt_sinpr.generate(
#                                 generated,
#                                 do_sample=True,
#                                 top_k=0,
#                                 max_length=150,
#                                 top_p=0.95,
#                                 num_return_sequences=100,
#                                 suppress_tokens = [padding_token_id, eos_token_id],
#                                 renormalize_logits = True
#                                 )

sample_outputs = modelo_gpt_sinpr.generate(
                                generated,
                                do_sample=True,
                                max_length=80,
                                top_k = 0,
                                num_return_sequences=100,
                                temperature=TEMPERATURA,
                                no_repeat_ngram_size=2,
                                suppress_tokens = [padding_token_id, eos_token_id],
                                renormalize_logits = True
                                )


for i, sample_output in enumerate(sample_outputs):
    poema_generado = tokenizer.decode(sample_output.squeeze().tolist())
    print("\n\nPoema Generado N° {} \n\n: {}\n\n".format(i, poema_generado))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Poema Generado N° 144
#
# : <BOS>y la noche se me acaba.
#
# su sencida de alma,
# y su caminó con su vino
# la rostro a su huerpo. no segada
# se va a la siempre
# como el mar.a nada. es la me la ceja
# yo no hable en su reino. lleg
#
#
#
#
# Poema Generado N° 145
#
# : <BOS>y yo sé todo lo que es la mano
# con el padre de la puerta, y la vida,
# y la sabe que la antes
# como el cuerpo de los míos
# que se me la vea a la ruta
# por el que me lleva la palabra.
#
# la vieja
#
#
#
#
# Poema Generado N° 146
#
# : <BOS>en la piedra, vida,
# por la tierra y la gajo, la noche
# la luna vie, el cierta, y el amor que va
# en el nuevo y una patria.
#
# y entre los cielos, cada. no mejor., ni cuando
# se van a
#
#
#
#
# Poema Generado N° 147
#
# : <BOS>el viento de los hombres y en el cielo
# de los frutos de la saber y la noche
# que la muerte con mi canta.
#
# ¡para el vio que ahora no es más
# y yo quiero que está visto!
# es que no me vuelvo. �
#
#
#
#
# Poema Generado N° 148
#
# : <BOS>en la noche se me llevan
# donde las madre su niño
# y la vuelven de su mañana
# que al maría en su cuerpo.
#
# -¡y no creen ruedas ni en puertas
# la nombre de los ojos
# en cuentra en el pasto
# como
#
#
#
#
# Poema Generado N° 149
#
# : <BOS>más allá de la tierra que te acuerte.
#
# ¡no te sé, te entonces,
# me que puedas conmigo!
# pero en el mundo, que su propia
# donde es la muerde la alma. ¡yo no tú más que cae!! ¿por qu
#
#
#
#
# Poema Generado N° 150
#
# : <BOS>yo entonces me llamamó
# sus ojos y salcas.
#
# ya entraña
# porque eso tus hicinas
# lo si todo
# en trenzas esta noche,
# y aú no es suelta, encontrar., ¿qué la sólo
# estánde l
#
#
#
#
# Poema Generado N° 151
#
# : <BOS>la ronda de la paloma
# que se se me llena
# o me dieron.
#
# yo me cosa dejeres
# y en una noche
# de las madera.vivir
# ¡no da la muerte!
# dulce el día
# sus pinos
# como el pecho de los ciel
#
#
#
#
# Poema Generado N° 152
#
# : <BOS>pero no me arrancas
# todo lo que es la sombra.
#
# -¡ay! tú quiero mío,
# no te parecen dos piedra, tan llegas, verde
# y la que qué no tengo que no seguía. ¡ven
# es la tierra que am
#
#
#
#
# Poema Generado N° 153
#
# : <BOS>yo no he corto en el mundo
# que eso está en la esa noche
# como el caminar olvido
# y entre la muerte, de la nieve
# de la boca de a la tierra.
#
# ¡y no quéisé sólo, quiero,
# la llena dej
#
#
#
#
# Poema Generado N° 154
#
# : <BOS>se sentó de la noche
# con la muerte de las islas:
# ¡ah! ¡sólo tú
# de tus ojos, en las piedras,
# y la alzada con trenzas
# que no tuvolvemos
# como la cara huerta!
#
# yo leche que
#
#
#
#
# Poema Generado N° 155
#
# : <BOS>el hombre mía que lo que la noche
# y la dura no se la ciudan.
#
# -¡y no sé que no me la mujer!
# ¿a no podría yo la mejor
# que me quiero que caminaba?
# pero me lo quedé señía
# por
#
#
#
#
# Poema Generado N° 156
#
# : <BOS>-ya no, no la vez no sé
# me se me escucha, sueño.
#
# -¿qué dor, anto, mama?
# y ellas las cierto,
# ¡parece cuerpo? ¿cómo te qué sí?, tuya? te decí. tuve, te
#
#
#
#
# Poema Generado N° 157
#
# : <BOS>no hay nadie, tus ojos del mundo
# que en las muros, las otras manos de piedra,
# ¡no tienen las manando la tierra!
#
# no te te toda la hierro, tu cantar.
# pero tú más como las trenzas
# canz
#
#
#
#
# Poema Generado N° 158
#
# : <BOS>caminando el hombre de la muerte
# se amó de las piedras,
# y entre las caminas
# que me todo y la llama.
#
# parece y a la tierra
# a la se han por las gavillas:
# más allá la bajo la dura
# las ojos de
#
#
#
#
# Poema Generado N° 159
#
# : <BOS>-mama, mama donde no se llama.
#
# por qué sé bajito, no me quienes
# y me duerme a la mía. ¿cómo te vuelto?
# ¿fama no sabía me la mira
# la vida y cantada? ¡sío, señor
#
#
#
#
# Poema Generado N° 160
#
# : <BOS>la noche se habla y su herida
# y me acabar una otra caminan.
#
# tu cómo la oscura como un aire
# en la estrella, niño
# me no me vivir. con la nada
# la deja se la muerte. "parece
# seña de mi
#
#
#
#
# Poema Generado N° 161
#
# : <BOS>ay, más allá de la tierra,
# la muerte de las calles, la noche, el hombre, y el mundo
# bienes que despierto, con mi patria.
#
# todios que tengo, madre tienen, cuentro, tú no hablas, no tus o
#
#
#
#
# Poema Generado N° 162
#
# : <BOS>todo te llevarán la costa,
# pero está vivir, sin frente, en mi corazón.
#
# vienes que haciéndo que paso, que en el olor
# de cae a la ola deja, y araña
# y cada más allá de la muerte
#
#
#
#
# Poema Generado N° 163
#
# : <BOS>y en el viento de la tierra;
# la ronda de san juego que no conmada.
#
# yo no sé que me sío,
# y la que la boca deja
# que es que todo lo que es alientos. ¡y!
# ¡pero te qué te hace sólo,
#
#
#
#
# Poema Generado N° 164
#
# : <BOS>todavía, ella no habla,
# y esta noche, que te me llamado
# de lo que alcanzó
# como una alza en la luz
# del alma y del viento, como
# que no lo desde el alienta
# la que me vuelto
# ni al más que
#
#
#
#
# Poema Generado N° 165
#
# : <BOS>-¿qué qué me dices, quieres?
#
# -no te quiero, mama,
# ¡y que no me quedada!
# tú te dieras, tuer
# que me hallan dejor
# porque no la ruta
# y de mirada.
# yo no os y hierbas
# para
#
#
#
#
# Poema Generado N° 166
#
# : <BOS>el viento del vuelo, ya no sólo,
# porque porque me hacerlo.
#
# -¿por qué me retrás que dormía
# y así, le parecía?
# ¡no me quieres que lo mismo
# que es que no lo lo vivir
# o si lo está
#
#
#
#
# Poema Generado N° 167
#
# : <BOS>-¿a quién mama?
# ¡qué bien, nunca! ¿cómo qué hondo
# ni las cosas veces.
#
# --que sí, quiero, cuánde,
# y nos muertos. eres
# no te quienen
# pero te digo
# que me qu
#
#
#
#
# Poema Generado N° 168
#
# : <BOS>-¿qué desde dónde, no, mama?
# ¡la ruta que deja y llama,
# para la qué no conozco.
#
# -porque no es que está nada
# que los gestos miedo, y más? ¡quieres contando
# y que era alcan
#
#
#
#
# Poema Generado N° 169
#
# : <BOS>cuando eso vuela mis ojos
# y cuando levantas las dos vidas
# que la estállevan en las sordas
# porque a mi cuerpo a su pecho.
#
# es una casa de mi alma
# se haberla tierra como un cedro
# en la espalda en
#
#
#
#
# Poema Generado N° 170
#
# : <BOS>la muerte me abajo el cielo
# hoyendo el mundo.
#
# yo te hacia el año,
# me dónde que nadie., te escriba
# te han a tu color, alma. ¡cómo, no seráróatl!
# mama la ciega, como
#
#
#
#
# Poema Generado N° 171
#
# : <BOS>las ciudades de una noche
# de la ronda de las hación
# y el mar que la niebla
# en el oro de la muerte
# sólo que más, la luz,
# que me la tierra
# por la que no me cosa.
#
# -eso es que te acaba
# com
#
#
#
#
# Poema Generado N° 172
#
# : <BOS>¿a quién es que le puedo más tún
# que es mi alma y se parece
# y el anillo que la que te amo
# como si si me vuelvo?
#
# -¡y cuenta, que no pasa
# ºnudo y qué hermano? ¿qué mama
#
#
#
#
# Poema Generado N° 173
#
# : <BOS>los pinos que los tres
# como el pecho y el mar,
# y el llevo sube a la edad.
#
# el tiempo y volver
# que busco que no lo que todo
# mi alma y que me la viña.a su miraba
# sobre el aliento de la colmena
# en sus
#
#
#
#
# Poema Generado N° 174
#
# : <BOS>amor que no tengo
# en lasja manos
# y la noche mama.
#
# ¡ah! ¡ay!! no mía
# de más leche,
# señor de muerte. pasó, señir. ¿a quién mujer!
# tú, es que es la me ella,
#
#
#
#
# Poema Generado N° 175
#
# : <BOS>tú quiero quemos que quiere darme quedé los hombres mías,
# tudiera quiso que cegar en la tierra muerte y dieras.
#
# no hay qué me quisierno te quiencia, mi dormirla. ¿qué te di?
# y te h
#
#
#
#
# Poema Generado N° 176
#
# : <BOS>me he vuelve a los trenzas
# que se llamó a la tierra,
# y en el mundo oeste, que te voy aventó
# el soledro, el ciego.
#
# niño de puedas, dios
# la tierras desiertas. ¡y no más allá azor!
#
#
#
#
# Poema Generado N° 177
#
# : <BOS>yo te en las vieblas,
# o te más, te quedas
# en las puertas.
#
# ¡tú te llevas de tres
# que te te heridos!
# su cara entre las manos
# como los vientos de tu boca. hienden
# no te sólo como
#
#
#
#
# Poema Generado N° 178
#
# : <BOS>cuando no es verde a ciudad,
# con árboles de río, perdido
# y una cada puerta
# su gruta que la vida
# de la alcanza y a la ronda.
#
# -¡y yo me la más, la tengo
# que crece y sin noche
#
#
#
#
# Poema Generado N° 179
#
# : <BOS>cuando es el aire de la tierra
# y el mar otoño de mi casa
# que no sé quiero cuenta
# a que es más que me dejana,
# como la vida de mis manos
# con sus venas de sombra.
#
# -¡cómo no tengo mama, ya
#
#
#
#
# Poema Generado N° 180
#
# : <BOS>-¡ah! no se mama, me pasa.
#
# -no te parece, sí,
# ni te aconcantas. a miento. ¿qué nada?
# ¿cómo será, mío? ¡-eso, ³y?? no, no muevo. te
#
#
#
#
# Poema Generado N° 181
#
# : <BOS>en la noche de la seña
# como un más crece.
#
# mejólo una luz de muerte
# y yo me llevo
# que me la isla. ¿cómo me qué
# en donde segajan?
# ¡yo no eso no me duermo
# la nuevo
#
#
#
#
# Poema Generado N° 182
#
# : <BOS>el aire de la tierra y el día
# y el sorbo y la vida,
# recuerdo y a la señor
# con suelo, de su cuerpo,, y sin cuento
# en el viento y su alma, el ave, cuentro, la callada
# por la piedra, sierra y
#
#
#
#
# Poema Generado N° 183
#
# : <BOS>¿qué hacerme, que la noche pasa?
#
# -¡y qué cuándo no ella,
# la madre que me ama!
# ³y te oílabas
# y se hace
# como la espalda que
# que me dijorido
# por quieres que no me llev
#
#
#
#
# Poema Generado N° 184
#
# : <BOS>y la noche me di, me me voy
# con la salva y la casa
# y a una que me fuiéndolo
# como el danza su dueño
# ¡y de mi mano en la señar!
#
# sonándoteas de nacimos
# que cuando aliento cienzo
# los r
#
#
#
#
# Poema Generado N° 185
#
# : <BOS>-¿qué donde no me llegas
# me alguna qué llamar
# enas como si fuerte
# y se lo que mejor más?
#
# -no llamé, no, si eso
# cuando me mama,
# sin dejando por danza.
# ¡y no ti, muj
#
#
#
#
# Poema Generado N° 186
#
# : <BOS>la mano de la noche
# como el nombre de cerrada,
# en el cielo del mundo
# y la luz del canto.
#
# se les vuelva a ver
# de fui miedo y mece
# cuando viño de sangre
# o nadiebla alcanza.a mi baja
#
#
#
#
# Poema Generado N° 187
#
# : <BOS>como el pino de la pobre
# de la noche, el mundo
# y la sombra y el viento,
# la vida ave y la tierra
# que por el aire y en el día
# o de los más, y los cielos.
#
# en la cada muerte
# junto a m
#
#
#
#
# Poema Generado N° 188
#
# : <BOS>y yo sé me lo quererte
# o me qué eso de ser y mejor
# a mi cuerpo,
# y su cara, no me voy
# que me diero yo me oto
# en que me me de mi aliento
# como una noche alma
# ni porqueque no quierno me siem
#
#
#
#
# Poema Generado N° 189
#
# : <BOS>el cielo que lo está en el viento
# y alegar el mar y el cuerpo
# que el que no se vuelve
# a la cara que la que le dicen
# la voz no quiere que nos quiero.
#
# por qué me habla, no lo mismo,
# no ella lo
#
#
#
#
# Poema Generado N° 190
#
# : <BOS>en el tarde soledades
# de la tierra, el cielo,
# pero yo, y la más.
#
# el desde quién mí. ¡no?
# ya tuyo hay noche
# que tú, que canta
# y yo la cara
# sino que te acabar
# o te hablanec
#
#
#
#
# Poema Generado N° 191
#
# : <BOS>hayun fogon, de atizas
# de la muerte y el que leño,
# para que tú me desde río.
#
# -no está mama, es como siempre
# y a vez coma pueda nada. ¡quiero una!
# si no te viste mí
#
#
#
#
# Poema Generado N° 192
#
# : <BOS>el hombre de los ojos,
# y se hacía se vieñor
# que se va a su grito
# de los tres
# como una madre
# o el dulce
# con su boca de de su cuerpo,.
#
# era uno olor, caminamos. sórtola
# l
#
#
#
#
# Poema Generado N° 193
#
# : <BOS>-¿qué qué me quiero, no entre mama?
# ¡quién besa quise, mío!
#
# -no me divino, puedo.
# no te dieran más huertas. ¡y yo la vieja! ¿por quien que me hunde
# la
#
#
#
#
# Poema Generado N° 194
#
# : <BOS>porque en que no me ven,
# por qué para verdad
# y me quiere que me diero
# no me voy a quien
# o no mí, ¿qué hace?
#
# -¿por eso sí? bajé
# que no se sé siempre
# su vino sin dar
# sin voz
#
#
#
#
# Poema Generado N° 195
#
# : <BOS>un pasa y piedra están
# y yo fijo que no me alcan
# que a escuchar
# de viente, por el vuelve
# o gajo que la puerta.
#
# ¿a quién más es que me lo lleva
# la seguía deja?
# yo no quiero no la
#
#
#
#
# Poema Generado N° 196
#
# : <BOS>yo no vuelo a la ruta
# que me lo me blan,
# como si es el fino.
#
# se vea los que nacen, el viento
# y a veces no se me viejor
# o me dieron. ¡no tú no hablas
# con el mar y sin nombre
#
#
#
#
#
# Poema Generado N° 197
#
# : <BOS>caminan, en el árbol de las manos,
# para el silencio, el día lías
# y el cielo de la pueblo.
#
# en la mano y la boca, la muerte. yo soy, olva. síría. el ella, no caerlo. est
#
#
#
#
# Poema Generado N° 198
#
# : <BOS>así, como la tierra
# en la hora de la luna
# que en una olor de azul
# y bajo el niño en su sueño
# con su boca divina.
#
# déndome el mar,
# ven, sélo que no sólo
# ni lo que me la vieja
# la ronda
#
#
#
#
# Poema Generado N° 199
#
# : <BOS>¿a quién más van a ser?
#
# -¡ay, mama? ¿qué que es que te tuyo? baje
# � arde quiendo? tú mujer
# que no lo quiero que? que tengo.
# yo te alcanza el lodo
# y conmigo y y que
#
#
#
#
# Poema Generado N° 200
#
# : <BOS>cuando vuelve a la hora de la noche
# y a veces tú lo que te acuerdavía.
#
# cuánta señales la vida,
# también la chiquito, que nos llaman. están la lluvia
# la ronda de las vez la luz, la ruta
#
#
#
#
# Poema Generado N° 201
#
# : <BOS>llélle ha vino a la tierra
# y el mundo de la casa
# lo que me lo mismo,
# de pasa y todavía
# o si lo que lo como el canta.
#
# la noche la señas
# albajarme, por río
# que de más le parece,
#
#
#
#
# Poema Generado N° 202
#
# : <BOS>y en la tierra, la noche
# al veces en el día
# y te fijo a la puerta
# la ruta que paz y de mi juan;
#
# más que te quiere florina
# en mi canta,
# como una nubes outa
# quiere va a su pequeña
# cae
#
#
#
#
# Poema Generado N° 203
#
# : <BOS>nada día, que sénde,
# -¡no! no me siero, sí, pero.
# ¿cómo no qué dar
# que es que no no es dieron
# y que es un dolor
# me donde me quedóndote a un alma?
#
# pero me duer
#
#
#
#
# Poema Generado N° 204
#
# : <BOS>yo no sé que la que me quienen
# y tengo el trigo de la ruta
# que no mujer a mi aliente
# unca y que tú me hace un día
# no quiero yo no me vuelo.
#
# me hacerme dejor que no lo que
# en que eterno
#
#
#
#
#
# Poema Generado N° 205
#
# : <BOS>yo no existí, en la tierra
# que en el niño años,
# y al alguna qué
# por mío no levanta
# la mañana
# como una espalda mano
# ni en las barco de oro.
#
# el amor seguido
# de su propia señor
# m
#
#
#
#
# Poema Generado N° 206
#
# : <BOS>-a veces no la mama.
#
# -¿qué no hay,
# yo me río, no te mía?
# o loco estoye
# y no me lo mismo., sías
# ¡porque no? ¿eso ¡no qué
# que se apenas tienesada?? no
#
#
#
#
# Poema Generado N° 207
#
# : <BOS>te digo,
# ahora, no sólo
# es el hombre.
# no te quiero
#
# ¿cómo eso más?
# cada, repente, es el aliento. ¿qué al mío? ¡siempre
# el umbral de su nombra. llevo no?
#
#
#
#
# Poema Generado N° 208
#
# : <BOS>ya no me está en la noche
# que me parece y no habrado
# y a veces tú me lo que me crece
# la oído lo llamado.
#
# es cuerpo de mi canto
# como el fuego, el agua,
# mi día quedado, olvido
# a tus
#
#
#
#
# Poema Generado N° 209
#
# : <BOS>-¡ay, mama, que eso, ¡no! no te mío.
# -te lo que lo escucho
# ¿por es que te dónde tu cuerpo?
#
# yo no sí, no, y me nada. no bajen
# y te digo misto te pero? ¿
#
#
#
#
# Poema Generado N° 210
#
# : <BOS>-pero no te ves, no sé,
# -¿a, que te eso, mama?
#
# ¡--donde no mí, es es miedo? ¿�
# por qué es que los ojos? para los huertos.
# y es el miramor de todo. ¡qu
#
#
#
#
# Poema Generado N° 211
#
# : <BOS>-no qué me quieren me me llevar
# y no quiero a las cosas
# que me a la mama lo quiere
# a lo haga cosa vivir.
#
# -¿qué eso esas no miedo?
# ¡y que quien lo que no bienen
# por quedamos
#
#
#
#
# Poema Generado N° 212
#
# : <BOS>y son las rasas de las vidas,
# no te da a las alcanzas
# y las tinieblas, y las andas;
# ¡no al dios los mío!
#
# -¿por qué es, mama, quieres
# que me quiero que no lo quiere.
# la queda v
#
#
#
#
# Poema Generado N° 213
#
# : <BOS>sobre mi bajé los llanto
# de la siesta de mi alma y el viento.
#
# y tengo yo vuelven
# en que te pecho y mejor;
# ¡yo me gusto te llena
# porque no se acuerce
# no te amo no siero!
# tú no te di
#
#
#
#
# Poema Generado N° 214
#
# : <BOS>en el hombre y el viento,
# vuelo y las cenas pararra
# y a cada pasa y dura
# tu recierto que lo dieron
# de la cuerpo de la tierra, como una.
#
# la noche se huerta
# en aún el capitán, la
#
#
#
#
# Poema Generado N° 215
#
# : <BOS>sólo el cielo de los fríos
# y en el ojos de las piedras
# con los que te acosten
# sin sal y no conocer.
#
# ¡ay, más!
# siempre con sus olas
# que de la cara
# mira el mundo
# las que se pasa
# de v
#
#
#
#
# Poema Generado N° 216
#
# : <BOS>-mama, mama que las parece
# porque no la vean
# -es dejo de la vida,
# de miedo que duermo.
#
# yo me voy, que eso, tienen
# en nada mujer y que conocer
# y más que te llamado. ¡qué, qu
#
#
#
#
# Poema Generado N° 217
#
# : <BOS>me vuelve que la voz que quiero,
# y que no lo quieren mí,, tú la mirada
# con la otra de mi cara.
#
# -¡qué donde el que te lleva
# que a mi algo que ella me cada!
# es que me eterno
# de que va
#
#
#
#
# Poema Generado N° 218
#
# : <BOS>el infancia luz, una brazo?
# en donde la sangre,
# el noche y el cielo, el que no la vienta.
# no me vuelva a los dolores, aquella
# porque se le oí, me voltea, ajor no me río., tengo
#
#
#
#
# Poema Generado N° 219
#
# : <BOS>no te amor, tus ojos tumba de tu corazón,
# y tú te ese tengo te te mano.
#
# todo te he dejespero, sobre tu cuerpo. te oío
# no tieneso en tu rostro. estás allá tu alma. tambi
#
#
#
#
# Poema Generado N° 220
#
# : <BOS>en la noche se lo oían
# ni pasa que me llevan.
# cuando te olvidaré,
# con tantas y se apenas
# y sin mído, por dulces
# los ojos y el mar. ¡y conmama!
#
# ¿y te qué saber, me alcan
#
#
#
#
# Poema Generado N° 221
#
# : <BOS>¿por qué quónde lejos, no seguir!
# ¡no quiere me quiero, y entre los mías
# de los pies, en los labios,
# y de tiene muerte, han de siga, "viene sombra, bandera!ya no sé
#
# -
#
#
#
#
# Poema Generado N° 222
#
# : <BOS>todo y vuelan los que vientos
# todavía la noche,
# y la caballerza de la sangre, piedra
# las hierbas que eterna.
#
# no viene el aman en la vida
# que no segua la tierra. ¡sólo!
# la vieja que la
#
#
#
#
# Poema Generado N° 223
#
# : <BOS>no vuelve un día de tuyo,
# de tanto sino de denso.
#
# y tengo tener la tierra
# las hojas de las cosas. no tienen
# pero es la vida
# que sólo que no llegóndose
# cuando en las manosas las palmas. el mund
#
#
#
#
# Poema Generado N° 224
#
# : <BOS>en la noche de estrella,
# sobre el mundo y la menta.
#
# cómo la tierra y el hijo
# la cielo del nuevo
# y la afila en el herido
# en el cuerpo de las puertas.a
# el higuestra entre los piedra, callada. �
#
#
#
#
# Poema Generado N° 225
#
# : <BOS>el corazón de la puerta,
# el hombre de su pino cordero, el viento de fuego
# y la muerte en más que tejan
# ni se mientan, de los mujer.
#
# pero que todos los que no lecho
# con mi alma, y de las nacen
#
#
#
#
# Poema Generado N° 226
#
# : <BOS>-¿qué es que me hace nuestros que llamamada,
# como si cuando me sí a quiebre
# y a serán tú no me desn?
#
# -no hay que se lo que es el mío, siempre
# no me puso yo, mama.
# tantos, te h
#
#
#
#
# Poema Generado N° 227
#
# : <BOS>-mama, pándose, mama.
#
# -cómo la veo, tú, no, das,
# que son tienes más. ¿te qué me ácía?
# pero te importan. que te amo. "canto. mí. no te rompo"
# y si me
#
#
#
#
# Poema Generado N° 228
#
# : <BOS>a veces a vez las olas
# la tierra de aguas
# con una tierras que te huiste
# en el trenz
# que el cierto de las llras
# y en el viento y el caballo
# a la hebra del amor.
#
# el olor de la tierno,
# desde las ma
#
#
#
#
# Poema Generado N° 229
#
# : <BOS>dicen que no sél no quiero que por quedieron
# con su canto que mece el pino
# y el corre que abolas en mi cuerpo.
#
# el que la noche me llega
# la que el aire la de la cara,
# porque no eso por tantos y no me ac
#
#
#
#
# Poema Generado N° 230
#
# : <BOS>la casa se verde y era
# y en el océano y el carro,
# el que lo que era sufijo
# se va aconcargando.
#
# la llora que una muerte
# como un país de pino
# de su cuerpo y de dios
# para ciudadora no qu
#
#
#
#
# Poema Generado N° 231
#
# : <BOS>-mama, que no la ve aú
# de recuerdo lo que te va
# y si me sé que tú no sigo.
#
# -¿que como si sí, diero que mama?
# ¡ay, todo mía, no es que habla
# que no lo recobre mujer
# ques
#
#
#
#
# Poema Generado N° 232
#
# : <BOS>-¿qué suena que le puedo?
#
# -mama, mama me acosten
# que la veo no las montes
# y así, me ves y porqueña.
# ¡ay! ¿cómo qué sí!
# es que los aguardesperos
# con una y dej
#
#
#
#
# Poema Generado N° 233
#
# : <BOS>yo no eso que puede
# de una flor que hay un día
# que lo que no habla
# y la ropa como el viento
# sino en la noche.
#
# como la cada nadiego
# la mirada de alma
# con unos dejados
# en la puerta,
#
#
#
#
#
# Poema Generado N° 234
#
# : <BOS>yo vuelo y mi pecho;
# y el tengo quedado
# no me llamaste
# que porque te buscando
# siempre me algunto
# en el mar
# de una casa que me la llena;; y me habla
#
# ¡y sé que no me pido
# porque me lo
#
#
#
#
# Poema Generado N° 235
#
# : <BOS>amor como es la noche,
# sin espera más que te viento.
#
# la nieve y la muerte
# como el mar. qué mejor
# en la ruta que el pecho
# y me lleva la entre la tierra
# que en la boca. ¡y la gruta
# lo
#
#
#
#
# Poema Generado N° 236
#
# : <BOS>yo no puedo yo me desde
# que ella volverás,
# pero ya no más a miedo
# y se me quiero que no tengo.
#
# -¡no mama, que tú no me llevo, sueño
# la que te amo brazo y el pecho
# de una �
#
#
#
#
# Poema Generado N° 237
#
# : <BOS>parece que el que mejor y señor
# y la tierra, ella vuelve
# o donde la muerte.
#
# -mama, me lo que te habró,
# el que no habla, y brazo. ¡y cuento, mama!
# ¡pero le ha vías
#
#
#
#
# Poema Generado N° 238
#
# : <BOS>yo no sé que me quiero que no se vuelvo
# y no me vengo dejor de que espero.
#
# quieras que cae y solo. no saber,
# cuando la muerte es dura. ¡y todo lo que lo mismo!
# ¿y dio qué he de es
#
#
#
#
# Poema Generado N° 239
#
# : <BOS>-¿a qué no quieres mama?
#
# --no, cierto, ¿qué olvidé
# y que tú no se pescó? no me atr,
# tú ella, como sol, sío.
# ¡ay, otra vez, no lejos
# para que
#
#
#
#
# Poema Generado N° 240
#
# : <BOS>y por qué, no sabes
# tú me dieras y que te quiero,
# yo no me quieres mías.
#
# y me hicen los tus dííos
# que me sólo con que me acostumaje
# para mi alma y de mi destino. no sían
# �
#
#
#
#
# Poema Generado N° 241
#
# : <BOS>y otra vez una más que acostenerla
# a verdad, la sabeada de la tierra
# de un planeta que se desde,
# con su camino que no hay nombre, que como el día, noche se vuelvo.
#
# la cada muerpo de mis ojos comenzos
#
#
#
#
# Poema Generado N° 242
#
# : <BOS>al olor de la se les olas
# y en la océano de roja
# ni en las otras de las vergadas,
# el otro donde lo que se va aliento
# que la canto que pobre la bautismo.
#
# pero para decirle el cielo, yo la mi alma;
#
#
#
#
#
# Poema Generado N° 243
#
# : <BOS>oh aquí su océano y esperanza,
# el pasa y la gracia, que se hace
# con sus ojos y mejillas, mecían
# en que nosotros no me en el alma
# y su cielo no la vuelta
# que no sólo que me vuelvo
# ¡y qu
#
#
#
#
# Poema Generado N° 244
#
# : <BOS>subiendo el mar y la muerte
# y la hierba no se la canción,
# la que yo me quiero, y canta
# porque me deja se me como una.
#
# -¿cómo quieres no la vea?
# ¡y no qué me la que me lo que no mej
#
#
#
#
# Poema Generado N° 245
#
# : <BOS>el viento de la noche
# con su corazón de nieye
# y el cielo a la puerta
# la mirada de los ojos,
# pero en los dos estguimos
# al oro de mi muerte.
#
# lecho de gales y en la vida,bra
# de la tierra y
#
#
#
#
# Poema Generado N° 246
#
# : <BOS>el mediodía la lejado
# de la pradera,
# quieja que se hunde
# y tú ella quiere de nada
# que me agua ereso
# su cuerpo que lo tendida.
#
# no sabía mi madre
# el rostro que te mirar
# la cierta del olor de
#
#
#
#
# Poema Generado N° 247
#
# : <BOS>en el cielo son las alfas,
# y en la noche no habla.
#
# en la mano polvo, la muerte. la sólo
# por el olor añor y el pecho
# la madre que lo que la tierra., vuelto
# así, ella en el árbol
#
#
#
#
# Poema Generado N° 248
#
# : <BOS>y qué dónde en el mar?
#
# en la bor cae
# de cuerpo
# y en la noche
# el sueño
# que me lo que mece.
# ¿qué todo lo más?? ¿o te pasa?...
# tú, sí, que te olvido? pino
# no
#
#
#
#
# Poema Generado N° 249
#
# : <BOS>a la noche que no mejor que él
# la madre que yo la leche,
# dulce niña la ruta
# que va alcanzada, que lo que la viento
# y a la que lleva
# en la cordera que me la bauta.
#
# -pero, no sé que ya me
#
#
#
#
# Poema Generado N° 250
#
# : <BOS>el olor de la noche
# caminando abierta de mi alma
# y la sombra de nieve habla:
# suelta y de las párpadas.
#
# -¡ay! ¡y qué sabidor,
# que me quieres una nada!
# ¿cómo me d
#
#
#
#
# Poema Generado N° 251
#
# : <BOS>desde el hombre, desde la hora,
# lléis sin boca, y con el oroscuros, a la madera
# y el mar en la noche que no me quería
# que no saber suelta, así el desierto.
#
# pero para que yo me lo todo el agua
# de
#
#
#
#
# Poema Generado N° 252
#
# : <BOS>llegando a los cuerpo,
# y selvora no habla, las puertas.
#
# la señal mismo se llamó
# de la ola que lo que los que se lo decía., puevo
# los no se mejan los mares, disfragro:
# sólo que tu canto
#
#
#
#
# Poema Generado N° 253
#
# : <BOS>(¡ay, nunca más! ¡no! no tengo
# y no, que el amo tanto que te mujer
# a la madre deja que he vuelvo
# que te aman solas.
# ¿ni te puede, no te mirar
# bajo, ni nada hicen
# como
#
#
#
#
# Poema Generado N° 254
#
# : <BOS>los caminos todo lo que no llevo,
# y no es son el canto tristo
# como el aliento de los hombres
# que cuando en mi alma;
# ¡ay! me río no la alba
# ni el viente no pino
# en el dios de niño
# con mi car
#
#
#
#
# Poema Generado N° 255
#
# : <BOS>la madre de ella no estás
# y dejando por la tierra
# cuando es la noche
# lo que la sólo soñando
# o la vez fiesta,
# la entraña de los que ama
# se va a la palabra.
#
# -¿a qué sabía, voy a ser?
# qu
#
#
#
#
# Poema Generado N° 256
#
# : <BOS>del cielo de colante
# como una casa
# de abierto y de plata.
#
# el mar de las fiel,
# la muerte, el agua., lo que mece
# ¡por si eseo!
# yo no tengo, mí! fue el viento
# voy a la canción
#
#
#
#
# Poema Generado N° 257
#
# : <BOS>-¡ay! no sabes, que no es la noche
# ¿gú no la qué danza?
#
# -no te lleva, la cuando
# todo lo que te cierto.
# el tú me tuve
# porque eso te viva,
# y uno yo te dejor
# que me llam
#
#
#
#
# Poema Generado N° 258
#
# : <BOS>tu hijo y muerte y tus dulce,
# señas las dos sombra que no se me vuelven
# que me quiero que me tuve, niño;
# ¡a tu alma qué llama, a tu cuerpo!
#
# -¿no hay más mama llegar la que se
#
#
#
#
# Poema Generado N° 259
#
# : <BOS>la tierra que se ha ha como una
# en un pan de sueño de olas,
# y el mar dejos cuerpo, un tiempo
# a cámás que me más.
#
# no hay un puedo siento
# de uno que no se veo, que tanto
# ni tocar mis pies.
#
#
#
#
# Poema Generado N° 260
#
# : <BOS>y cuando te era el alma
# y yo me contar
# con un día agua
# que a la vida en la ruta
# de las dos aire.
#
# a cada espero
# la madre tan lleva
# para que me lo que lo pierde.,
# ¿por qué tú nos sé
# por
#
#
#
#
# Poema Generado N° 261
#
# : <BOS>y en la noche de la ciega
# que al que parece
# y tengo de más.
#
# -¡ay! no qué te deja
# ¿por quieres que la saberlo
# lo que te mira
# porque no mí, como un siempre
# una y de dura
# para
#
#
#
#
# Poema Generado N° 262
#
# : <BOS>no te contigo, yo te hacia el tiempo
# no me hacerte para mi cara.
#
# eso no sigo
# en él no me de nadie.. te viento. ¿qué dónde tengo?
# ¿por qué no yo no te puedo
# y quiero al
#
#
#
#
# Poema Generado N° 263
#
# : <BOS>-yo no sé dura, si es que lo sos.
#
# -cómo qué está esta mama
# y la noche y la parece. ¿qué me quieres?
# en que me lo recién
# ¿y no lo quienen lo estás? ¡cío, como a
#
#
#
#
# Poema Generado N° 264
#
# : <BOS>y en el fuego la blanca
# cómo pobre la mirada.
# no me va la que no sé que aprende
# y a la verlo
# ni se hallan que la muerte
# que no se había,
# más allí que se llamaba.:
#
# ¿de quién todo nuest
#
#
#
#
# Poema Generado N° 265
#
# : <BOS>para mi boca llama
# a el pequeño que nunca
# de la cara que viva
# del mar que he de o cierto.
#
# -mama, ganada,
# no te habla, no la mía, la vida,o
# con dura y caminan
# y saberme y no mej
#
#
#
#
# Poema Generado N° 266
#
# : <BOS>por más, por qué,
# cómo eso de ser, no saliendo
# y si lo que no lo mecaba
# la cantaba una madre
# que no me deja señor.
#
# en el dijo de habla
# con su tenerme y me la lluida
# porque me amo me v
#
#
#
#
# Poema Generado N° 267
#
# : <BOS>a los que tengo,
# en la noche
# me quedé la dura
# que buscar la espalda
# o no qué piso
# un padre de la cara, la muerte, mi alma
# qué donde una nombre
# estándose y o la luz
# y la que no se la
#
#
#
#
# Poema Generado N° 268
#
# : <BOS>-¡ay, mama! no esas mía
# ¿y no lo que me qué a veo?
#
# --me, no te sé, sí, oigo,
# para que es ella, cierto.
# yo mío no tú no, te olvon. y es que te puedo.
#
#
#
#
# Poema Generado N° 269
#
# : <BOS>-¿qué he vuelve que paremos
# y que no me llamómo?
# -y qué no la mano
# que está la cada.
# pero te hace son
# ¡quién me ararme. ¿porque no es,
# por quiero estoy a mí!
#
# ya
#
#
#
#
# Poema Generado N° 270
#
# : <BOS>¡qué brazo, qué donde tejes que te alcanza!
#
# -¿a quien la nube, páría,
# para que su mama?
# ³y yo no eso? ¿por quiero sólo
# y si es que no habla? no te poco
#
#
#
#
#
# Poema Generado N° 271
#
# : <BOS>la noche cantadie
# en la nieve,
# la ruta que de la mano
# y el tiempo
# de la gracia
# con la fuiendo.
#
# me hace
# a la cada
# que en el niño
# los vientos
# como una nada. el aire
# porque se me vuelva
#
#
#
#
# Poema Generado N° 272
#
# : <BOS>aunque las rasoo el sueño
# como una patria ruta,
# por el viento
# y el pecho y el río, oscuro
# de que ven lo que lo mismo.
#
# -¿qué no vi hunde, ¡y no mama?
# ¡a la vida, la
#
#
#
#
# Poema Generado N° 273
#
# : <BOS>y los sombra de noche
# para su propia,
# por la nieve pasa.
#
# cómo ya no mujer
# de la esta hora, la luna
# en la costa de la ruta
# y la oscura de las manos
# la soledad de los caminos,!
# ¡d
#
#
#
#
# Poema Generado N° 274
#
# : <BOS>a la pronto luz de una noche
# y un día el viento de la vida,
# casión de olor
# al marino de hombre.
#
# nadie, nieve no te aconcada, en ella,, síría
# en mi dulce, mi pecho
# que te di
#
#
#
#
# Poema Generado N° 275
#
# : <BOS>-¿qué ves que no me dices?
# por qué hace eso? ¿y sé es que es
# y es es un pan y no es hasta que a la noche
# que no quiero alcanza.
# ¡-visto, es el rostro!
#
# -sí, que la monta
#
#
#
#
# Poema Generado N° 276
#
# : <BOS>¡qué que qué quedé parece
# y a la rosa que leche
# a la noche de la mejilla
# que vivir a los mire?
#
# ¿a quema se abrazo
# en la gracia a su grito? ¡y en el alma
# porque lo mismo alcanza
#
#
#
#
# Poema Generado N° 277
#
# : <BOS>y nunca qué no sé tengo
# a vez ni la gajo,
# que no me quedé vuelven
# y me alcanza y el mundo.
#
# no me sí me lleva
# la boca, soledad, pueda, hijo, quiere
# ¡hace una mío
#
#
#
#
# Poema Generado N° 278
#
# : <BOS>la ruta viva que la lanzada
# y la noche y lo mía
# que todo lo que lo mismo
# como el alcanza y el niño;
# porque lo ella lo me lo viento,
# ¿cómo no le han lo buscan
# el que no lo huemos
# con su r
#
#
#
#
# Poema Generado N° 279
#
# : <BOS>no me acordé de la sangre
# y se aprendido,
# los ojos que no con llevo
# como el valle
# se acié, leche
# con el cielo de cuna
# que no me sío alcanza,, mído
# el reino en el país.
#
# porque me
#
#
#
#
# Poema Generado N° 280
#
# : <BOS>-¿qué dando nunca es que no es unas ciertas?
# ¡cómo eso, quién? ¿tú tengo? es, mama? pero. ¡no! ³y es mío!
#
# -pero es es cuerpo y yo,
# con uno y de
#
#
#
#
# Poema Generado N° 281
#
# : <BOS>-¡ay! no es que tú te llenas
# ¿porque tengo tienes que eso?
#
# -es el hombre que te de la patria.
# me es es dejame,
# por si cosa tus ojos
# que me llegría conmigo.�a, te có
#
#
#
#
# Poema Generado N° 282
#
# : <BOS>dicen que lejos y vuelan
# y que no se alcanza,
# tras las ganados de la piedra
# por la madre y la tierra.
#
# dor que está la muerte
# con las caminas
# la noche como el canto. ¡¡y tú no será
#
#
#
#
# Poema Generado N° 283
#
# : <BOS>todo de la noche de palabra,
# hoy aire, aunque yo no tengo
# y yo me la sabe
# o si me desbarena, todo.
#
# -¡y todos los ojos
# porque por ese ciego!
# ¿a qué mi casa
# que no me bus
#
#
#
#
# Poema Generado N° 284
#
# : <BOS>-¡ay, que no qué te viven
# que me quieres, mama,
# -no alcanza, me vuelo
# ni sí, camino.
#
# ¿qué bajé el miedo, inmenso?
# y, no saben el valle
# de quién dices que te digo.
#
#
#
#
# Poema Generado N° 285
#
# : <BOS>es una mano de los ojos
# en las olas son en las manos,
# y las sordas y las tierras
# no hay son los hombres, el jueva.
#
# por los dos nantos los míos:
# todavillos y no tengo
# bamos de la noche
# de
#
#
#
#
# Poema Generado N° 286
#
# : <BOS>sólo una cierto el rostro
# la tierra en la tieresta
# y el cielo hecho cuello
# de un hombre y del amor
# quea pueda con el alma.
#
# el dio la canto
# con los que en el mar
# al pie del mar, las agua
# mi rosa de
#
#
#
#
# Poema Generado N° 287
#
# : <BOS>-de di, no lo quiero
# que me acostaré, sí,
# -¿qué mama?
#
# por qué sé te dan
# o no eso te oigo
# y en las cosas.
# es que te di? ¿de haya y que es mí
# de quién te piden? iba
#
#
#
#
# Poema Generado N° 288
#
# : <BOS>en el viento está que entre los tuyos
# y el rodillas y el otro,
# que se me da el pecho y aire.
#
# al mar y no tengo el girar
# en un treso de la tierra
# me voy a la muerte. ¡cél fuerte!
# ¡
#
#
#
#
# Poema Generado N° 289
#
# : <BOS>¡y será donde es que se olvido
# y me ha de puedo de aliento
# que se le arriba y seguir!
#
# ¿que sé si me saben los pájaros
# ni me abajo el cielo?
# es mi sangre
# o yo me dieron,
# para
#
#
#
#
# Poema Generado N° 290
#
# : <BOS>sucede que le le cantas
# como una boca de huerta,
# donde quien no puedas, no sías.
# ¿y no quieres no me miras?
#
# -¡ay, que no es un nada noche
# que llamó de la santa espero
# y por
#
#
#
#
# Poema Generado N° 291
#
# : <BOS>-¿no hablas que eres parece
# que no hallan a mías?
#
# -mama, mama? ¿por qué? no eso?? ver
# no quienes que es, sí,
# y a veces no soy
# me miran quieres que tú
# con tus peces.
#
#
#
#
# Poema Generado N° 292
#
# : <BOS>no quiero que seguir olvidó el lejos,
# que te dejurre los ojados de las flores, y y a los sueños.
#
# todo me alba en la aveve nieve los pies en espejeros
# y en el mar se desciende en las puertas. no me
#
#
#
#
# Poema Generado N° 293
#
# : <BOS>¿qué dónde,
# dejor que hues puede es que no habla?
#
# -¡y tú no me sécturna
# que me dieron se adentro
# y las poder la noche? ¿por qué me huerta, cuando
# para quieres
#
#
#
#
# Poema Generado N° 294
#
# : <BOS>estoy en mi corazón como el viento
# que en la tierra y tuya, y señor,
# y también en mediodía todo
# añasían mías.
#
# yo no me dan el mar
# la boca que día
# las llanadas. "¿qué ví,
#
#
#
#
# Poema Generado N° 295
#
# : <BOS>por eso puede vuelvo
# que es que el mundo
# a que se responde
# y la siete a la vieja.
#
# lo que me voy a cosa,
# la noche es cada
# de sol sol, de niño
# ni alcanza aliento. ¿a qué sólo?
# �
#
#
#
#
# Poema Generado N° 296
#
# : <BOS>porque no le ojos
# de tus olvidado
# y en las costas de cuentas
# tantas las rías,
# por daréndote a la pobre
# a la muerte hace
# me va a mi alegría.
#
# la noche me en pasto, la alma, com
#
#
#
#
# Poema Generado N° 297
#
# : <BOS>-¿qué las piedras, mama?
#
# --las veras, no sabes,
# mejor buen, esas. eso mejos
# y nunca viste el viento.
# ¡qui, ¿cómo mirar!
# quieres que a es que las rutas
# que
#
#
#
#
# Poema Generado N° 298
#
# : <BOS>-¡ay, todo mí!
# -la tierra, mama, ¿cómo! ¡qué, qué más,
# ¿por quisias y quieres miedo?
#
# me diero me hablas otra
# que me quieron tú mía? ­nto! y
#
#
#
#
# Poema Generado N° 299
#
# : <BOS>-de humo, mama, no tú,
# no te lo que tejos.
# -¿no quiero lo quieres?
#
# yo soy, te cierto. ¿por qué eso? ¡yo no me quien
# ¡�ual que no has vuelvo? es es cerca. no es
#
#
#
#
# Poema Generado N° 300
#
# : <BOS>todavía todo los tientos
# o que abajo el igualquiero
# y en el cielo de la boca
# por el que no se me quieran
# como una casa
# que a un árbol que se, me frente
# de el terrestre
# con la luz, y el am
#
#
#
#
# Poema Generado N° 301
#
# : <BOS>donde no piedras no me pasar
# y al río que me acostar;
# ¡y no qué me habla, que no lo le ha dejales,
# yo ciego que de la marcha
# que no vuelve en su día, y deja,, la cielo, el tanto,y
#
#
#
#
# Poema Generado N° 302
#
# : <BOS>-mama, qué donde unas unos
# que me haya mama no sé
# y el ojo dejor de las ojos.
#
# -¿qué eso quieres que mejaste
# sin piedra y no quienzo
# enas sí!
# ¡quimos la noche
# com
#
#
#
#
# Poema Generado N° 303
#
# : <BOS>me miran a mi casa
# y mejor que no me me pasar
# el cuerpo y lo que me lo deja
# porque estoy me la cara.
#
# ya no lo hacen que vistas
# la casierto y la madre
# que no salen la tierra. y me las montaña
# lo me m
#
#
#
#
# Poema Generado N° 304
#
# : <BOS>-¿qué qué le cuando me di?
# ¡quieres decir, mama? anda, ¿para que estaba? ¡y
#
# -no me quieren, eso, dije,
# es una mujer y por quedada.
# no te te acostié
# por quier
#
#
#
#
# Poema Generado N° 305
#
# : <BOS>-¿qué dónde han es que ya?
#
# -no sin dio, que va a ve
# y me hallando, no se ve,
# que no me vuelven
# o lo que me tú, sigo.
# ¡ay, qué me quieres veso y te dan? ¿cómo?
#
#
#
#
# Poema Generado N° 306
#
# : <BOS>los hijos que la seña
# y la españa que sabe
# la madre me dura
# como el sueño de la noche
# que alimenta.
#
# es la ciego que es
# en las que de oírí;
# ¡y no la tengo dejo
# con el mar de mi alma!
#
#
#
#
#
# Poema Generado N° 307
#
# : <BOS>-¡ay, mama, ¿cómo tú, qué cara?
# ¿por quieres no es que te parecen
# y quiero, que no hablas? ¡no, tienes, nunca,
# su voz te hacia tu hijo.
#
# -viejo, te ha
#
#
#
#
# Poema Generado N° 308
#
# : <BOS>la llena de la vida,
# la sombra y el pan
# de los miedras más, en la tierra.
#
# el blaneció el cielo, el frío
# sobre el fondo de las puertas
# y la noche y la ronda, entre los hombres
# mi pino y
#
#
#
#
# Poema Generado N° 309
#
# : <BOS>y tú mejor que lo que te llega,
# la llama, que no me pero me llevo
# y tu cuerpo se me acerca.
#
# -no hay anto, cuchan, me cargas. no se la mama.unca
# o si no sé que me esa que viene
#
#
#
#
#
# Poema Generado N° 310
#
# : <BOS>-¡ay, mama! ¿es que no bajas?
# ¿cómo no lleva tiene cierto? ¡y tú, cuánde
#
# --no te veo, no te puedo? es que te sabes
# a dejas como eso
# y entregas tambi
#
#
#
#
# Poema Generado N° 311
#
# : <BOS>en la noche de la páría
# que no me hablará a la cierta
# me cerrar las cuando el mar
# y el tiempo que no se todo
# a la mano mece,
# porque se desde la misma luz
# con su pecho de su grito.
#
# no quien
#
#
#
#
# Poema Generado N° 312
#
# : <BOS>donde no sé que quiero más parecida,
# pero que no quise esta siempre
# y yo no me alma y me mece.
#
# -mama, caminar a la selva
# que en la luz que en que traen
# o me dejor, me fui y de la sang
#
#
#
#
# Poema Generado N° 313
#
# : <BOS>alguien se va va se quedó
# y no acerca, se acajar
# con su muerte de su ruta;
# la salva de mi alma,
# me sobre el aliento y la cuentura
# que lo que la miese.
#
# pero los seños en la tierra
# como el
#
#
#
#
# Poema Generado N° 314
#
# : <BOS>la tierra que te dénde
# los que amé,
# este amor tarde
# que te te amo
# en tu voz
# de la muerte.
#
# -¡no te llama!
# ¿a qué tú te alma?
# tú yo te esta tengas
# con él te pueblo
#
#
#
#
# Poema Generado N° 315
#
# : <BOS>un soledad de la cuello
# de la boca hecho en la noche.
#
# hacia el tiempo como el cielo
# y el que se siempre
# como una nadiebla de las palmas. llega
# ¡y en el mar
# se leche y que sube
# a flor
#
#
#
#
# Poema Generado N° 316
#
# : <BOS>si me qué por quiero, que te pobre
# el viento que me espes en el mar
# de tus ojos que en la cara
# y en ese no me dieron
# siempre me acostenas a la sino
# que me hablaría porque de a eterno
# ni por ser
#
#
#
#
# Poema Generado N° 317
#
# : <BOS>-¿y qué me lo quiero, sólo?
#
# -yo quieren, mí, huerta,
# qué bajas, por quediste.
# ¡-pero está de mama!
# yo, tú soy, no más, eso. ¿a mamor? ¡
#
#
#
#
# Poema Generado N° 318
#
# : <BOS>por eso es una noche
# de ras a los viebla,
# sólo unos de ciertos
# y como un niño, y de labios
# que de siete veces, sin cuerpo.
#
# no te quiero sí, comerme
# en los versos vientos. �
#
#
#
#
# Poema Generado N° 319
#
# : <BOS>los caminos de la noche
# que va cuenta a los pinos,
# sus ojos por la garganta
# y los que los vivos y los cuentos
# con su muerte y la fijo
# bajan la más espera o la juan.
#
# en la hierba ella era "cada
#
#
#
#
# Poema Generado N° 320
#
# : <BOS>por qué no me alcanza,
# los que leche y algunas
# y la ruta que su mudo
# que en la misma no llega
# ni el mar y de mi cuerpo
# como el cielo rlegar
# de lo que me ese,ce
# siemprendose que lo mismo
# porque
#
#
#
#
# Poema Generado N° 321
#
# : <BOS>por eso que parece
# y a mi costado
# me iba a la aunca
# te lejos por que se me brazo
# que no se hacen un ciertos.
#
# cuando se habla,
# la baje, la cara
# como una cada, un vagido,bía
#
#
#
#
# Poema Generado N° 322
#
# : <BOS>si me quiere me diero me llegar
# que me mirar la que no me lo quieras
# cuando me viento nacen
# a mi donde me déjor
# y me busca me mían
# con una huerto de mi roja
# o dor de agua.
#
# no me encina la
#
#
#
#
# Poema Generado N° 323
#
# : <BOS>ahora el que no soy voy la llanto
# y he de las manos que nunca me secreta.
#
# no te llamó sin llama,
# los niños alcanzas, no te sómo.. ¡no! no la llega
# pero te al valle de aliento. desde
# porque no
#
#
#
#
# Poema Generado N° 324
#
# : <BOS>en la noche devuelva
# en el cielo como el alma;
# y el viento se va
# por el sueño de alza
# como una falta manos
# de los cuatro vivos.
#
# -¡ay! no te tomaste
# ni te te puedo
# que me mujer
#
#
#
#
#
# Poema Generado N° 325
#
# : <BOS>en una luz de un puros,
# no pasa sin día, piedra, el viento, su pobre, estableciende oscura.
#
# los que te vienen los pinos de la noche
# y el mar que estaba de tu mano. no se pueda. pero ese la
#
#
#
#
# Poema Generado N° 326
#
# : <BOS>ya no está como el cuerpo
# y más que no la se quiero cuentan
# en la noche y me en la revuelven.
#
# -¡y la loca, mama, no te escucho,
# ¿cómo que te amo?
# todas las caras azoradas?s
#
#
#
#
# Poema Generado N° 327
#
# : <BOS>-¿dé amél no, no se vuelva,
# que a mi brazo, siempre, que me fui
# cómo la noche y la sínea?
#
# -y cuando es que no sé la gracia
# y me mama a la viva y que lo sólo
# a ves que
#
#
#
#
# Poema Generado N° 328
#
# : <BOS>porque en las pasa
# no sé dólo,
# sabajar las fábula
# y una sola cerrilla
# de unos de ojos que espera
# tro, muros y de la luz.
#
# el noche que me crecía
# para que no me llevan
# sin que
#
#
#
#
# Poema Generado N° 329
#
# : <BOS>en el viento verde y en el mar
# y no lo que lo digo
# me lo recita y lo mismo.
#
# de la boca que era
# que lo habla mar, mejor y quebraba., ¿qué es el amo?
# no habrar mi pecho
# como una flor de
#
#
#
#
# Poema Generado N° 330
#
# : <BOS>¡dame, pero qué que toco,
# yo está la que no me lleva
# y por quedé tu mano
# como una sola que te amo.
#
# ahora, que tú no son
# de que, dejaros, no te encontrada. ¡¿qué me hoy
#
#
#
#
# Poema Generado N° 331
#
# : <BOS>esa cierto que me fuese
# y la granada deja de noche
# la casa de la nieve
# que no mece alcanza.
#
# sólo me contesta,
# me lo que lo ojo
# como lo mismo está
# ni la primera de mi frente
# para nuestras palmas.j
#
#
#
#
# Poema Generado N° 332
#
# : <BOS>yo no sé, si no mujer
# ¡no! con el que no hay sí.
#
# pero te quiero que te sisto
# y darme en el viento. ¿por qué eso?
# es el oío me fui
# que yo no los hombres
# no quise. lleg
#
#
#
#
# Poema Generado N° 333
#
# : <BOS>en la noche de las nieve,
# mejor que no tienen
# de la sombra me hablaba.
#
# pero si me quedé
# y no me oíces
# como una mano
# que no lo que está
# ni conozco., ¡qué sale
# o me acaba?
# por
#
#
#
#
# Poema Generado N° 334
#
# : <BOS>¡bien, ciudad de págrimas,
# pero de otra vez en el hombre, boca, la tierra, y el que sea
#
# la tierras del pueblo que quiega piedra
# y el tiempo y la viego, hace más, siempre
# el sol
#
#
#
#
# Poema Generado N° 335
#
# : <BOS>y recuerdo lo que me entonces
# y sin puedo yo me alcanza
# en la que te sufuego
# del árbol del mar y del cielo
# su nombre, los su aliento.
#
# ¡y el más allá está la tierra
# la de la sangre y el h
#
#
#
#
# Poema Generado N° 336
#
# : <BOS>-no, tú, ya no me visto,
# y a veo si tienen
# -¿quién me la veañana?
# ¡y sí, que son mama?? ¿es cierto? eso? laú no es mí.
#
# eso yo no lo que nada. ¡
#
#
#
#
# Poema Generado N° 337
#
# : <BOS>yo no segunda esperria esta noche.
#
# no hay una vida en la tierra
# y el árbol de la nieve,
# ni la vieja en el día
# la grave y la arena. ¡cómo!
# el mar, la boca, el viento:
# pero la flor
#
#
#
#
# Poema Generado N° 338
#
# : <BOS>en la noche y el hombre
# y en el año de la señor
# que se les abra el viento
# como un sollozco,
# la espuma de habla.
#
# no sé que te parece
# ni te raz de mar. ¿cómo esa?
# ¿por qu
#
#
#
#
# Poema Generado N° 339
#
# : <BOS>-sí, no te quiero, me quedé
# me no me lo digo desierto.
#
# -no te llananada. mama
# cuando ya me dieron., sé para lo cruz.. ¿qué no más? no?
# ¿por qué voy y no habla? �
#
#
#
#
# Poema Generado N° 340
#
# : <BOS>-¿qué eres, parecómo, mama?
# ¡quién, qué me en que me voy,
# que no me diero se aprió
# y la llama se pobre
# como la hierba y la señada? ¡y
#
# -yo no lo quiso, lo va to
#
#
#
#
# Poema Generado N° 341
#
# : <BOS>cuando llamó el viento
# del desnudo y supeño
# y de noche y al soledó.
#
# yo se la verde que canción
# con su cuerpo de su nieve,
# el que se va sube
# que se día me construía. ¡sóndo!
# ¡de
#
#
#
#
# Poema Generado N° 342
#
# : <BOS>si no me llaman me vuelve
# que no estoy a la noche
# y dejarélleva alguna
# como una sola vida
# de mi cuerpo.
#
# -bula, que yo, mama,
# el sol de dejor
# pero que me dóndome, yo te esperanza
#
#
#
#
# Poema Generado N° 343
#
# : <BOS>las sombra, yo te digo
# que yo me llevo, mi alma.
# ¡el cuerpo amo qué
# y como el mundo que me les habla,
# la danza del mío tiempo!
#
# yo me vuelve mi casa
# porque es todo lo que no te ll
#
#
#
#
# Poema Generado N° 344
#
# : <BOS>la tierra que está caminando,
# el que no habla en madre canta
# su noche es nombre y canto.
#
# bajo el agua, la queda, el tiempo, como una nieve
# y la hallá la que el otro hoy
# siento cayendo el peque
#
#
#
#
# Poema Generado N° 345
#
# : <BOS>-¿que se acosto, no me darme
# y no es unasí, que no tuyo
# con el viento que me lo dejor?
#
# -yo no lo que lo quiero.
# ¡ay, mama, ¿tú no, eso? ¡y llama?? yo me l
#
#
#
#
# Poema Generado N° 346
#
# : <BOS>para el que no me vuelvo
# con el viento que en la elele,
# y yo canto y él no tengo
# no me da el pecho aire, enseñor, el mundo, y el mar
# porque me lo que me me escuchar
# me el silencio y sin que lo niño
#
#
#
#
#
# Poema Generado N° 347
#
# : <BOS>tú no mece me llevar los ojos
# dejor y de un ímpago y arre.
#
# tu piedra con todo
# que tuyo aman,
# enciendo y en el viento
# y no tengo tienes cielo. ¡silado!
# ¡có
#
#
#
#
# Poema Generado N° 348
#
# : <BOS>todavía el despojo de la tierra;
# aliento en el vienta y el silencio
# de la estrella de su caballo.
#
# el que no sólo supe
# porque en las puertas y dejos
# como el cielo una cerros
# y el que era la mano
#
#
#
#
#
# Poema Generado N° 349
#
# : <BOS>todas las vientras
# y el que pino
# que no me la alma
# la boca que el mundo
# en el mar
# re la canta,
# otra en el desnuda
# las caminas
# como el nido
# del mar y el cielo.
#
# todo el vino que todos
# con el
#
#
#
#
# Poema Generado N° 350
#
# : <BOS>vamos de llegar
# todos años en el mundo
# que no se vean
# y se fui más
# en la luz,
# o en desde la noche.
#
# se va y vuelvo
# el camino
# como el pinar. y el mío. ¡y tengo!
#
#
#
#
#
# Poema Generado N° 351
#
# : <BOS>-¡ayó, tú no te rompes
# de unas parecen piedras!
#
# -mama, mama y mejor,
# no te digo, ¡no! ¿qué de nada! mí!.
# ¿a tiene má en miedo. ³y sí,
#
#
#
#
# Poema Generado N° 352
#
# : <BOS>te digo, el que te amo
# de que no te dejez oigo
# y no me vuelven
# como cierto o puedo.
#
# -¡y si te eso es mama?
# ¿o no sabes no hablas
# que no la nada?? ¿quién me aman
#
#
#
#
#
# Poema Generado N° 353
#
# : <BOS>cómo no me dijo dejor y no habla,
# todo lo que la que mece sin cuerpo
# y no la oíría como una sueño:
#
# -¡y es que te eso que tengo
# la madre que se me la huella
# porque no lo mían comer
#
#
#
#
# Poema Generado N° 354
#
# : <BOS>pero en la tierra no es el tiempo
# y en mi madre niño "y cuando en el llano
# con el cielo de su cuerpo.
#
# -y si eso cuentre el niños
# como una tenerte
# sin noche que estándosecha
# no sí, só
#
#
#
#
# Poema Generado N° 355
#
# : <BOS>hermano, tú mejor, que me dieron
# de mi casa y duras
# hasta que no señan
# y esta palabras que quemas
# ni puede lejos serán.
#
# todo lo viente, y olvidarme
# porque no lo mismo que sólo
#
#
#
#
# Poema Generado N° 356
#
# : <BOS>no hay tengo de noche
# en una ventana de poco.
#
# pero si yo te eso
# que no más
# como alcanza que te nada. dilo,
# ¡no mí! ¿porque es un hace tarde
# y te oío te cruzado
# por quieres que
#
#
#
#
# Poema Generado N° 357
#
# : <BOS>-¡ay, mama, no, mira,
# -mama! no sé que tú, sías
# no sigo, que es que me mían.
#
# ¿quién más podría la mirada?
# y si me entiertas por esa. ¿es que no eso? ¡
#
#
#
#
# Poema Generado N° 358
#
# : <BOS>la noche que llega la mano se está estrella,
# y tú, no te ha llevo que te vuelen
# porque no señas como unos nada.
#
# yo no quiero más que no sé
# todo lo que naciendo
# sino que alcanza de la sombra
#
#
#
#
# Poema Generado N° 359
#
# : <BOS>-¿qué dieron qué es que no está día?
#
# --no me quieres, sí, te haya huerta.
# ¡cómo aguas, no mama, y sueños,
# y que te di? no eso, ¿porque se dejor? ¡
#
#
#
#
# Poema Generado N° 360
#
# : <BOS>y donde estás que no habla
# en la noche se hacía
# y nunca lo no me la segura
# que la rama a su cuerpo
# ni la que el huerta.
#
# -donde no se me vuelve
# por quedaron;
# pero cuando me ha de la mía,
#
#
#
#
# Poema Generado N° 361
#
# : <BOS>por eso que te habías tanto
# la noche me entre las manos.
#
# no te dierras que no se entiendo
# que se me hace el cuerpo. ¿quiero qué quieres?
# ¿y no quierasí, te hizo? ¡no? no ese es
#
#
#
#
# Poema Generado N° 362
#
# : <BOS>y el que todo lo mío.
#
# lo que lo que vuelven
# como unas cierto,
# algunas de tierra
# que de sombra tierras
# en el alma. ¡qué siento!
# ¡y no qué más, ¿de mama! tus ojos
#
#
#
#
#
# Poema Generado N° 363
#
# : <BOS>ahora es es que no lleva
# de donde no me llegar
# que no qué que me olvidé
# y en la luz de la cara;
# tú no la rueda me acostengo
# la noche me natural dejor,
# porque me quiero que te es dejo
# como un
#
#
#
#
# Poema Generado N° 364
#
# : <BOS>cuando camino de amor,
# añor de los pies, que tren, me llevas
# en la tierra, y el viento
# y en la noche de san juan.
#
# sino diciendo
# me hablar, nad en espero, alcanza, sólo
# de la caña y
#
#
#
#
# Poema Generado N° 365
#
# : <BOS>en el cielo que tres mejillas
# y no traer a mi pecho,
# con la lluvia de las cosas
# pero lo que se habla
# que que el que la que me la ciega.
#
# el caminó, el país y el soledado
# de tierra que no se hayó
#
#
#
#
#
# Poema Generado N° 366
#
# : <BOS>yo no sé, no,
# -qué que no me qué
# que no se diero sabía
# ni me ver a quedar
# y no quieras las niñas.
#
# ¿quién volarénde, eso?
# no quiso es es el árbol. ¡ngelto
# la
#
#
#
#
# Poema Generado N° 367
#
# : <BOS>y quiero que es más frío,
# por qué por quienes, olvido, y mí, a las casas, quiso, sí me vierno
# y en mi corazón que me la quedan.
#
# es la que dejor, una isla que no me deja. ¡no
#
#
#
#
# Poema Generado N° 368
#
# : <BOS>yo no sé que son alcanzanas
# y que nunca se escondiendo.
#
# -lo que tú ya cuánde,
# que me carga el padre que no tengo
# de que me dejor tien parece
# donde no me llamar. ¿se leche todavía?
#
#
#
#
#
# Poema Generado N° 369
#
# : <BOS>yo soy el que te aconcómo
# que me quieren, y no hablas las puedas.
#
# no hay nadie, no se habían. no te sigo. ¡yo no más!
# ¡no te serán tengo uno de alma!o. el mar, yo te tuy
#
#
#
#
# Poema Generado N° 370
#
# : <BOS>porque se noche se toca
# a la mano está con la nieve,
# y en la tierra no la entre los vientos
# que la pradera de los tres
# ...
#
#
#
#
# Poema Generado N° 424
#
# : <BOS>la ronda de los que viego,
# cómo del cielo de alma,;
# ¡y podrían tus ojos
# y de la tierra
# que vivieron sus olas
# como ríos de pecho
# niño de mis árbol de páría!
#
# al quer
#
#
#
#
# Poema Generado N° 425
#
# : <BOS>yo te vuelo en el que te escuchas,
# nosotros también más que he viste
# porque me lo mismo que no me la fiesta.
#
# -todas tú no es mama
# no siempre me dar
# y si la mirada deja
# que te quiero verdes, d
#
#
#
#
# Poema Generado N° 426
#
# : <BOS>por eso también el rojo
# llegrío como el viento
# de la chinchilla del pueblo,
# parece y la calleada.
#
# -maría, hacia el bosque
# o paremos, canto, aún, tú, sólo
# y tanto que qu
#
#
#
#
# Poema Generado N° 427
#
# : <BOS>de la montaña del otoño,
# y era un ponco de más, y arañales
# que me quería en la tierra
# en cintura y la piedra.
#
# ninguno no lo mira
# o me miraba a la mano
# la madre a los cinco, todos
# las camin
#
#
#
#
# Poema Generado N° 428
#
# : <BOS>donde la miel, más que repas
# la noche que la lle el sueño
# y como la ruta
# de la hora y de la niebla
# en cualquiudida
# con las palabras.
#
# se leche, mascando,
# caminan, niñas, hicen
# com
#
#
#
#
# Poema Generado N° 429
#
# : <BOS>en la noche y las rostro
# me miró el cielo,
# y el tiempo y el mar
# conocer que no se me en fui
# como el que busca
# que no me lleva el aliento.
#
# yo no quienen las aguas
# a la ruta
# o en la casa
#
#
#
#
#
# Poema Generado N° 430
#
# : <BOS>el aire de los volcanes de sus ojos
# y una noche abriráisana.
#
# cuando se habla a vuelva a mi nombre
# que a contar mi cara alma,
# en todo lo que no te ha llevo.:
# no me viste más dejor
# silb
#
#
#
#
# Poema Generado N° 431
#
# : <BOS>como la noche no las nieblas
# y la menta la frente
# la de la siesta, la cara.
#
# las cerras de las vuelvo
# comenzada de alcanza,
# donde la mesa de aleja;
# ¡y no mía la miedad!
# los que nadie
#
#
#
#
# Poema Generado N° 432
#
# : <BOS>no me quiero que te puede,
# me da mi propia hacerme
# y el gran desposo de su espalda.
#
# para que no quien me tengo
# sin que me llevar brazo. ¿o a qué no no me me alcanza
# ni me entrarme a la quiere
#
#
#
#
# Poema Generado N° 433
#
# : <BOS>pero ya me se abió,
# y me llevarme, no me qué alcanz, pero
# que me hablaba mi paso.
#
# -¿qué me pasa pasar
# sólo eso si me di?
# ¡y ya no te mama
# por ese entero
# de quién va
#
#
#
#
# Poema Generado N° 434
#
# : <BOS>dejecer, más que llevo,
# mejé una ruta que te alma
# y que el cuerpo de la ronda
# que me miran como unas
# a madre de sombra
# de la trenz o el llanto.
#
# -¡y no qué la ciego, niño
#
#
#
#
# Poema Generado N° 435
#
# : <BOS>y en la noche se viene una casa,
# y hay un donde hecho con él se acabar, la mano, el blanco
# a no desde un árbol que tiempo
# cando las cosas trencia;
#
# tal vez no me abrazo te hablaba, a la sise
#
#
#
#
# Poema Generado N° 436
#
# : <BOS>¿qué no es verde, eso espero?
# ¡y qué me decir no, mí!
#
# -³la, la mama! ¿no? ¡�rbol, quien lo que es dejo.
# ahora? no me lo quierencia,
# el oírí, y lo
#
#
#
#
# Poema Generado N° 437
#
# : <BOS>-¿qué va todo, es, mama?
# ¡qui, ¿por qué que no? ¡cómo,
# no hablas tien, que nada? no abierto.
#
# -no te corto me vueles, ya ya eso. ­nto
# y no lo hallan
#
#
#
#
#
# Poema Generado N° 438
#
# : <BOS>no todo lo que todos vieja
# muerte en que enseñas las ciertas,
# y en las cosas de las ebria.
#
# -sólo tienen sus ojos
# de manos de mi pecho
# que en el árbol de la muerpo. ¡ngel
# para
#
#
#
#
# Poema Generado N° 439
#
# : <BOS>-¿y me voy a quieres, puedo
# y no te llamamadas?
#
# -mama, no la veo,
# o te hacía
# que te cierto que pasa.
# ¡ay! ¿por qué eso? ¡cómo saliertas?? no, se pob
#
#
#
#
# Poema Generado N° 440
#
# : <BOS>los vientos los hombres y los tres
# que el agua y del cielo
# y de los ojos y las islas
# al y la noche asombre.
#
# quién aquí está en que nacen
# en las estas caminas
# las manos de las madres,
# caían por
#
#
#
#
# Poema Generado N° 441
#
# : <BOS>y la noche jacimos alzando los hombres
# es la que el viento y el agua,
# de tiempo que te dieron
# y que no que me hacieras
# como que se apretan
# porque no me llamando.
#
# la palabra no la vieja
# el mism
#
#
#
#
# Poema Generado N° 442
#
# : <BOS>-¿por qué te ves mama,
# -mama! no te lo que no?
# ¡quiero es que eso que te oí.
#
# no hay uno tú te lejos. te parecido. ¡no, mío, te más. quienes, el a la muerte
#
#
#
#
# Poema Generado N° 443
#
# : <BOS>tú me vienen los caminos dieron
# que no me abrán, hombres, que dejaré,
# en la tierra muerte y la ciega.
#
# hay pueda noche
# y una llama que nada
# eres canto que la mía
# dejaste y de los h
#
#
#
#
# Poema Generado N° 444
#
# : <BOS>-no, ¿qué, mama, si eso?
#
# -¿por qué no es que,
# porque en quiero, la nada? ¡quién, que te
# ¡ay, va, "para? es es, loco.
# y la mío ser. �to, quien, per
#
#
#
#
# Poema Generado N° 445
#
# : <BOS>el viento que se parece
# que se acuerdo y se doy
# y a mis ojos me buscando
# por quedaron a busca
# con las cosas y las las quebras
# o si entre mis muertas.
#
# -¡y yo tú, te pasa,
# no quiero t
#
#
#
#
# Poema Generado N° 446
#
# : <BOS>le hacía y salino al sol de las puertas,
# y la tierra de la muerte, y el viento, la montaña
# porque donde el silencio, levanta, que que viste.
#
# el vino que lo que la vuelve la lejos
# la canta que fueron
#
#
#
#
# Poema Generado N° 447
#
# : <BOS>-¿qué dónde qué mama?
# ¡quién me quiero, tú
# que me hablas y regresas? ¿es? no, que me llevas
# me déjorado y me vuelan? esto
#
# --cómo lo paso no lo huertas
#
#
#
#
# Poema Generado N° 448
#
# : <BOS>-¡qué que qué si me dejor que no me quiero
# ¿quieren que pasa que me llegar
# que no parece
# ni por quieres que di?
#
# -por quiere sí, mama,
# me yo me vuelvo.
# es la nada
# y bajaron
#
#
#
#
#
# Poema Generado N° 449
#
# : <BOS>madre y parece
# que yo puedo
# ¡toda el instante!
#
# no viento todos
# porque vuelve
# me dios olvid
# de madre que te dieron.
# -¿qué voy a qué quieres
# y me dónde perdido
# o no qu
#
#
#
#
# Poema Generado N° 450
#
# : <BOS>-¡ay! ¡qué está mama, más!
# ¿quién que la mía
# que el viento es que me fui
# y la verte dejo deja! apretada
#
# -mama niño, que te habla
# por quieres que no sí,
# el nombre
#
#
#
#
# Poema Generado N° 451
#
# : <BOS>-¿en qué quieres tú, mama?
#
# -por quiero no pasa
# ¡ay, quemos, no la veo? ¿quién
# las quiera tienes un alma? siempre
# o, dar que es que te quienen
# y entero de que digas
#
#
#
#
#
# Poema Generado N° 452
#
# : <BOS>el hombre se sombra, aquí,
# se abriendo el rostro, aire a sus dos págrimas,, el año, sin roto, una ola
# el árbol de la cierto, la tierra cuerpo su cielo en la alma.
#
# no saben las pied
#
#
#
#
# Poema Generado N° 453
#
# : <BOS>-ahora es que me parece
# y el viento que te hablas.
#
# -no te te eso, te he dejor
# que te dejo deja. ¿donde te dura?
# no sé te llevo. esa
# ¿qué quiero volteada? "¡yo?
#
#
#
#
# Poema Generado N° 454
#
# : <BOS>-pero no te sé, no tengo
# y sí, mama, me da ara
# en donde el palabra.
#
# -¡y te te digo, sigo?
# ¿qué me amo me sólo
# o te pajarme!
# por qué dejor y mejame
#
#
#
#
#
# Poema Generado N° 455
#
# : <BOS>desde una vez la llena
# que caída la madre
# y el mar y el pecho de los cuentos
# en la noche, sin niebla.
#
# rás que la muerte, no me ven,
# la tengo que no hablar
# con verdad y llamado, la montaña
#
#
#
#
# Poema Generado N° 456
#
# : <BOS>-¡ay, mama, no mía,
# sin tú no las ras
# que me sé me deja años
# porque te donde síos?
#
# -no me acercas, es ciertas.
# yo no los vivos. ¿qué "¿por qué? no sólo
#
#
#
#
# Poema Generado N° 457
#
# : <BOS>hay, mío, no más,
# donde no, ni ni donde
# la oración de mujer
# y de mi patria, y mi alma
# como una cuerpo.
#
# hizo mi boca, mi voz, cuento, el alba, la muerte, en la noche, un
#
#
#
#
# Poema Generado N° 458
#
# : <BOS>-¿por qué me toca,
# es que es que me la hierba
# mama, cita seránde
# que en los caminos.
#
# -es, no eso te dieron. "¡y me lo que he dejo, mama!
# ³y no tú, ¿que, llama?
#
#
#
#
# Poema Generado N° 459
#
# : <BOS>con el oro de la cierta
# y la pudad de las cordilleras,
# de manos de llama, plumas
# con la tierra de piedra, y aire, el hombre y la luna
# a vez la secreta.
#
# la noche que te más, yo, tuvimos, los
#
#
#
#
# Poema Generado N° 460
#
# : <BOS>se hacería de una mano de su manó su boca
# se lejó la fría, el muerte, como un día.
#
# la isla de la brazada, la otra bultándome. la noche
# y en la gencada no se hanía su destinado.a,
#
#
#
#
#
# Poema Generado N° 461
#
# : <BOS>pero a la sabeza
# a la tierra
# la ceño de la mía,
# no te dijo:
# porque no séisiera
# el niña
# o que tengo
# que alumbra.
#
# -¡sío, mí, amor, caminando
# de azor!
# ¿e �
#
#
#
#
# Poema Generado N° 462
#
# : <BOS>-mama, no es mama.
#
# -cómo te te eso tú
# ¿cé, di, ¿por qué? no, mí?
# o es que es cierto
# que no la pueda
# no sé que te quiero. ¡qué mujer
# pero no lo que ha
#
#
#
#
# Poema Generado N° 463
#
# : <BOS>porque mis brazos se oyen
# y a mis manos a su viento.
#
# se va en el mar
# lo que te llevarme
# que me saben mi voz. ¡por qué te alma
# ¡y no tengo el alienta!
# a si dejor que me oye
# ni t
#
#
#
#
# Poema Generado N° 464
#
# : <BOS>por eso a esa más allá de mi pecho
# y en una casa que tú, que lo que yo,
# porque me vuelve en mi boca
# ni el mar y me la cara.
#
# -¡qué apreta quién y caminar
# que no qué conozco
# a de m
#
#
#
#
# Poema Generado N° 465
#
# : <BOS>mi tanto que me quiere miedo, ya te va ape
# que el cielo que te olvido;
# pero yo no lo que lo sentido
# ¿por qué no me lo eso?
#
# -tú te te a la vivir
# y yo te habla mío
# como la que no ha
#
#
#
#
# Poema Generado N° 466
#
# : <BOS>cuando la tierra, más,
# tú, mejor que me la vida, el verde, en un zodas
# y la noche y tristal
# en la gargo que se pobre tu roja
# sin saber de tu pecho
# como una alma de toda tu ninguno.
#
# no
#
#
#
#
# Poema Generado N° 467
#
# : <BOS>en el mar de las gavillas
# y en el pecho de piel-
# con su piedra en cielo,
# todavía y se acordado, te adeles
# sus ojos que gritan los que ti
# porque no sólo como en que yo
# que yo, en mi alma y mecer
#
#
#
#
# Poema Generado N° 468
#
# : <BOS>hasta que lo pequeñas y señan
# la llena de las ras que la ruta
# y se vuela por el huerta
# por la pándose y el viento.
#
# -no qué me quiero que es mi dura
# que me pasa y que me o vayan
# segú
#
#
#
#
# Poema Generado N° 469
#
# : <BOS>la vida que ella es como a más,
# y la hierba que te otra vez
# ni la vieja que la rompa
# la que van la sos que amo la he entra
# que me la lleva a la madre, la alma
# por la noche la me alcanza.
#
# -�
#
#
#
#
# Poema Generado N° 470
#
# : <BOS>en la noche se la viebla,
# se habló la tierra
# la espuma del marino,, la espacio,y la casa.
#
# volve un día de dulce
# de pastales de nuevo, y maría, piedra, ya no fui.nuda, mi alma, no me
#
#
#
#
# Poema Generado N° 471
#
# : <BOS>otros los pies tres tú yo sólo
# y el mundo de la noche
# que no séisiera sosten
# a la sino como una casa
# en el viento que no me ojo
# o si me han la mano.
#
# no me vuelvo a la quiega
# como el
#
#
#
#
# Poema Generado N° 472
#
# : <BOS>está banderas
# con el viento del mar.
#
# el canto y el valle
# la tierra
# que el mar y la noche
# en el silencio.a
# tal vez es su nombre
# por la piedra,
# como una espada
# laba los niebla, y cielos
#
#
#
#
# Poema Generado N° 473
#
# : <BOS>y la raya donde la vida
# y su boca a su destino.
#
# al sol te bienen como una espino,
# ¿qué qué amor que veo quiero?
# tú no te quedas tú eres? no eso. no hay nada
# eso que sólo que
#
#
#
#
# Poema Generado N° 474
#
# : <BOS>
# no poco de tanto
# a noche, piedra,
# mejé
# los pueblos, amar
# de la tierra:
#
# vienes
# la nieve
# en la ninguna
# del otoño
# cuando
# que
# ni pobre
# y
# pero
# con una isla de agua
#
#
#
#
#
# Poema Generado N° 475
#
# : <BOS>y esa también me acostar,
# y me vuelto a más, rostro.
#
# -no te sabes la mama
# ¿qué ya no voltijo?
# no es que me quiero y cantar
# que no me aman. no lo odio. ¿porque alcan es la noche
#
#
#
#
# Poema Generado N° 476
#
# : <BOS>presaré en su mío, por el alma y de las piedras,
# y a la noche que me crié a verde
# con sal y se baña y a los días.
#
# el viento que no se desió la hierba
# ¿por qué me hoy a quedaba?
#
#
#
#
#
# Poema Generado N° 477
#
# : <BOS>el sol que sólo el viento el mundo
# con un barco del cielo.
#
# la próndose en la cierta,
# y el baja aire su rey. la pronto
# ¡y como una puertos y de llamas!
# por más de noche
# defiendo en
#
#
#
#
# Poema Generado N° 478
#
# : <BOS>y la mira el donde cielo
# ¡no! ¡en la luz, el cierto!
#
# -¿y qué quienen tengo?
# pero ya no leche
# y no, ¿porque no la orilla? ³y
# con quién con lucha?? alcanza,
#
#
#
#
#
# Poema Generado N° 479
#
# : <BOS>y la muerte, que no te viene
# o en la flor de la mano deja,
# la azul de mi tréndola
# y el pan de puro que te mira.
#
# es la que tú me como el aire
# que no sólo que mece, sigo. ¿qué está qu
#
#
#
#
# Poema Generado N° 480
#
# : <BOS>me duerme las venas, dejillas,
# de ti, y de noche, pero porque, sin mujer
# y no me vuelo de alma.
#
# -¡ay! no tienes que yo tengo
# para que no se hacer. ¡ahora ya me también
# como
#
#
#
#
# Poema Generado N° 481
#
# : <BOS>no me dejor que no te saber,
# ya no me estoy en la noche, espera.
#
# qué mujer que me lleva
# y a la sé yo no saben
# que no digo se me me alcanza. "¿cómo me qué me lo digan?
# ¡y no
#
#
#
#
# Poema Generado N° 482
#
# : <BOS>y los cuerpo caer en la otoño
# y donde se acordaba.
#
# a la madre y de pábía,
# con su muerte y los ojos. y se sólo, piedra, y no sabía. ¡sómo te parece!
# ¡y no la he ignor
#
#
#
#
# Poema Generado N° 483
#
# : <BOS>como el alma del vino
# y el loco que te destino;
# ¡y era canta no señor!
#
# -¿a te puedo peremos,
# de tumba que la dura
# comenzar la encina, ademos
# se la noche de la muerte, -sa, la
#
#
#
#
# Poema Generado N° 484
#
# : <BOS>en el mar de nuestra piedra,
# parece una razada
# y la mirada de oscura
# sobre la luz de la alma.
#
# vamos a los tiempo
# sin más como unas
# que me pobrar por quedado
# a madre de noche
# ni otra
#
#
#
#
# Poema Generado N° 485
#
# : <BOS>llegó la paloma,
# de la hierro, sube
# y a la tierra
# como la llamarada
# la sangre y el agua
# con la luz
# que no mece del cielo
# en canto aire.
#
# si no la esta noche
# o en el pecho
# porqueña y a ve
#
#
#
#
# Poema Generado N° 486
#
# : <BOS>estoy a la tierra están en la noche
# que en el mundo cuento más,
# la luz que en que me lleva
# y la mirada de la callada.
#
# el viento la caña
# de la mano y señarla
# ni la madre y el canta
# o no la luna,
#
#
#
#
# Poema Generado N° 487
#
# : <BOS>-mama, ya me lo que mejor
# y me desenas a veces
# que me llevo me da a mío
# porque no me sé, ni porque
# con unos me donde me acas
# ni por qué me quien oías.
#
# -¿y no quieres tú me f
#
#
#
#
# Poema Generado N° 488
#
# : <BOS>por el caerme lo que lo visto
# y no hablan y alcanza
# porque no como si fuese la ruta
# en las piedras y la queja.
#
# -pero él me lo haría,
# la noche deja y el peso, la leche, llega
# que nos hu
#
#
#
#
# Poema Generado N° 489
#
# : <BOS>¿a quién puede la muerte?
#
# -bajo el viento,
# ¡cómo di? ¿qué habla? no, sé, ras
# por qué quien cada? sío? y quiero.
# es cónde a la vez. ¡qui
#
#
#
#
# Poema Generado N° 490
#
# : <BOS>las otro que no saberán,
# de las ricen, y todos los ojos
# con su amor, con su cuerpo, derribada
# que pasó a la niebla de los senos.
#
# lo que son como las llenas. ¡qué, me llega!
# ¡y
#
#
#
#
# Poema Generado N° 491
#
# : <BOS>y a gotería de entro en la duros,
# cómo aúscuro, un silencio, flor, mi propia, enfermo
# haciendo la aurora de la tierra, la muerte, como un lluvia, almientras, de pronto, sombra en llanto, y
#
#
#
#
# Poema Generado N° 492
#
# : <BOS>-¿quéndo estándome a qué
# que no te huerto, mama?
#
# -pero ella no, no es que la quiero.
# ¡ay, sá que te digo
# y gan a la miedo,
# porque me llevan en ellas
# no quieren las
#
#
#
#
# Poema Generado N° 493
#
# : <BOS>en la noche no se sólo
# y en la está día
# como una ninguna
# que me fiel más
# la boca que la seguía.
#
# porque no me quiero que me sobre
# a que yo me llevan
# en un donde
# pido brazo y en su bander
#
#
#
#
# Poema Generado N° 494
#
# : <BOS>el nombre de los bajos
# que se haber canta,
# y a la albatado
# ni la raza de la muerte
# al que se desde
# como el pecho
# de la costa y deja.
#
# ¡pero no ser mía,llorando
# re cosa de su viento
# ent
#
#
#
#
# Poema Generado N° 495
#
# : <BOS>hay una mano, océano y un día
# en un verde que yo verdad,
# su mía un silencio de agua, un oro de un cielo
# y un ramo de otoño de mujer, como unas oeste.
#
# ¡y tú no qué quiero que
#
#
#
#
# Poema Generado N° 496
#
# : <BOS>yo yo soy el que te siempre
# que por quempre me llevar
# a veo como en cielo
# y en que me vuelve
# con el canto y lo alma,
# quiero que cuando
# ya me hallar en nombre
# en su oída
# niño de pino y de mi cas
#
#
#
#
# Poema Generado N° 497
#
# : <BOS>-¿a quién, mama, ¿qué es que no tiene
# y eso? ¡quién miedo.
#
# -no te respondas y la lleva
# que con el alma y habla,
# pero qué habamos por mío
# porque te sías las caras
#
#
#
#
# Poema Generado N° 498
#
# : <BOS>en el mundo blanco
# a la arena,
# por el mar, la mano
# de la granada
# y hacerte amar
# la cada y el cielo.
#
# en la mañana
# para que no lleva
# como el juan. ¡qué
# lo que puedo, cosa
# el ind
#
#
#
#
# Poema Generado N° 499
#
# : <BOS>parecían los ojos
# como los que nosotros
# que nos abajas.
#
# ahora se así,
# y en nacía
# la luz ola de la sangre
# desde las caminas, unas
# quiere sería, la noche
# con una nieve
# sin mí. est

# %%
## Guardar los poemas generados

generated_poems = []

for i, sample_output in enumerate(sample_outputs):
  if tipo_tokenizer == "tiktoken":
            generated_poems.append(tokenizer.decode(sample_output.tolist()))
  else:
            generated_poems.append(tokenizer.decode(sample_output, skip_special_tokens=True))

output_file_path = f'ModeloA_prompt_libre_T_{int(TEMPERATURA*100)}.txt'

with open(output_file_path, 'w', encoding='utf-8') as file:
    for poem in generated_poems:
        file.write(poem + '\n\n\n')

print(f"Generated outputs are saved to: {output_file_path}")
# Out:
# Generated outputs are saved to: ModeloA_prompt_libre_T_60.txt

# %% [markdown]
# **Word Clouds**

# %%
archivo_path = f'ModeloA_prompt_libre_T_{int(TEMPERATURA*100)}.txt'

with open(archivo_path, 'r', encoding='utf-8') as file:
    contenido = file.read()

wordcloud = WordCloud(width=800, height=400, background_color="white", stopwords = stopwords_espanol).generate(contenido)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# #7.B. Entrenamiento SP-GPT2 con GPT2 preentrenado de Hugging Face

# %% [markdown]
# ---
#
# GPT2 preentrenado con el corpus de wikipedia y libros en español [link del modelo](https://huggingface.co/DeepESP/gpt2-spanish). Por lo que el entrenamiento es esencialmente realizar fine-tuning con nuestro corpus.
#
# ---

# %%
''' ¿Qué tokenizador usar? '''

tipo_tokenizer = "preentrenado"
#tipo_tokenizer = "tiktoken"

''' ¿SP-GPT2 o sólo GPT2? '''
sp_gpt2 = True

# %% [markdown]
# ## Entrenamiento

# %%
#OBTENER MODELO PREENTRENADO
model_name = "DeepESP/gpt2-spanish"
configuration = GPT2Config(vocab_size=vocab_size, n_positions=MAX_LEN).from_pretrained(model_name, output_hidden_states=True)
poem_stanza_model = GPT2LMHeadModel.from_pretrained(model_name, config=configuration)
poem_stanza_model.resize_token_embeddings(vocab_size)

#MODELO LSTM
head_gpt = SelfAttentionLstm(input_size=768,hidden_size=256, num_layers=1,n_head=2)
for param in head_gpt.parameters():
    param.require_grad = True
# Out:
# pytorch_model.bin:   0%|          | 0.00/261M [00:00<?, ?B/s]

# %%
batch_size = 8

train_dataloader = DataLoader(dataset_train,
                              sampler=RandomSampler(dataset_train),
                              batch_size=batch_size)
valid_dataloader = DataLoader(dataset_valid,
                              sampler=RandomSampler(dataset_valid),
                              batch_size=batch_size)

# %%
# hyperparameters
learning_rate = 1e-4
eps = 1e-8
warmup_steps = 50
device = torch.device('cuda')
epocas=10
optimizer = torch.optim.AdamW(poem_stanza_model.parameters(), lr=learning_rate, eps=eps)
criterion = nn.CrossEntropyLoss().to(device)
total_steps = len(train_dataloader) * epocas
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps=warmup_steps,
                                            num_training_steps=total_steps)

# create text generation seed prompt
prompt = "<BOS>"

if tipo_tokenizer == "tiktoken":
  generated = torch.tensor(tokenizer.encode(prompt, allowed_special="all")).unsqueeze(0)

if tipo_tokenizer == "preentrenado":
  generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)

generated = generated.to(device)

# %%
poem_stanza_model, train_loss_B, valid_loss_B  = entrenar_red(poem_stanza_model,
                                                              head_gpt,
                                                              tokenizer,
                                                              train_dataloader,
                                                              valid_dataloader,
                                                              newline_token_id,
                                                              device,
                                                              criterion,
                                                              optimizer,
                                                              scheduler,
                                                              epocas,
                                                              tipo_tokenizer = tipo_tokenizer,
                                                              sp_gpt2 = sp_gpt2)
# Out:
# Epoch: 01 | Epoch Time: 4m 52s
# 	Train Loss: 4.115, LSTM loss: 0.073
# 	 Test. Loss: 3.649, LSTM loss: 0.012
# Epoch: 02 | Epoch Time: 4m 55s
# 	Train Loss: 3.201, LSTM loss: 0.019
# 	 Test. Loss: 3.292, LSTM loss: 0.010
# Epoch: 03 | Epoch Time: 4m 55s
# 	Train Loss: 2.469, LSTM loss: 0.016
# 	 Test. Loss: 2.981, LSTM loss: 0.010
# Epoch: 04 | Epoch Time: 4m 55s
# 	Train Loss: 1.828, LSTM loss: 0.014
# 	 Test. Loss: 2.730, LSTM loss: 0.010
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Epoch: 05 | Epoch Time: 4m 56s
# 	Train Loss: 1.348, LSTM loss: 0.013
# 	 Test. Loss: 2.500, LSTM loss: 0.009
#
#
# Poema Generado N° 0:
#  el aire que pasa por tu cuerpo
# ¿no lo ves? oye.
# es como un ruido
# que corre y que corre
# por tus faldas.
#
# vienes volando.
# vienes volando.
# por la sierra del mundo,
# por la feria del valle
# donde no hay nadie.
# por la sierra del mundo.
# vienes volando.
# vienes volando.
# por la sierra del mundo,
# donde no hay nadie,
# vienes volando.
# vienes volando.
# por la sierra del mundo,
# por la feria del valle,
# donde no hay nadie,
# donde no hay nada.
# vengo a encontrarte,
# vengo a encontrarte,
# vengo a encontrarte.
# ¿por qué? ¿por qué?
# ¿por qué? ¿por qué me traías?
# ¿por qué estás aquí,
# me oyes? ¿es cierto?
# es cierto.
# ¿por qué,
#
#
# Epoch: 06 | Epoch Time: 4m 55s
# 	Train Loss: 1.017, LSTM loss: 0.012
# 	 Test. Loss: 2.324, LSTM loss: 0.011
# Epoch: 07 | Epoch Time: 4m 55s
# 	Train Loss: 0.791, LSTM loss: 0.011
# 	 Test. Loss: 2.239, LSTM loss: 0.011
# Epoch: 08 | Epoch Time: 4m 55s
# 	Train Loss: 0.647, LSTM loss: 0.011
# 	 Test. Loss: 2.132, LSTM loss: 0.012
# Epoch: 09 | Epoch Time: 4m 55s
# 	Train Loss: 0.557, LSTM loss: 0.010
# 	 Test. Loss: 2.112, LSTM loss: 0.015
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Epoch: 10 | Epoch Time: 4m 55s
# 	Train Loss: 0.501, LSTM loss: 0.010
# 	 Test. Loss: 2.097, LSTM loss: 0.013
#
#
# Poema Generado N° 0:
#  la muerte no me alancea;
# en una noche de éstas mi rostro
# conduce y repasa
# su rostro con las palabras.
#
# la muerte es un cuento
# en que los vivos se juntan
# como río de río a río,
# y en el silencio, el niño
# con diez años, lo peino
# y le doy su gracia.
# los vivos nunca fallan;
# la vivos no lo quieren.
# yo le he conocido, yo le he visto
# carne de alepo, de salmuera,
# y salino de limo,
# y salino de su nombre
# al que llaman el cristo.
# los muertos nunca fallan;
# en una muerte así, morir es morir.
# y la muerte, como la vida,
# como una antífona, es la muerte.
#
# yo le llamo desde el nacimientos
# y nunca le nombro a mi madre
# hijo de mis

# %%
plot_losses(train_loss_B, valid_loss_B)

# %% [markdown]
# ##Generacion de Poemas: Experimentar con parámetros de Temperatura

# %%
##Experimentar con diferentes prompt

prompt = "<BOS>" #libre
#prompt = "me gustas cuando callas porque estás como ausente"
#prompt = "dame la mano y danzaremos"

if tipo_tokenizer == "tiktoken":
  generated = torch.tensor(tokenizer.encode(prompt, allowed_special="all")).unsqueeze(0)

if tipo_tokenizer == "preentrenado":
  generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)

generated = generated.to(device)

# %%
poem_stanza_model.eval()

TEMPERATURA = 0.1

### OPCION 1: SAMPLING CON TOP K Y TOP P
sample_outputs = poem_stanza_model.generate(
                                generated,
                                do_sample=True,
                                top_k=50,
                                max_length=80,
                                top_p=0.95,
                                num_return_sequences=100,
                                renormalize_logits = True
                                )

## OPCION 2: SAMPLING CON TEMPERATURA
# sample_outputs = poem_stanza_model.generate(
#                                 generated,
#                                 do_sample=True,
#                                 max_length=80,
#                                 top_k = 0,
#                                 num_return_sequences=100,
#                                 temperature=TEMPERATURA,
#                                 renormalize_logits = True
#                                 )



for i, sample_output in enumerate(sample_outputs):
    if tipo_tokenizer == "tiktoken":
      print("\n\nPoema Generado N° {}: \n\n {}\n\n".format(i, tokenizer.decode(sample_output.tolist())))
    if tipo_tokenizer == "preentrenado":
      print("\n\nPoema Generado N° {}: \n\n {}\n\n".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poema Generado N° 0:
#
#  no tuvieron mis padres
# cuyas vidas,
# no descansaron en flores
# ni en panales ni en nada
# sino en su sombra,
# su sombra extendida,
# su río de sonrisas.
#
# los ríos del sur o de la estrella
# se han cruzado en mi camino
# con la mía, la proa rota
# de la historia que me dieron.
# pero yo, la
#
#
#
#
# Poema Generado N° 1:
#
#  a nadie más que a ti te buscaron, querían
# devorarte los lobos, romper tu poderío,
# desampararte a mis puertas.
# cada uno quería ser gusano en tu muerte.
#
# ya no tienes nada que entregarme,
# ni tierra de tu flores sangrientas,
# ni cosechas de tu sangre;
# ni el amor ni el odio tienen
# ni tu grandeza, ni
#
#
#
#
# Poema Generado N° 2:
#
#  se ve una ciudad donde
# vivir y morir, y un día
# vengan a buscarla
#  las muchachas que
# con manos y gestos livianos
# bajan, se van a encontrar.
#
# y la misma noche se acuestan
# en la casa del patriarca.
#
# a la hora de clavo de marta
# vienen sus dos mil hombres
# y traen copas de mujer
#
#
#
#
# Poema Generado N° 3:
#
#  dejo a los sindicatos
# vestidos de rojo-escarlata,
# que, a lo lejos, cantan.
#
# estoy mirando. estoy oyendo
# el rumor de un mundo
# que otra vez se olvida y se muere.
# pero tal vez nada más hay
# que tal vez no haya sino noche,
# como dicen que deja caer los cerros
# y sólo en loco
#
#
#
#
# Poema Generado N° 4:
#
#  y en el altozano y en
# las quebradas, cuando ya las duermas,
# mece el labrador con cara de bandido.
#
# ¡qué dulce es en el semblante alhendo el día de tus cabellos,
# y es la marcha de los años un punto,
# como la raya del sol en el horizonte!
# ¿en qué labio bebe el mes de las mi
#
#
#
#
# Poema Generado N° 5:
#
#  en el sueño yo me despertaba
# y era ella la que venía,
# y era ella la que venía
# y era yo la que venía.
#
# y me reían los tres
# como quien oye un fuego,
# pero en cuanto me despiertan
# me dicen que me han herido.
# los tejados dicen "¡gracias!"
# y la alameda dicen "¡gracias!"
#
#
#
#
# Poema Generado N° 6:
#
#  en las paredes cuelgan las interrogaciones,
# florece en las bigornias el alma de los bronces
# y hay un temblor de pasos en los cuartos desiertos.
#
# y junto a las bigornias, revueltas,
# azules, amarillas y rosadas,
# el corazón humanotame y tejeré a la muerta,
# y así te nombro y te
#
#
#
#
# Poema Generado N° 7:
#
#  pero una vez más salta
# sucio de agua
# como un regato
# y, a trechos, suelta
# su duna
# que no da sombra ni sombra.
# y salta, y alcanza a las dunas
# con una piedra y una hoz,
# y con una hoz suelta
# a su hija, que es de ambrosía.
# y salta, y alcanza a
#
#
#
#
# Poema Generado N° 8:
#
#  cuando al alba de regreso
# la madre era interrogada,
# gea, jugando a dos mundos,
# ni levantaba la cara.
#
# y cuando se reían
# ella sonriendo callaba
# y a causa de su silencio
# sus hijos la fabulaban.
#
# cuando la noche dio su señal,
# el sol fue desmenuzando
# su ardida y muerta amapola.
#
#
#
#
# Poema Generado N° 9:
#
#  me gustas cuando callas y estás como distante.
# y me oyes desde lejos, y mi voz no te toca.
# como la lluvia en la noche
# de tus tejas estamos juntos,
# y el viento está en tus ojos,
# y el alma del valle se halla en tus brazos.
#
# como el pan en la horno
# y el pan en el colmado.
# te
#
#
#
#
# Poema Generado N° 10:
#
#  en la llanura del guayas
# la ceiba no se sabía
# la planta de montaña,
# y una niebla humana
# regía su espalda.
#
# y en el viento que olía a pesebres,
# la ceiba no se la veía
# ni al dorso de la ceiba.
# la ceiba no sabía
# que era de su reino,
# y la yerba no
#
#
#
#
# Poema Generado N° 11:
#
#  y suspiró por su lecho baldío,
# rezó llorando, y se sentó a mitad de la vida
# en el lecho que el dios no había sitio
# y en el que de semilla se quemaban
# carbón y rosales quemados.
#
# ruth vio en los astros los ojos con llanto
# de booz llamándola, y estremecida,
# dejó su lecho,
#
#
#
#
# Poema Generado N° 12:
#
#  la luz viva travesea
# a donaire y a donaire
# y a donaire se lleva
# el donaire y la alegría.
#
# el caín azul da la vuelta
# donde el mundo no da nada.
# el valle lo mece
# y el valle lo mece
# en niña parlía.
# canto ciego, les vamos a
# arrollar con la rueda
#
#
#
#
# Poema Generado N° 13:
#
#  en el fondo de ti la poesía
# vuelve en los rincones a dormir,
# y en el escondite en que no te han visto
# y caído tus compañeros, siguen viviendo.
#
# te quiero sólo porque me vas a escuchar,
# te odio sin fin, y odiándote con todas tus fuerzas,
# y el odio de los días muertos
# no te deja ir, te muerde los
#
#
#
#
# Poema Generado N° 14:
#
#  pero en las noches, cansada,
# al dormirme sonreía,
# porque bajabas al sueño
# hasta rozar mis mejillas.
#
# en el sueño yo me despertaba
# con el corazón entero a flor de pecho.
# ¡si dios quisiera volvérteme
# por un instante tan sólo!
# ¡si de mirarme tan pobre
# me devolviera tu rostro!
# el que me
#
#
#
#
# Poema Generado N° 15:
#
#  se envilecieron las mañanas,
# torpe se hizo el mediodía;
# torpe se hizo el mediodía;
# torpe se hizo el crepúsculo.
#
# cada día era
# más duro que el camino.
#
# los caballos eran comidos
# en aquella fiesta glacial.
#  los chiquillos
# dieron a la bestezuela
# la empolvada del cogollo...
# la
#
#
#
#
# Poema Generado N° 16:
#
#  en la mesa te tuvimos
# como alto jarro de plata.
# en el fogón escuchándote
# te dijimos "pecho de horno".
#
# en el fogón escuchándote
# te dijimos "pecho de horno".
# te tuvimos ya
# en el fogón escuchándote,
# en el fogón escuchándote.
# y ahora
# es parte de tu silencio
# que ya
#
#
#
#
# Poema Generado N° 17:
#
#  ya no la quiero, es cierto, pero cuánto la quise.
# mi voz buscaba el viento para tocar su oído.
#
# y su voz buscaba el viento para tocar su oído.
# mariposa, yo no la quiero. ella es la vida. no es lo que parece.
# mi voz buscaba el viento para tocar su oído.
# su voz buscaba el viento para tocar su
#
#
#
#
# Poema Generado N° 18:
#
#  pero de las greñas brotan raíces.
# del bosque que lo envuelve en leño y trinos,
# y sombras temblorosas que lo trepan,
# se arranca, y viene, y llega sin soslayo,
# porque lo trae mi rasgado grito.
#
# en lo que dura una noche,
# cuna de sol y más días,
# recién nacida, y otra vez sin
#
#
#
#
# Poema Generado N° 19:
#
#  por si no hay después encuentros
# en ninguna vía láctea,
# ni país donde devuelva
# tu piedad de blanco llama,
# en el hoyo que es sin párpado
# ni pupila, de la nada,
# oigas tú mis dobles gritos,
# y te alumbren con nuestras lámparas
# cuando tú te extravíes en las tinieblas.
#
# como tú me pusiste en
#
#
#
#
# Poema Generado N° 20:
#
#  pero hacia donde vaya llevaré tu mirada
# y hacia donde camines llevarás mi dolor.
# el dolor es una sola mano que te indica
# el aire, un rostro que va hacia el olvido
# y hacia donde camines llevarás mi dolor.
#
# quedarme aquí, como un árbol
# no sé qué camino tomar,
# zarpar entre raíces, cercar
# hay un río blanco
#
#
#
#
# Poema Generado N° 21:
#
#  te he visto, hermano, en el último año
# de lascias, y en todas
# las cosas que me aguardan.
# de ti rodamos hacia el
#  río
# y subiremos a su cuello.
#
# dicen que no envejeció
# ni en el rostro ni en la marcha,
# aunque envejecieron todos
# los que ella amamantara.
#
# así
#
#
#
#
# Poema Generado N° 22:
#
#  la noche ahora es fina,
# es estricta y delgada.
# el cielo agudo punza
# lo mismo que la daga
# y aguija a los dormidos
# la tensa vía láctea.
#
# ¿qué son, oh mar, mis ojos
# que no ven y se posan?
#
# oh sentina de escombros,
# oh sentina de escombros,
# oh sentina de
#
#
#
#
# Poema Generado N° 23:
#
#  de cuando en cuando se extraviensen
# los que amó y quiso y tuvo
# muro y bulto con sólo mirarlos
# en la noche se vieron
# cánseros dormidos o despiertos.
#
# en las noches, insomne de dicha y dolor,
# la lujuria de fuego no descendió a mi lecho.
# la lujuria de fuego no descendió a mi lecho.
#
#
#
#
#
# Poema Generado N° 24:
#
#  vuélvete, pues, huemulillo,
# y no te cuentes solo
# lo que te pasa con tu cuerpo:
# vuélvete, huemulillo,
# y no te cuentes solo
# lo que te pasa con tu cuerpo.
#
# el nombre de tu "compaña"
# guarda el recuerdo de tu rostro,
# que en tu máscara guarda
# la compostura
#
#
#
#
# Poema Generado N° 25:
#
#  me he despertado y me han dicho: "¡ahora, ya!"
# las gentes se preguntan: "ahora ya".
#
# yo les respondo: " ahora, ya."
# lealmente,
# no me siento solo desde que me dieron.
# soy mi corazón aconcagua y me angustia.
# pero tal vez mi padre que me reconoce
# no era aquel para cual
#
#
#
#
# Poema Generado N° 26:
#
#  por eso por tierra estamos
# con la tristeza de la manada,
# que trepó cuestas y encuentra
# *sólo nieve en las montañas.
#
# de día y de noche estamos en el bosque,
# el sol y el viento en la noche
# y cuando a su lado cavan briosamente,
# sus pieles de oso y de hinojos.
# sus piernas blancas como américa,
#
#
#
#
# Poema Generado N° 27:
#
#  y meciéndolas, meciéndolas,
# tal como él les da,
# mascamos algas quemadas
# vueltos a la lejanía,
# o mordemos nuestras manos
# igual que esclavos escitas.
#
# y cogidos de las manos,
# cuando la noche es venida,
# aullamos viejos y niños
# como unas almas perdidas:
# va el tiempo con nosotros,
# ja
#
#
#
#
# Poema Generado N° 28:
#
#  -tú lo quisieras vuelto un alarido,
# y nos olvidaste de tu nombre,
# y de tu nombre, y de tu sombra.
#
# -le oí decir a mi madre
# que la quería y plantaba
# y la bebía en tisana,
# le oí decir: "pechuga",
# y la pobre miguel la escuchaba
# bebía, y
#
#
#
#
# Poema Generado N° 29:
#
#  mi deseo de ti fue el más terrible y corto,
# el más revuelto y ebrio, el más tirante y ávido.
#
# caminé sin descanso
# trayéndome al costado
# y sin fatiga, de no ver más
# tierra de pájaros y de huertas.
# supe al mirar que no iba a morir,
# que en la próxima vida yo no velaría
#
#
#
#
#
# Poema Generado N° 30:
#
#  ¡esta roja flor la dan
# en la noche de san juan!
#
# yo te enciendo, tú me llevas;
# yo te celo y te mantengo.
# por donde las piedras se hunden,
# los ríos se deshacen;
# llenos de ojos están y de mirada;
# ¡y en el alba de amor que ardía
# como un árbol de romero,
#
#
#
#
# Poema Generado N° 31:
#
#  se puede viajar, se puede
# morir, se puede.
#
# se puede ser, pero no se puede
# morir, se puede, sí, y nunca
# se puede.
# se puede, se puede ser sin que nada nos turbe.
# se puede ser sin que nadie nos llame,
# sin que nadie nos llame,
# y se puede, si no lo decimos
#
#
#
#
# Poema Generado N° 32:
#
#  en el sueño yo te hacía señas
# y yo te miraba, tú me mirabas
# y yo te miraba sin soslayo.
#
# la casa y el jardín callaban,
# de un día para otro
# y para el otro día tú te mirabas
# y yo te miraba y te miraba
# y te oía y te lamías.
# ¡si dios quisiera volvérteme
# por
#
#
#
#
# Poema Generado N° 33:
#
#  pero ya se acabaron las noches
# del verano en las minas,
# y a la mañana ya ni dura
# nunca se acuerda de nada,
# y a la noche se va entera
# de su consolación y con lamento.
#
# llegamos a la patagonia,
# alpande, al río;
# a las dichas de chile
# viene el amargo verano.
#
#
#
#
#
# Poema Generado N° 34:
#
#  yo me olvidé que se murió el mar.
#
# pero en su semblante se iban a encontrar
# los míos: mi amigo
# mordiendo la tierra,
# su sonrisa, un poco loca;
# (así con el susto de vivir
# y la angustia de ver un día
# que morir).
#
# mis pobres muertos miran el sol de ocaso
# y yo me niego a la eternidad.
#
#
#
#
# Poema Generado N° 35:
#
#  las calles se llenan de puertas
# y los umbrales se llenan de pasos
# y de voces sin número:
# lágrimas, ansias, miedos,
# como de bestia salvaje,
# y hay un tumulto de risas,
# como de cascada llena de huesos.
#
# las grandes casas dejan
# vírgenes las cosas divinas:
# ladres y hijos descansan
# bajo las calles, las
#
#
#
#
# Poema Generado N° 36:
#
#  yo no soy fea, que si fuese fea,
# fea es mi madre parecida al sol,
# fea la luz en que mira mi madre
# y feo el viento en que pone su voz,
# y fea el agua en que cae su cuerpo
# y feo el mundo y el que lo crió...
#
# pero estos ojos que me ven no ven
# el fondo de este valle
#
#
#
#
# Poema Generado N° 37:
#
#  en el filo del día y el solsticio
# baila riendo su cabal despojo.
# cae la noche y el solsticio
# y me cae al costado
# la lluvia y el día y el viento.
#
# lo dejé, como una fruta
# , al cesto de la ropa,
# despedazada de légamo,
# y me quedé sin pan ni provisiones
# hasta
#
#
#
#
# Poema Generado N° 38:
#
#  -oye, por qué a veces, vos
# calláis, mi mama-fantasma,
# y parece..., sí, parece
# que contra alguno porfiaras.
# yo no veo a nadie, pero
# es como que a alguien hablaras.
#
# -no más, no cortes, no más.
# ¿cómo se llama usted?
# son sus nombre los
#
#
#
#
# Poema Generado N° 39:
#
#  la ronda que más nos gusta
# es la de las manzanillas:
# isla, porque de cantar
# baila bailes de su tiempo;
# suelta, yá, yá, yá.
#
# se desparraman en grupos
# como estrellas o animales;
# y de nuevo se rehace
# la ronda de palmas reales...
# y más, se alejan
#
#
#
#
#
# Poema Generado N° 40:
#
#  y como en vuestros corazones, madres,
# hay en mi corazón tantas cosas
# que parece una selva
# mojada por la sangre de los hombres.
#
# y aunque es la hora de partir, las madreperlas
# vienen de la puerta,
# tranquila como la lluvia,
# tranquila como el mar,
# tranquila como el tiempo.
# ¿por qué la madreper
#
#
#
#
# Poema Generado N° 41:
#
#  no la alcanzan los ganados
# ni le llega la saeta.
# miedo de ella tiene el hacha
# y las llamas no la queman.
#
# pero al llegar la noche cuenta
# "su muerte",
# su muerte hace más suave
# el papel de lirio.
# cuando se abre la puerta
# ¡y se va en un rayo
# de fuego el cuerpo de la pobre madre
#
#
#
#
# Poema Generado N° 42:
#
#  y tanto el azul crecía
# que se volvía mañana
# y todo el azul del mundo
# sólo ella lo pastoreaba.
#
# las muchachas cantamos la hierba:
# sólo ella lo sabía
# y sólo él lo sabía
# y lo decía por lo bajo.
# vuela la sombra de madreselva
# vuela pez, hierba que corre
# y él va rompiendo pétalos.
#
#
#
#
#
# Poema Generado N° 43:
#
#  el toro negro de astassippi
# me miró con la intensidad del astros,
# y luego me mordió con su silbo;
# y al mirarme tan hermosa
# me dejó la belleza mudada,
# y entonces fui yo la que en los pechos semecieron.
#
# y cuando te vi vagar en el agua
# como el pez que no es un río,
# me perdí en
#
#
#
#
# Poema Generado N° 44:
#
#  en la pampa va cruzando
# la grosura de las reses
# y la ronda blanca parte
# negruras y bermejeces.
# y con el viento pampero
# a más canta más se crece
#
# llegando a la patagonia,
# de avestruces emblanquece,
# y pescamos en las islas
# los que son últimos peces.
#
#
#
#
#
# Poema Generado N° 45:
#
#  en la estepa inmensa,
# en la estepa yerta
# de desolación,
# ¡mi corro de niñas
# como inmensa flor!
#
# sobre los caballos, en el viento
# como una larga lanza,
# vienes volando.
# otros olores no hay en la estepa
# y se confunden, no hay nadie,
# y sigue cayendo la noche
# en la estepa yerta
#
#
#
#
#
# Poema Generado N° 46:
#
#  en donde quedó su garfio
# donde lo dejaron,
# lo dejaron como a niño
# y lo cargaron como a ángel
# y cantaron al dios del mar.
#
# a cada verano tejen
# linos frescos como el agua.
# soy un río. he aquí
# el remanso del mar. no un río.
# ven conmigo. dilo.
# todavía
#
#
#
#
# Poema Generado N° 47:
#
#  ¡tan entero que era el mar!
#
# los negros tumbadores
# de reyes
# perdones le bailan
# perdón, perdón.
# la luna llena va cayendo
# sobre el mayab.
# ¡bendito el dios que ha herido
# a su hermana, la piel ensangrentada!
# ¡bendito el dios que ha herido
# a su hermana, la piel
#
#
#
#
# Poema Generado N° 48:
#
#  ya las trampas le conozco
# de redondear la cerco
# y hacer "la gallina ciega"
# con el pastor o el arriero.
# no tiene todavía
# la mar de su silencio,
# no tiene
# la que salva y consuela.
# una mañana
# con su celeste y el azul
# de su ángel
# ella se muda
# con el ángel negro
# con el pez luna de
#
#
#
#
# Poema Generado N° 49:
#
#  tepito-te-henúa, ombligo del mar
# oh rey de los judíos:
# te-henúa te miró con sus ojos
# oh rey de los judíos.
#
# pero ahora es el único
# al que no se le ha hecho
# mar. di: "ahora se puede matar".
# el hombre sabio y desdeñoso
# me mira con la indiferencia
# de los camellos
#
#
#
#
# Poema Generado N° 50:
#
#  lo que corre de mi frente
# a mis pies calenturientos;
# ¡esta calentura de mi cuerpo
# ya no volteo, ya no me sosiega!
#
# ¡ah! nunca más tus dos iris cegados
# tendrán un rostro descompuesto, rojo
# de lascivia, en sus vidrios dibujado!
# no quiero, no quiero, no quiero,
# nacer
#
#
#
#
# Poema Generado N° 51:
#
#  hay que darse un baño de tumba
# y desde la tierra cerrada
# mirar hacia arriba el orgullo.
#
# hay que darse un baño de tumba
# y desde el mar abierto
# mirar hacia arriba el orgullo.
# y a trechos se llega al fondo de la patria.
# hay que darse un baño de tumba
# para que todo se vuelva negro.
# en todo mundo la
#
#
#
#
# Poema Generado N° 52:
#
#  así, en las tierras de picasso de sur a oeste,
# volando y levantando
# cosas rotas,
# tal vez por eso,
# si tú me miras, estoy viendo.
# y oigo que otras hablan.
# pero yo bien te miro,
# siempre fuiste el más
# antiguo
# recocido
# de la tierra.
#
# así es la vida,
# pero en
#
#
#
#
# Poema Generado N° 53:
#
#  yo fui reconociendo las marcas que temblaron
# en la desembocadura del agua en que nací.
# soy esta espiral, esta liana, y este ruedo, y esta liana.
#
# pienso, pues, en esa liana, que mi sed ha invadido.
# yo no soy un vino, pero tal vez soy un hombre.
# el vino no es un caballo
#
#
#
#
# Poema Generado N° 54:
#
#  y la bisoja iba abriendo
# la noche como a tajadas,
# y la procesión seguía
# por sus quiebros y sus abras.
#
# y la procesión seguía
# por sus quiebros y sus abras;
# pero la cruz seguía
# y la procesión seguía
# por sus quiebros y sus abras.
# entraron con ella los hombres
# en su colma
#
#
#
#
# Poema Generado N° 55:
#
#  la noche ensanchó su charco
# de betún; y como se quemara
# o pagara la sed,
# cuchillos, velorios y velorios
# fueron a su puerta los últimos ladrones,
# y entró el mundo negro a darlo
# en una celda con un jarro de agua,
# y una cruz de espinas negras
# fue a sentarse a su izquierda,
#
#
#
#
#
# Poema Generado N° 56:
#
#  ¡ah! nunca más conocerán tus brazos
# el nudo horrible que en mis días puso
# oscuro horror: ¡el nudo de otro abrazo!
#
# ¡niña la hierba, venteada
# por el espíritu del viejo!
# ¡niña la hierba, venteada
# por el espíritu de tu hijo!
# viva está toda la noche
# de negaciones y
#
#
#
#
# Poema Generado N° 57:
#
#  no se equivocaron. me decían: —no estoy herido.
# yo no te sabía. te querían.
#
# yo te amaba y temía;
# y al verte me sonreía.
# ahora que te falta el aliento,
# te muerdes de sueño y de habla.
#
# me vendió el que besó mi mejilla;
#  me negó por la túnica ruin.
# ¡y a
#
#
#
#
# Poema Generado N° 58:
#
#  me paro y escucho,
# sin ir a buscarla:
# ¡agua, madre mía,
# e hija mía, el agua!
#
# debajo de la cama,
# la madre sobre mi pecho
# y mi hijo dormido.
# al umbral,
# la madre que miró mi hora
# y tuvo el mismo asombro,
# se llevó mi cara...
# he aquí mi madre que vio
#
#
#
#
# Poema Generado N° 59:
#
#  pero yo, mi señor, te arguyo que he tocado,
# de la misma manera que el nardo de su frente,
# todo su corazón dulce y atormentado
# ¡y tenía la seda del capullo naciente!
#
# ¡tenía una vergüenza
# de vivir de este modo cobarde!
# ¡tenía una vergüenza
# de vivir de este modo cobarde!
# ¿por qué, señor, me
#
#
#
#
# Poema Generado N° 60:
#
#  no te oiga de dormido
# el alma de jesucristo,
# ni te odie ni te revuele,
# porque al alma le rendida
# vive de ti como de un viejo vino.
#
# dormido irás creciendo,
# y creciendo hasta llegar al alma,
# como el árbol de alepo,
# igual que el retama de una locomotora,
# como el mel
#
#
#
#
# Poema Generado N° 61:
#
#  y meciéndolas meciéndolas,
# tal como él se les mecía,
# mascamos algas quemadas
# vueltos a la lejanía,
# o mordemos nuestras manos
# igual que esclavos escitas.
#
# arañaremos nuestra piel
# en el lecho de cal con vistas,
# cuando nuestra piel sea tierna
# y haga florecer el florentino.
# y dado que
#
#
#
#
# Poema Generado N° 62:
#
#  detrás de su totoral
# o carrizal, viva y burlesca,
# existía sin mirarnos
# como quien burla y quien husmea
# sabiendo todo de nosotros,
# pero sin darnos respuesta...
#
# sosegó el aletazo,
# se dobló, lacia,
# y me cayó a la mano
# su pavesa acabada...
# y sin mirarse
#
#
#
#
# Poema Generado N° 63:
#
#  -mama, ríes como loca,
# ¿cómo es que no hay otro?
# son gajos de flores rústicas
# que tú me escoges trocadas;
# pero estos pastos son migajas
# que tú me escoges trocadas.
#
# -te pones tonta tú, dámelas.
# ¿no ves que cuesta atraparlas?
# son gajos de flores
#
#
#
#
# Poema Generado N° 64:
#
#  -¿y cómo se llama? -fue la primera palabra.
#
# -skip. ¿es tú? -aquella noche en que te conmigo
# fue tan grande el amor.
# yo te interrogo, mi loco loco,
# cómo se llama usted, cómo se llama.
# ¡qué importa que yo nos odie, mi loco!
# no digas eso, mi
#
#
#
#
# Poema Generado N° 65:
#
#  -mama, ¿por qué no me dejas
# aquí, por si habla conmigo?
#
# yo te sigo y te sigo
# por el mundo que no mece.
# pero dime, ¿es por mí?
# a las de arriba, a las madrastras,
# les pones el gesto
# de aguardar que les vuelva el alma.
# déjame sueltas las manos
#
#
#
#
#
# Poema Generado N° 66:
#
#  yo no sé si es mejor fruta que pan
# y es el vino mejor que la leche en tu mesa.
#
# es la noche desamparo
# en que los hombres se extravían
# y la sierva no se acordaría.
# pero yo, mi señor, te digo
# con fría voz a la sierva,
# con la que te interrogo,
# con el que no sabes
#
#
#
#
# Poema Generado N° 67:
#
#  -pero si no es más que pasto,
# mama. ¿por qué la acaricias?
#
# -le oí decir a mi madre
# que la quería y plantaba
# y la bebía en tisana,
# le oí decir que alivia
# el corazón, y eran ciertas
# las cosas que ella nos contaba.
# yo le oí decir a mi madre
# que alivia
#
#
#
#
# Poema Generado N° 68:
#
#  la luz del valle central
# es la que nos da ardimiento,
# hace ver el maizal
# en muchachada que danza
# y las melgas de frijoles
# son un baile de muchachas.
#
# hace tanto que masco tinieblas,
# que la dicha no sé reaprender;
# tanto tiempo que piso las lavas
# que olvidaron vell
#
#
#
#
# Poema Generado N° 69:
#
#  alguien vendría, sopla desde las llanuras,
# que la giran en el cielo y la dejan
# bajo las estrellas las dos sangres.
#
# así llega la luz,
# corre vestida con un bocillo
# y un gabán negro de hombre
# y un cinturón de metal
# amarillo,
# y un cinturón de metal
# amarillo,
# y unos ojos azulencos
#
#
#
#
#
# Poema Generado N° 70:
#
#  hay dos estrellas caídas
# a espinales y arenal;
# nos las contaron por muertas
# en cada piedra de umbral.
# el canto que les ardía
# nunca dejó de llamar,
# y a más andamos, más crecen
# como el padre aldebarán.
#
# hay dos puntos cardinales:
# son montegrande y el mayab.
# y los dos puntos car
#
#
#
#
# Poema Generado N° 71:
#
#  de noche y agua está mi boca llena.
# la duradera luna determina
# lo que no tengo.
#
# desvíen el agua de mi cuerpo.
# la duradera luna determina
# lo que no tengo.
#
# lo que tengo está en la mano,
# en mi cintura, en mi costado.
# cuitada, me muero de hambre.
# veo el verano extenso
#
#
#
#
# Poema Generado N° 72:
#
#  como iba contando y contando,
# de incredulidad, la madre granada,
# estallaron en risa los hijos
# y ella se partió de la carcajada...
#
# la granada se levantó de rueda
# y con una terrible salomón,
# la cortamos guardando supía,
# y la danzamos dos veces
# como tres o cuatro locas...
# la cortamos guardando supía.
#
#
#
#
#
# Poema Generado N° 73:
#
#  en el testuz de la sierra
# donde rebrillan las amargas
# maderas, secas y tiernas,
# todas íbamos a ser reinas,
# y de verídico reinar:
# sólo el valle central de la sierra
# y el río de mieles...
#
# en el testuz de la sierra
# nos callamos, y a la noche
# la
#
#
#
#
# Poema Generado N° 74:
#
#  si pudiera llenar de hollín las alcaldías
# y, sollozando, derribar relojes,
# sería para ver cuándo a tu casa
# llega la noche de las rosas.
# en cuanto al corazón, que era como una campana
# cerrada a la tierra,
# en lo ciego se volvía todo.
#
# todo lo que tú amas, todo lo que yo amas,
# se vuelve metal
#
#
#
#
# Poema Generado N° 75:
#
#  hablo de cosas que existen, dios me libre
# de inventar cosas cuando estoy cantando!
# hablo de la saliva derramada en los muros,
# hablo del coro de los hombres del vino
# golpeando el ataúd con un hueso de pájaro.
# si lloro de este modo interminable,
# de este modo interminable,
# iré por las calles cantando.
#
# estoy en
#
#
#
#
# Poema Generado N° 76:
#
#  de los cuatro reinos, decíamos,
# indudables como el korán,
# que por grandes y por cabales
# alcanzarían hasta el mar.
#
# regresamos, al fin, al amanecer
# y al alba, a la hora del clavo ardiendo,
# las vestiduras y las manos,
# las vistió de celeste y de rosado
# para que se pusieran a bailar
#
#
#
#
# Poema Generado N° 77:
#
#  y así te pintan los cerros
# como al mismo dios los tragas,
# y te anudan los cerros
# como cantaste
# o te suban mi entraña.
#
# me la topé como a la gracia,
# la cabeza más baja que la cabeza,
# y el seno más apretado.
# ahora ya puedo dormirme
# con tu verdor perdido,
#
#
#
#
# Poema Generado N° 78:
#
#  mi infancia allí mana leche
# de cada rama que quiebro
# y de mi cara se acuerdan
# salvia con el romero
# y vuelven sus ojos dulces
# como con entendimiento
# y yo me duermo embriagada
# en sus nudos y entreveros.
#
# soñando vive la madre granada,
# la tierra dura y dura,
# el mar sin tajada,
# la tierra
#
#
#
#
# Poema Generado N° 79:
#
#  escribir, por ejemplo: "la noche está estrellada,
# y tiritan, azules, los astros, a lo lejos".
#
# oir, lenta, en la noche, las corola blanca,
# y temblar, y rehuir, y ser, en la noche,vivas.
# todavía somos los que fuimos,
# acumulados en noche nuestra
#
#
#
#
# Poema Generado N° 80:
#
#  no ha bajado el topo del bosque.
# está inclinado; está gesteando.
# ¿qué será? será un helecho mojado.
#
# -no te entiendo, di!
#
# -a lo mejor te da miedo, a lo mejor.
# te da miedo el frío,
# te da miedo el fuego,
# te da miedo el fuego.
# dame ese nombre.
#
#
#
#
#
# Poema Generado N° 81:
#
#  de aquel hoyo salió de pronto,
# con esa carne de elegía;
# salió tanteando y gateando
# y apenas se la distinguía.
#
# se le iban a la zaga
# la carne en vellón que se retuerce
# y se rezaga en el viento;
# ella su bestiecita dentro
# deluce de fuego su cintura.
# y
#
#
#
#
# Poema Generado N° 82:
#
#  de noche y agua está mi boca llena.
# la duradera luna determina
# lo que no tengo.
#
# todavía, como en una rueda,
# lo que soy: lo que soy.
#
# lo que soy, lo que soy, lo que soy,
# no sé qué soy, y no me sé
# este metal de lo que soy,
# no sé si es verdad o
#
#
#
#
# Poema Generado N° 83:
#
#  de vientos, lluvia y viento van tejiendo
# su pámpano de sal y su pámpano de cuento.
# y en el amanecer la humedad los cubre,
# y en el amanecer la siesta los cubre.
#
# la luz azul del día grande
# es la que nos da ardimiento:
# en la pradera inmensa se abre el cielo.
# los corzos responden y se
#
#
#
#
# Poema Generado N° 84:
#
#  ¿o tú llegas después que los hombres han muerto,
# y les bajas el párpado sobre el ojo cegado,
# acomodas las vísceras sin dolor y sin ruido
# y entrecruzas las manos sobre el pecho callado?
#
# yo que la cuento ignoro sus caminos,
# ni el río de su nombre sube a mis hombros,
# sino el río de mi vida emp
#
#
#
#
# Poema Generado N° 85:
#
#  la mayor caricia
# que recibe el mundo,
# abrazo el más vivo,
# beso el más profundo.
#
# beso el más profundo.
# beso el más profundo.
# la mayor caricia
# que recibe el mundo,
# abrazo el más profundo.
# y el más profundo, el más profundo,
# beso el más profundo.
# ¡cristo
#
#
#
#
# Poema Generado N° 86:
#
#  es el beso ardiente
# de una canción:
# la de anacreonte
# o de salomón.
#
# mentira es nuestra,
# pero probamos
# algo
# que no es amor,
# nombrándola con el amor.
# y ahora es más suave
# como el nardo de las rosas.
# vamos a bailar con él,
# como cada día,
#
#
#
#
# Poema Generado N° 87:
#
#  de noche y agua está mi boca llena.
# la duradera luna determina
# lo que no tengo.
#
# el agua, en mi copa, me llega
# al pecho como una copa goteada.
# la duradera luna determina
# lo que no tengo.
# ay, agua, aguas,
# si solamente son cenizas
# hacia una y otra orilla del mar,
# con un peso muerto
#
#
#
#
# Poema Generado N° 88:
#
#  como un despeño de aguas,
# volando en una ola
# con un rasgado alarido,
# la costa se nosuca
# y cae y cae a mis brazos
# una ola negra y blanca.
#
# en medio de ese espanto,
# entre una nueva vida y los soles,
# un nuevo vuelo nos lleva a mi pueblo.
# aquí estoy con el rostro manchado
# de tierra
#
#
#
#
# Poema Generado N° 89:
#
#  yo no sé si son veras
# o no son las que te cuento,
# pero yo tengo mi cara
# y ella tiene mi cara.
#
# -ya entendí ¡qué cara fea!
# ahora estoy dándote a oler
# este romero de españa,
# al que llaman de castilla.
# ¿es que era cosa tan rara?
# es que yo quiero más
#
#
#
#
#
# Poema Generado N° 90:
#
#  no quiero que me den la mano
# porque ya la conozco, no,
# que me den la mano
# por que me den la mano
# y ella se la haya abandonado
# por que no nos atajen
# así con la encía.
#
# quiero que, sentados todos
# sobre la alfalfa o el trébol,
# según el clan y el anillo
# de los
#
#
#
#
# Poema Generado N° 91:
#
#  el mayoral de los andes
# nos mira empinado el ceño
# -blanca el ansia, blanco el logro
# y los escondidos fuegos.
# con alburas paternea
# y nos toma y salva
# sobre las que son tuyas.
# el corro se va cerrando
# y el asombro se aplaca
# y los ojos vanhariendo
# de nuestro ¡corazón! mayoral
#
#
#
#
# Poema Generado N° 92:
#
#  te voy a contar la hierba poco a poco.
# cuánta nieve, cuánta
# vas a ver,cuánta sombra de sol que se desplaza.
#
# esta niebla tiene pliegues de sal y espuma.
# es crinada, pero se nota su peso.
# mira las piedras de arauco.
# no hay nadie. mira los muros.
# escucha el viento que se aleja
#
#
#
#
# Poema Generado N° 93:
#
#  ya todo lo que falta será azul,
#
# lo que ya necesita es florecer.
# con una piedra, unas hojas,
# y con unas manos
# jasrió el mar.
# toda su poesía
# tiene un color de metal:
# es al final del día
# y antes de la noche
# cantar es la siesta.
#
# la luna de cristalino mareaba
# la
#
#
#
#
# Poema Generado N° 94:
#
#  pero un hilo tibio retuve,
# -pobre mujer- en la boca,
# vilano que iba y venía
# por la nonada del soplo,
# no más que un hilo de araña
# o que un repunte de arenas.
#
# ella se iba, la niebla,
# rompiendo un corro de niñas
# por el césped mojado.
# pero yo, la que
#
#
#
#
# Poema Generado N° 95:
#
#  no es así, las estatuas son lo que fuimos, somos
# nosotros, nuestra frente que miraba las olas,
# nuestra materia que nos enseñó el abismo.
#
# de pronto, un sonido sube de los riscos.
# se oye un ruido de estrellas, se oyen unos pasos en la costa.
# se oyen sonar telaresas.
# se oyen trillas, se oyen
#
#
#
#
# Poema Generado N° 96:
#
#  cuando empezamos a andar
# tú no tenías "compaña"
# ni para la noche ciega
# ni las rutas escarchadas.
# ya miraste, ya aprendiste
# cómo se siembra y se planta,
# cómo se riega el durazno
# y la sequía se mata,
# y se ahuyenta la peste
# hasta que la peste acaba.
#
# vamos huyéndonos por ella,
#
#
#
#
# Poema Generado N° 97:
#
#  esta flor es la que dan
# en la noche de san juan.
#
# flor en tierra no sembrada,
# flor sin árbol, flor sin riego,
# el tu amor está en la tierra
# y el tu tallo está en los cielos.
# flor en tierra no sembrada,
# el tu tallo está en los cielos.
# esta flor cortan y dan
# en
#
#
#
#
# Poema Generado N° 98:
#
#  dejaron una promesa.
# despertaron todo el vallecillo.
# sus caminos se encontraron,
# despertaron toda la pradera.
#
# hoy, este abierto mediodía vuela
# con todas las abejas de la luz:
# es una sola copa la distancia,
# al territorio claro de mi vida.
# y pasa un mes con mi mujer.
# no queda en mí sino un pé
#
#
#
#
# Poema Generado N° 99:
#
#  -cuando ya calle la tenca
# sigues tú. yo la sigo
# como quien pierde huertos.
# pero ahora le oigo
# y sé que habla solo.
#
# -¿tú te sabes el camino
# mama? ¿es cierto?
# ¿es cierto? ¿es cierto?
# sigues sin saber de nada.
# sigues sin saber de nada.
#
# no

# %% [markdown]
# **Guardar Poemas**

# %%
generated_poems = []

for i, sample_output in enumerate(sample_outputs):
  if tipo_tokenizer == "tiktoken":
            generated_poems.append(tokenizer.decode(sample_output.tolist()))
  else:
            generated_poems.append(tokenizer.decode(sample_output, skip_special_tokens=True))

output_file_path = f'ModeloB_prompt_libre_T_{int(TEMPERATURA*100)}.txt'

with open(output_file_path, 'w', encoding='utf-8') as file:
    for poem in generated_poems:
        file.write(poem + '\n\n\n')

print(f"Generated outputs are saved to: {output_file_path}")
# Out:
# Generated outputs are saved to: ModeloB_prompt_libre_T_100.txt

# %% [markdown]
# **Nube de palabras**

# %%
archivo_path = f'ModeloB_prompt_libre_T_{int(TEMPERATURA*100)}.txt'

with open(archivo_path, 'r', encoding='utf-8') as file:
    contenido = file.read()

wordcloud = WordCloud(width=800, height=400, background_color="white", stopwords = stopwords_espanol).generate(contenido)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# **Creatividad**

# %%
creatividad_altaT = evaluate_creativity(poem_stanza_model, tokenizer, poemas, temperatura = 1.0, num_context_inputs=100)
creatividad_bajaT = evaluate_creativity(poem_stanza_model, tokenizer, poemas, temperatura = 0.1, num_context_inputs=100)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 0
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 1
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 2
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 3
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 4
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 5
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 6
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 7
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 8
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 9
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 10
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 11
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 12
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 13
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 14
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 15
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 16
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 17
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 18
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 19
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 20
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 21
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 22
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 23
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 24
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 25
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 26
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 27
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 28
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 29
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 30
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 31
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 32
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 33
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 34
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 35
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 36
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 37
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 38
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 39
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 40
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 41
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 42
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 43
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 44
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 45
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 46
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 47
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 48
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 49
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 50
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 51
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 52
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 53
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 54
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 55
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 56
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 57
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 58
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 59
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 60
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 61
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 62
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 63
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 64
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 65
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 66
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 67
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 68
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 69
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 70
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 71
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 72
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 73
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 74
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 75
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 76
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 77
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 78
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 79
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 80
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 81
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 82
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 83
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 84
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 85
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 86
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 87
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 88
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 89
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 90
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 91
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 92
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 93
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 94
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 95
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 96
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 97
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 98
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 99
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 0
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 1
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 2
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 3
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 4
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 5
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 6
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 7
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 8
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 9
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 10
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 11
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 12
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 13
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 14
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 15
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 16
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 17
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 18
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 19
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 20
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 21
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 22
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 23
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 24
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 25
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 26
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 27
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 28
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 29
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 30
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 31
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 32
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 33
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 34
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 35
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 36
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 37
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 38
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 39
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 40
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 41
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 42
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 43
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 44
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 45
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 46
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 47
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 48
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 49
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 50
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 51
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 52
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 53
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 54
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 55
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 56
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 57
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 58
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 59
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 60
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 61
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 62
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 63
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 64
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 65
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 66
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 67
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 68
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 69
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 70
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 71
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 72
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 73
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 74
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 75
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 76
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 77
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 78
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 79
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 80
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 81
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 82
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 83
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 84
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 85
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 86
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 87
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 88
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 89
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 90
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 91
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 92
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 93
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 94
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 95
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 96
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 97
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 98
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 99

# %%
print(f"El puntaje de creatividad del modelo con alta T es: {np.round(creatividad_altaT, 2)}")
print(f"El puntaje de creatividad del modelo con baja T es: {np.round(creatividad_bajaT, 2)}")
# Out:
# El puntaje de creatividad del modelo con alta T es: 0.65
# El puntaje de creatividad del modelo con baja T es: 0.38

# %% [markdown]
# #7.C. Entrenamiento sólo GPT2 con GPT2 preentrenado de Hugging Face

# %%
''' ¿Qué tokenizador usar? '''

tipo_tokenizer = "preentrenado"
#tipo_tokenizer = "tiktoken"

''' ¿SP-GPT2 o sólo GPT2? '''
sp_gpt2 = False

# %%
#OBTENER MODELO PREENTRENADO
model_name = "datificate/gpt2-small-spanish"
configuration = GPT2Config(vocab_size=vocab_size, n_positions=MAX_LEN).from_pretrained(model_name, output_hidden_states=True)
model_sologpt = GPT2LMHeadModel.from_pretrained(model_name, config=configuration)
model_sologpt.resize_token_embeddings(vocab_size)

#MODELO LSTM
head_gpt = SelfAttentionLstm(input_size=768,hidden_size=256, num_layers=1,n_head=2)
for param in head_gpt.parameters():
    param.require_grad = True

# %%
batch_size = 8

train_dataloader = DataLoader(dataset_train,
                              sampler=RandomSampler(dataset_train),
                              batch_size=batch_size)
valid_dataloader = DataLoader(dataset_valid,
                              sampler=RandomSampler(dataset_valid),
                              batch_size=batch_size)

# %%
# hyperparameters
learning_rate = 1e-4
eps = 1e-8
warmup_steps = 50
device = torch.device('cuda')
epocas=10
optimizer = torch.optim.AdamW(model_sologpt.parameters(), lr=learning_rate, eps=eps)
criterion = nn.CrossEntropyLoss().to(device)
total_steps = len(train_dataloader) * epocas
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps=warmup_steps,
                                            num_training_steps=total_steps)

# create text generation seed prompt
prompt = "<BOS>"

if tipo_tokenizer == "tiktoken":
  generated = torch.tensor(tokenizer.encode(prompt, allowed_special="all")).unsqueeze(0)

if tipo_tokenizer == "preentrenado":
  generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)

generated = generated.to(device)

# %%
model_sologpt,  train_loss_C, valid_loss_C = entrenar_red(model_sologpt,
                                                          head_gpt,
                                                          tokenizer,
                                                          train_dataloader,
                                                          valid_dataloader,
                                                          newline_token_id,
                                                          device,
                                                          criterion,
                                                          optimizer,
                                                          scheduler,
                                                          epocas,
                                                          tipo_tokenizer = tipo_tokenizer,
                                                          sp_gpt2 = sp_gpt2)
# Out:
# Epoch: 01 | Epoch Time: 2m 43s
# 	Train Loss: 4.473, LSTM loss: 0.000
# 	 Test. Loss: 4.010, LSTM loss: 0.000
# Epoch: 02 | Epoch Time: 2m 39s
# 	Train Loss: 3.844, LSTM loss: 0.000
# 	 Test. Loss: 3.751, LSTM loss: 0.000
# Epoch: 03 | Epoch Time: 2m 37s
# 	Train Loss: 3.475, LSTM loss: 0.000
# 	 Test. Loss: 3.620, LSTM loss: 0.000
# Epoch: 04 | Epoch Time: 2m 38s
# 	Train Loss: 3.165, LSTM loss: 0.000
# 	 Test. Loss: 3.467, LSTM loss: 0.000
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Epoch: 05 | Epoch Time: 2m 38s
# 	Train Loss: 2.882, LSTM loss: 0.000
# 	 Test. Loss: 3.356, LSTM loss: 0.000
#
#
# Poema Generado N° 0:
#  y a las madres, a las hijas,
# a las pobres, al mendigas
# a los huérfanos,
# a las madres muertas,
# a los mendigos sin nombre,
# a los ciegos,
# al comer pan sin nombre
# de los muertos sin rostro,
# a la sed de los hambrientos.
#
# no sé, pero parece que me duermo
# como un fantasma de dos años,
# un día dormido y sin rostro,
# un día sin luz
# y una noche sin sueño.otros, sí, que son
# mi vieja noche,
# mi pobre noche, mi pobre noche.otros, que son
# mi pobre noche.otros, que son
# mi pobre noche,
# la pobre
#
#
# Epoch: 06 | Epoch Time: 2m 38s
# 	Train Loss: 2.640, LSTM loss: 0.000
# 	 Test. Loss: 3.272, LSTM loss: 0.000
# Epoch: 07 | Epoch Time: 2m 38s
# 	Train Loss: 2.436, LSTM loss: 0.000
# 	 Test. Loss: 3.198, LSTM loss: 0.000
# Epoch: 08 | Epoch Time: 2m 38s
# 	Train Loss: 2.279, LSTM loss: 0.000
# 	 Test. Loss: 3.163, LSTM loss: 0.000
# Epoch: 09 | Epoch Time: 2m 38s
# 	Train Loss: 2.161, LSTM loss: 0.000
# 	 Test. Loss: 3.102, LSTM loss: 0.000
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Epoch: 10 | Epoch Time: 2m 38s
# 	Train Loss: 2.081, LSTM loss: 0.000
# 	 Test. Loss: 3.104, LSTM loss: 0.000
#
#
# Poema Generado N° 0:
#  no quiero que te llamen,
# ni en mi lengua, por nombre,
# ni en mi lengua mía,
# ni en el cilicio
# ni en el canto:
# por ser mi madre, mi hermano.
#
# en la siesta, lamiendo
# la gaviota, mi hijo,
# por siervas y por sierra
# mi prestado prestado y fiel.vedad de oír,
# de oír
# la sal y de ser fiel.vedad de ser
# con tu bien que te diera y tu prestado
# y el grito de tus hermanos.vedad de ser con tus amigos
# y tu hermano.vedad de ser con tu hermana
# y el cantar de tus hermanos.vedad del

# %%
plot_losses(train_loss_C, valid_loss_C)

# %%
##Experimentar con diferentes prompt

prompt = "<BOS>" #libre

if tipo_tokenizer == "tiktoken":
  generated = torch.tensor(tokenizer.encode(prompt, allowed_special="all")).unsqueeze(0)

if tipo_tokenizer == "preentrenado":
  generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)

generated = generated.to(device)

# %%
model_sologpt.eval()

TEMPERATURA = 0.6

sample_outputs = model_sologpt.generate(
                                generated,
                                do_sample=True,
                                max_length=80,
                                top_k = 0,
                                num_return_sequences=500,
                                temperature=TEMPERATURA,
                                renormalize_logits = True
                                )

for i, sample_output in enumerate(sample_outputs):
    if tipo_tokenizer == "tiktoken":
      print("\n\nPoema Generado N° {}: \n\n {}\n\n".format(i, tokenizer.decode(sample_output.tolist())))
    if tipo_tokenizer == "preentrenado":
      print("\n\nPoema Generado N° {}: \n\n {}\n\n".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Poema Generado N° 153:
#
#  -no te digas nada, no,
# ¡qué linda y qué linda!
#
# -¡ay! ¡qué dulce es la mama! mama es tuya.oyela, sí, pero no lame.
# ¿qué más linda podría ser! ¿para qué?mama, es tan linda. ¡todo el mundo, todo el cielo!m
#
#
#
#
# Poema Generado N° 154:
#
#  -pero si eso me gusta,
# ¿qué me pena verlo?
#
# -porque no lo quiero, mama.oye, sí, no.
# pero, ¿qué haces ahí, mira?no hay nada. ¡no!
# ¡qué más! ¡soledades, ésas!son las palabras
# que me dieron en la noche de san juan!
#
#
#
#
# Poema Generado N° 155:
#
#  en la noche de san juan,
# en las viñas de valparaíso,-¡yo no sé, yo sé!
#
# lo que importa es que no se muera
# y que se me mire y me dé espalda, porque se acerca.oye, mi amor, que ya no me muere.
# pero yo, la que te estrecha las brazos, todavía no tengo
#
#
#
#
# Poema Generado N° 156:
#
#  de la tierra que a mí me dieron
# la fruta que es mi alimento
# y la flor que él alimento;
#
# de mí que me dio la fruta,¿por qué
# me dieron la paz, por qué me gozo?sólo él
# es el que da la vida,
# que da el fuego, que dan la muerte, y la resurrección.la tierra es
#
#
#
#
# Poema Generado N° 157:
#
#  y el que te mece y que no te alcanza,
# ¡y que se lo oigo y me lo mengüe
# y se cansa y se cunde el alma!
#
# yo no he sido tu santo francisco
# con su cuerpo de calvario y su gloria, y sus respiraciones, oh
# escalera de su greña oscura, sus llagas sangrientas
#
#
#
#
# Poema Generado N° 158:
#
#  yo no quiero que me olvide,
# no quiero, no, que no me aprenda
# de ti, de no ser sus amigos,de no tener razón
# para irme de mi propio sueño.
#
# yo quiero ir de ti con tus ojos, con tu boca, conmigo, todos
# tú libros, tus versos, tu mirada, toda tu energía, todo
# tu alma
#
#
#
#
# Poema Generado N° 159:
#
#  tampoco en el sosiego
# pronto de su reino,
# ni en la montegrande
# mandíbula de sus cerros.
#
# -mama, no te mueras, mama, di, ya
# me nació de cuento.mame, me crié
# con los cerros de ojos
# oscuros y tremendos. ¿por qué te importan
#
#
#
#
#
# Poema Generado N° 160:
#
#  -¿por qué siempre lo haré que me tumba?
#
# -no, chiquito, no lo hallo.
# yo me voy a morir de un disparo
# o de una llamarada.no lo sabes, mama.
# ¿cómo te oiga, di?es fina, comocilla. ¿por dónde vas? sí, por eso. di. sí.
#
#
#
#
# Poema Generado N° 161:
#
#  la nieve las suele aburar,
# la lluvia las indica
# y la lluvia que cae.
#
# en la noche, las lunas de miel
# llaman a sus espaldas:
# "¡oh sentina, sentida!"oyen las palabras
# de las siervas que en ella se posan.elévala el aire
# con pétalos de fuego. "¡ea,
#
#
#
#
# Poema Generado N° 162:
#
#   ese verano yo no sé
# que dejo en el mar de mis manos
# y me cae a mis rodillas
# como al delfín.
#
# ahora que no tengo tiempo
# siento dos horas.mama, me duermo
# sin parar mi sueño. estoy
# con un sueño que es de mí mismo.
# no duermas con nadie. yo no me necesito.
#
#
#
#
# Poema Generado N° 163:
#
#  yo no sé, pero me sé sus ojos
# de niña con el pez y el cangrejo.
#
# yo tampoco sé de dónde está
# aquí me voy a parar,
# en el mar o en el país,o en las señales, o
# o me pasa por un campo imaginario
# con los ojos de niña y con los
# ojos de ángel.yo, es la tierra
#
#
#
#
# Poema Generado N° 164:
#
#  te llamaré y me dejaré sin llamada,
# porque si me volviera nunca más, al fin, te sabrán
# que sería una señal y una sonrisa.
#
# ya sabes que no me llamo todavía. ¿por qué no lo sabrás
# a la criada y la fiel?sigues, que me llaman y no le respondo.veo en mi
#
#
#
#
# Poema Generado N° 165:
#
#  -no te mueras, eso es
# también de fiesta.
#
# -pero a veces, cuando te cantas,
# yo no sólo
# devas tú los cerros, te deja
# en el cerro, y quema tu gracia.y tú, mi chiquillo, que
# te ha dicho muchas veces
# que te camina por las quebradas,o
# a la orilla del agua
#
#
#
#
# Poema Generado N° 166:
#
#  el viento negro de valparaíso
# que azota sobre valva,
# una vez al fin se deshace, como un niño
# de siete años.
#
# por la gracia de chile, el
# mejor vino
# del mundo. tú me quieras
# con la humildad de la ciudad, con la
# dulce de las islas, y el amor de
# las islas.ve
#
#
#
#
# Poema Generado N° 167:
#
#  -¿qué ves, mamá, que no lleva
# su alma de niño?
#
# -cuando me interrogan, les contestan
# como si fueran grandes
# las cosas que te hacen y las que nos hacen,
# y te digo que son
# casi todas las cosas grandes.
# pero cuando se callas y se?yo, mama, te sabes.no. ¿
#
#
#
#
# Poema Generado N° 168:
#
#  el cordero está espesando
# el vellón que he de tejer.
# y he sembrado en tu huerto
# a la patrona de la gea.¡y son tuyas las madres
# que te amaron y amamantaron
# con el cuerpo de tu hijo!
#
# cuando en las viñas de israel,
# en las terrazas de los valles
# donde se tuer
#
#
#
#
# Poema Generado N° 169:
#
#  ¡ay! juguemos, hijo mío,
# a esta reina con el rey!
#
# ¡eh! ¡oh sentina de escombros!oh loca, loca!oh ciega, fantasma!yo no te muero, hermano mío.di el dios que te espera.
# la tierra que no era tu morada, tu tierra! dime ¡noches llenas de polvo
#
#
#
#
# Poema Generado N° 170:
#
#  de la piedra a la otra se hallan
# la huella de un pastor o de una arribada,
# y el esqueleto de los arribados
# en lo que llaman la muerte, y la resurrección.
#
# se oye un grito y se oye el llanto,el del deseo, el de la agonía.sí, mi amor, ya no hay más amor.*booz
#
#
#
#
# Poema Generado N° 171:
#
#  -mama, no te aburres, mama,
# no te pareces a poco.
# te aburre entonces todo
# lo que te gusta decir. pero
# yo te amo, nada te odio.oye
# el filudo, que vendría
# del mar y que era de fuego. ¡cuantos atar!
#
# -no es que tú tengas miedo, chi
#
#
#
#
# Poema Generado N° 172:
#
#  -cuando te preguntes, di,
# yo sé que te va a llamar
# para que no conoces cosas
# y que nos llame sin llamada...
#
# -no te cantan las tontas
# por la pobre merced de tu alma.
# ¿cómo es que tú no paras
# a la gente que estás cantando?¿y dime que nunca
# te canto fue para cantar
#
#
#
#
# Poema Generado N° 173:
#
#  y el asombro de dios hizo dormir a mis muertos
# los que, sin mirarlos, me mataron.
#
# y la locura de que dios no me muriera
# no me muere, y de tanto que no pueda
# me crean una vida eterna.no, que me crean vidas. ¡qué dulce!otros muertos, tú sabes cómo moriste.no más. eso
#
#
#
#
# Poema Generado N° 174:
#
#  la tierra no conoce
# nada, sólo unas palabras.
#
# la noche es sosegada
# y la lluvia es venida
# de norte a sur, de norte al sur.la pavesa
# sin saber yo la veo
# en la sombra, en el agua,
# o en la noche como una
# relámpago"
# sobre mi cuerpo, oh
# agua
#
#
#
#
# Poema Generado N° 175:
#
#  ea, ceiba, ea, amando.
#
# yo no sé si es mejor vino que vino
# y es el vino mejor que me vino.lo mejor es callando
# su pecho y el de él, y no ser arribado.lo más bello es la cita
# en donde los dos me hacen gozos.lo tercero es ver el mar
# donde una
#
#
#
#
# Poema Generado N° 176:
#
#  el que te espera para siempre
# y que no le vuelva nunca más.
#
# -¿qué ves, mamá, que estás viendo
# defectos o voces que gritas
# o que nos llamaras "malas?no.es como que me oyes
# las cosas que asustas hacen y las que hacen
# malicias y deshechas. ¿y a qué me responde
#
#
#
#
# Poema Generado N° 177:
#
#  -¿y cómo es que no tienes miedo?
#
# -es que te buscan y no te encuentran.¿qué más podría ser?chiquito, mama, eso es todo. ¿cómo es eso que ya no quieres? ¿es eso cuánto te creías.
# ¿ves que yo quiero seguir contigo? es cierto. dime, di. eso de querer. ¡
#
#
#
#
# Poema Generado N° 178:
#
#  el frutillar oscuro y tornasoliento
# brilla en el matorral su flor,
# y el leñador ignora el nombre.
#
# la higuera de ojos claros
# no es de semblante, ni es del sembrador:
# ¡sacude como un árbol prodigioso
# si el rigo no endereza al animal!cuenta que es la higuera, ¡
#
#
#
#
# Poema Generado N° 179:
#
#
# aunque te quiero, tú me llevas.
# la fiesta se llevará por tu río
# y el viento que te rompe.oye, yo te amo,
# porque mi amor fue sólo un sueño. óyel del mar, óyelo. te espero. di. "tú no veo"
# es la canción que más quiero. bajo del viento.
#
#
#
#
# Poema Generado N° 180:
#
#  -no, no, chiquito, que
# me dirigí directamente.
# le dijimos que pusiera
# en una casa donde se cascaba.*
#
# -mama, ¿por qué me dejas
# que me baño con soledad?chiquito.y me voy, sí, a contar. dime, mamá, cuánto tiempo
# llevo un poco de tiempo
#
#
#
#
# Poema Generado N° 181:
#
#  yo la tengo todavía;
# no me la puedo dar:
# ¡y por piedad me perdí!
#
# me la tienen, y me recobro,
# y me creen en sus espaldas.por eso
# yo les doy como un hijo, por que nunca
# le oigo volver.
# a los que la quise, a los nacidos, al mar, me dejan.
#
#
#
#
# Poema Generado N° 182:
#
#  se alejarán los caminos y la tierra
# devan;
# se dejarán sin conducir,
# y morirándonos sin tiempo.
#
# no volveremos. no volverán.oyendo
# que tu hermana no está conmigo,no!
# la voz de tu madre
# está en las puertas del pueblo, y tu voz está en los árboles. te sigo, sigos
#
#
#
#
# Poema Generado N° 183:
#
#  en el aire la estrella cae
# y la frente de la novia cae.
#
# en la noche de los reyes
# la madre baila con el niño
# como una danza de cuatro almas. tú, el que te estrecha,
# te estrecha los brazos, te abro, me oyes.no acarrea nadie, no temas, ni acaba. es sólo tu alma, tú que
#
#
#
#
# Poema Generado N° 184:
#
#  -¡ay, mama! no es cierto
# que tiritas de niño y que tu pelo
# se me caen en linda y morena.
#
# -porque mama, me parece
# una pollada y unas fuertes.no veo más. ¿será
# el que te diera la espalda,
# la que nos dobla y nos
# hace bailar los otros?sí. ¡
#
#
#
#
# Poema Generado N° 185:
#
#  en la noche, como una hebra de llanto,
# sobre mi madre, que está durmiendo, y que endereza, al grito,¡y en el sueño que ella me hace, todo en ti fue naufragio!
#
# cuando la marea baja, caen hojas
# en tu rostro como en una duna, el agua de tu boca
# que caía contigo y se desl
#
#
#
#
# Poema Generado N° 186:
#
#  y el que te mece, que aúpes,
# te llena de dulzura y de llanto, y que endereza
# y te lleva como el niño sin dueño,*
#
# porque todo lo lleva el padre
# en un manto de misterio, en un traje
# de amapolas y pomares, con traje nuevo
# que te deja en los cimientos
# como
#
#
#
#
# Poema Generado N° 187:
#
#  la muerte de un solo ser,
# la de una sola ser.
#
# ¡qué dulce que es, qué dulce!
# y en la muerte del único ser
# que pudo ser feliz.él fue feliz porque
# su vida fue amargamente feliz!la sangre fue estrellada
# en el desierto, en las montañas, y fue
# tuya, tuya.la
#
#
#
#
# Poema Generado N° 188:
#
#  son los que sufren las tinieblas.
# son la niebla, la del silencio.
#
# es la rosa de la fruta.a veces
# lo mismo se repite. -anda
# de la noche, de las hojas. es la flor.* al viento, al río,
# la lluvia, el rocío. y yo no sé, por qué
# no sé que yo
#
#
#
#
# Poema Generado N° 189:
#
#   los que están heridos
# en sus casas y en sus huertos
# no saben que a sus hijos
# lesfones, ni amapolas,
# y no quieren que se vayan.
#
# los que piden el pan
# se van a contestar, se van
# a pedir la leche
# o la fruta que está en la mesa.oye
# que los panteran con gestos
#
#
#
#
#
# Poema Generado N° 190:
#
#  oigo
# los inviernos
# con su puro silencio
# o con la niebla de la mina.
#
# el sol de ocaso
# es la devorante
# luz de su mundo
# y el espanto,
# la grasa del hombre, el polvo de sus huesos,o la ira del tiempo
# que mata a sus dos grandes raudales.cuenta
# las estaciones, los caminos, las
#
#
#
#
# Poema Generado N° 191:
#
#  yo me entraba por la casa
# y me lo contaron por partida
# por el hombre de ojos claros.
#
# le preguntaba si me acudía
# con su rostro de niño o con ciervo
# o con el rostro sin pies de ciervo.y él me dijeron:
# -"¿y por qué me vienen a mis casas
# sin su cara de tigre?"yo le respondí. "
#
#
#
#
# Poema Generado N° 192:
#
#  el día lunes de los tristes
# carniceros.
# la noche americana. el día.¿no ha de llegar?
# el mundo está cayendo en pedazos. ¿no es cierto? es claro que la mañana
# se levanta y que se viene a bor,
# que llega a ser el alba, el ocaso. ¡no!
#
# y la noche que acaba como ayer
#
#
#
#
#
# Poema Generado N° 193:
#
#  la noche se va entera
# en que el ángel arderá sin querer
# y se haga amenaza de muerte.
#
# la medianoche, oh mañana,
# es como que al alba la noche
# se hace más espesa y más seca.no es así, es como un río
# que se hace en el viento. es un país, un pueblo, y un día. la
#
#
#
#
# Poema Generado N° 194:
#
#  -cuando hablas de nuevo
# me dan que recobro
# y se vuelvan a ver
# vuelven los viejos.
#
# -yo soy fantasma, pero
# no me da la gracia
# de seguir caminando
# sin que me conozca
# mis padres-dios,
# ni me tienen ni lamiendo
# en fantasmas ni fábulas.no son llamado
# por la puerta,
#
#
#
#
# Poema Generado N° 195:
#
#  el hombre ciego ignora
# que su amor está en la tierra
# y que en el aire está su sangre.
#
# el pobre peregrino ciego
# sólo le mira al que llama,
# al que le manda dar
# en su pecho o en su alma.bás donde está tu amor, en tierra y cielo, lejos
# de donde su corazón no mata el fulgor, el vino,
#
#
#
#
# Poema Generado N° 196:
#
#  -¿qué es eso de ver
# los fantasmas? ¡qué cara con ojos!
#
# -mama, no te aburres.
# no te pareces a nadie.no es cierto. di. niño prodigio. ¿es cierto?sí. ¡sí! juguemos. juguetones. escucha. sí. parece.sí, miramos, escucha todo
#
#
#
#
# Poema Generado N° 197:
#
#  en la luz de la tarde,
# cargado de noche, desnudo
# de la intemperie, todavía
# no hay humo en mi casa, y no hay agua
# en mi jardín.
#
# y las piedras no toquen mi tierra,a mi sombra:
# yo soy el que cortó el mundo, el pescador, mi dueño.y no sólo mi existencia
# que me
#
#
#
#
# Poema Generado N° 198:
#
#  y el chileno interrumpido
# por la fuerza del deseo,
# y las mujeres que amamos
# con su palabra en su espalda, y el beso
# en su boca, que es el amor verdadero.
#
# el chileno roto
# entre las hojas de la ceiba
# se balanceó, se agarró
# la sangre caída, el dolor
# de los que perdieron,el del olvido,
#
#
#
#
# Poema Generado N° 199:
#
#  y en la luz se vieron las espigas
# de las pobres viudas,
# y viéndolas subiría
# como la zarza a las colinas.
#
# en los astros de la noche
# lamían a la madre que ella amamantaba,ondrada
# con el rey hebreo y el profeta, y los reyes
# del sur, del norte y del este.amon
#
#
#
#
# Poema Generado N° 200:
#
#  aquí me estoy, señor, con la cara en calma
# y con los ojos en oscuridad,
# por la tarde y por las mañanas.
#
# el hombre que construye es para todos, pero es más
# para el hombre pobre y enfermo.oye ser el ciego y ser
# la pobre piedra rodada.yo no quiere ser, eso
# es para mí, mi hombre.
#
#
#
#
# Poema Generado N° 201:
#
#  -¿qué ves, mamá, con esas manos llenas
# de gracia, de fuerza, dices?
#
# -para que tú conoces a los tontos
# que no entienden, para que ellos no
# pangan pan en la mesa,
# en la almohada, en los dinteles,otras, cortadas
# por meros rojos y entendimiento.no te m
#
#
#
#
# Poema Generado N° 202:
#
#  ¡ay! juguemos, hijo mío,
# a la reina con el rey!
#
# ¡vamos, amor, en el alba de diamante
# como en la noche inmensidad, y en los cielos
# de rojez y de fulgor subemos
# el dios profundo que nos rodea.¡dios que te espera en tu más alto
# monte de gloria, que en las
#
#
#
#
# Poema Generado N° 203:
#
#   plata, huemul, sorbo de llanto,
# besado, en rojo llama, y espuma, de la sal
# entreabierta, cayendo en gotas
# con las manos unidas.
#
# plumas puras, espinas duras, cayeron
# sobre mi cabeza, como gotas de sangre, un
# enter sediento, una espesura, el corazón.oh sentina
#
#
#
#
#
# Poema Generado N° 204:
#
#  yo no quiero que me den muerte
# en este largo silencio, en este corto silencio.
#
# me voy a morir con todo
# que me dieron, el pan, y la leche:
# el vino, la carne, las frutas.kipling cuenta que lloran. di,
# no duermo en esta cinta, tengo
# sino que duerma en el anáhuac.
#
#
#
#
# Poema Generado N° 205:
#
#  dame el olor de rosas,
# el olor del vinagre, el del ácido, la sal de las aguas, las olas, y el dolor como un río.
#
# damos la mano turbulenta, como una tenaza gastada, en el tálamo.y la sangre que cae a mis manos, me muero, arrastrando mis brazos en la agonía.tuve
#
#
#
#
# Poema Generado N° 206:
#
#  en una noche tan grande me cubrió
# y tan dulce me lo mentaba.
# yo era como las leches de luto
# cuando el mundo se fue derrumbando
# en la estructura viva de mi alma.a través de tus ojos
# la sangre, la sangre mía,
# siempre me quema la cara.*
#
# no quiero que nos contamos
# como los mares de la mañana
#
#
#
#
# Poema Generado N° 207:
#
#  y como una rosa salvaje
# se arrodillaba y se recuesta
# de ella en la noche tan grande
# que la tenía nunca.
#
# y por eso me vuelvo, como
# la víbora de cascabel,
# a dormir conmigo.el sin viento
# me llama y me dice  "en sueño".no me canso, no me miento
# en la
#
#
#
#
# Poema Generado N° 208:
#
#  yo no quiero para mí tantas desgracias.
# no quiero ser apellido de ninguna raza.no tengo armas. no tengo novia. estoy triste porque debo. quiero que otros hombres se me atarantan. espero que mi poesía me calle,
# y quiero la paz que tengo entre los brazos. si no me busques entonces, debes morir. oyendo la palabra en mi
#
#
#
#
# Poema Generado N° 209:
#
#  amigos, si pudiera,
# amigo que alguna vez prendiste
# los ojos de fuego y de sangre
# como está en la bandera de la patria.
#
# ay, que tú la hallen
# en otra parte del camino
# con los ojos azulados
# de donde están los otros, y en qué
# sombra los que pasan entre nosotros?a qué vino de tan lejos
#
#
#
#
# Poema Generado N° 210:
#
#  yo no quiero que te llame "madre de la patria",
# ni pienses que me llamen vano.
# yo quiero oírte cantar.
# me gustaría oír a la que canta. allá lejos, lejos. cayeron
# en medio de lo que amo, y lo mismo que canto. ·bajo los tálamos y en medio
# de los mismos y de los dos,
#
#
#
#
# Poema Generado N° 211:
#
#  si existieras, en una costa
# de esperma, tú me muero.
# pero si sigo existiendo,
# será que te sigan.o
# tú mueres porque quiero
# morir con tus ojos, con tu lengua, y tu boca, ·
# y porque te quiero amarte. ¡ay!
#
# yo te amo, amor mío, por eso te
#
#
#
#
# Poema Generado N° 212:
#
#  la tierra es bella y seca,
# el mar es alto y dulce, y las estaciones
# se hacen miel de tristeza o de llanto.
#
# pero yo, la que te estrecha, no las sabía,pena de nervios, voz de vencido
# y tremenda, grité a la puerta: -"¡qué bien comidas, qué anchas, quién agraciada!" puertas
#
#
#
#
#
# Poema Generado N° 213:
#
#  -¡ay, qué linda!
#
# -¿a qué, mama, di?a la mama
# que te crece mal, cógamo,
# y que no te mientes, que te hienden.
# ¿y qué alguna vez, por qué
# con tu cuerpo de dos años te pasa, y tus cejas?
# pide, mira, escucha, oye,
#
#
#
#
# Poema Generado N° 214:
#
#  -¿por qué no lo hallamos antes?
#
# -porque todo lo cuento,
# lo cuento mío, eso es
# tan feliz y de buen gusto.no lo miras, chiquito.
# ¡qué lindas cosas te hicieron, qué tonadas!es como que sólo eres bueno
# para las gentes del mar. ¿no hago nada?por eso. sí
#
#
#
#
# Poema Generado N° 215:
#
#  la luz azul de la tarde gira en el cielo.
#
# miro bajar las hojas muertas.miro pasar.a través de las palabras.
# miro crecer la sangre y la venas...vienes volando. espumas. tremolares.tierras.allemos..y tú, la que como paloma tornasolada,
# espada como la espada en la
#
#
#
#
# Poema Generado N° 216:
#
#  ezquieres el de tus dos pechos
# que besaste y endulza en olas
# y enduzas con llanto y canto.
#
# en el mar de las fieras
# vamos a encontrar y a matar.no hay nadie, sólo son los árboles. ¡sí!
# ¡qué nombre le dieron y qué le dio!son sus manos de menta
#
#
#
#
# Poema Generado N° 217:
#
#  ."
#
# "¡ay! ¡no! el que tiñen los ojos,
# y los que tejen los labios
# no volverán a ver nunca!"anduvieron
# los viejos y los niños
# como ancianos profundos.ál fue la hora
# en que los viejos se despertaron.
# el que dormía se hizo inmundo
# para los suyos. ¡ay!,
#
#
#
#
# Poema Generado N° 218:
#
#  ¡ay! juguemos, hijo mío,
# a la reina con el rey!
#
# alguno se lo mecía, al niño
# de ver el mundo que mira.a los ojos suyos
# el mundo es más hermoso.
# la luz era tan grande, y
# y la rosa tan dulce. ¡ay!,
# ay!"niño
# ¡qué noche tan denso,
#
#
#
#
# Poema Generado N° 219:
#
#  -¿qué ganas de hacer?
#
# -la mama que habla,
# yo me lo creo. tú, la mama, te lo digo.
# de eso no sé nada. dilo tú que me falta.
#
# ¿por qué no se lo sabría, mama?no sé, por qué. ¿por cuánto? ¿no se cantara de nada? di.
#
#
#
#
# Poema Generado N° 220:
#
#  y es mi patria donde yo
# muerda, baila y vive.
#
# en mi país, en mi tierra
# de leche y hierro,
# arde de la lluvia, padre mío,o nada, nada.no hay nadie, sólo son los árboles.*ni tú, mi hermana, ni yo. ·el mío no sé, qué te creías. -
#
#
#
#
# Poema Generado N° 221:
#
#  tropas de noche
# de las casas paternea
# y arde también mi camino
# en los caminos ciegos,
#
# dijo que me busqué
# la ruta de un día
# si la casa no me la atrapamos
# como la tenca de oro.no sé, de lo que no se oía, por qué yo he sido
# un cobarde que beb
#
#
#
#
# Poema Generado N° 222:
#
#  yo no quise doblar los brazos
# para mí tan completo.
# se ha de ser tanto que es. ¡nada!
#
# yo veo un vaso de leche
# y una copa de agua,
# la cual yo no hiero, por no beberla.a todos
# me he de tenderle, como un ángel
# a ser fiel a su dueño...yo soy,
#
#
#
#
# Poema Generado N° 223:
#
#  aquí me estoy, señor, con los ojos ciegos
# que mi padre no sabía,
# y los dos me juntas o me aman
# como unas almas perdidas.
#
# por eso yo paso mi mano
# a las manos de los ciegos,o más bien, a la
# piedra de toque, que es la piedra
# de toque que está en medio de la tierra.no es
#
#
#
#
# Poema Generado N° 224:
#
#  los marineros de la noche
# se hacen rápidas y rápidas
# como cuando nacía,
# cuando ella se abajaba.
#
# y al llegar la medianoche
# la marta a su encuentro
# por el costado y la mano
# tiene su rostro en un vinagre
# que es de cobre y es dorada.ojalá, mi niño, que te lleve
# a su espalda, cuando
#
#
#
#
# Poema Generado N° 225:
#
#  ya no sé yo si eres "tan fuerte" o "grave".
# me gustaría tener brazos
# por donde no vingas,
# y no muevas ni se ven en las tardes
# sino que se ve en el otoño.
#
# ya me voy a quedarme solo
# si no me asustas en medio de la noche. ¿cómo pueden estar juntos
# para vivir juntos tan
#
#
#
#
# Poema Generado N° 226:
#
#  era la boina que amé,
# era el alto cardo de la caña
# que amó a la madre.
#
# bailan todas las ramas
# hasta que las hojas lleguen
# y las haya amamantadas.mueve todas
# las corolas que dieron aliento. "la espiga",
# "la gea", "el huemul" y "las mies
#
#
#
#
# Poema Generado N° 227:
#
#  en el valle de elqui, en el frío,
# como una isla hecha fuego,y en la noche, como un río
# de cien ríos queene, salobre y espeso, canta.
#
# en la altura de mi corazón, y en los ríos
# que me encamino, vivo y oscuro, danzando, ardiendo, me ahuyenta.o
#
#
#
#
# Poema Generado N° 228:
#
#  "la mama que fea",
# "el que amó a tu hijo", "la dádiva del que va a venir", han venido
# y llorado de su alegría.
#
# he vivido tantos soles,
# tantas lomas y praderas
# que ella no ha de florecer.mida, muerta, está
# en la falda de la pradera, en el filo
#
#
#
#
# Poema Generado N° 229:
#
#  el día lunes, lunes negro,
# deja caer al suelo
# el cadáver del hombre que fui herido.
#
# y hoy que él está vivo, que es
# una hora de luto.y yo me cubrió la frente
# con lágrimas, con dolores, y con
# un día de resurrección.cuando es que ya no hay luto
# para mí, para mí todavía. eso es
#
#
#
#
# Poema Generado N° 230:
#
#  -¡qué bueno es que tú tenías
# a lo que amabas, a lo largo
# de las montañas!
#
# -no te digo lo demás,
# que hablas de gracia
# y es cosa de veras
# las montañas...no pienso que te cuento
# con linfas que no te dan
# el que dejo ser más lindo.y en mi
#
#
#
#
# Poema Generado N° 231:
#
#  -¿qué dices que no somos míos?
#
# -míos son cosa de la tierra.pero son cosas que me hacen.
# yo te digo, "madre", "viejo" y "ancho".sí, mama, por eso,
# dicen que te amo y te doy con él.
# ¡qué de malo es, di, que nos llam
#
#
#
#
# Poema Generado N° 232:
#
#  yo soy el que te espera en la noche
# y en el sueño que llevo tú:
# mi corazón, que es fuego, hace bailar.
#
# de noche no te punza,
# ni te abro los ojos, ni te halle el corazón.no duermas nunca más. eso es.no me lo sabes. no sé qué te has olvidado. nada
#
#
#
#
# Poema Generado N° 233:
#
#  -¿qué haces ahí, mama, di?
# es la huerta de olivas
# y un predio de labrantíos.
# ¿por qué te lo robaron
# los huertas de lucía?
#
# -porque a la vista es todo.di nada. ¡qué es eso!
# ¡qué de malo es que tú tengas
# sino dos cosas de atar. ¿
#
#
#
#
# Poema Generado N° 234:
#
#  yo no quiero que me den
# la mano que le dieron.
# yo quiero ver cómo me la oigo
# y aprender más sobre esta hierba.y no seré como si tuviera
# un hijo como él,
# como si fuese hijo de madre cuerpos.  la tierra me quiso,
# me voy a ver en un futuro, un día, una noche, cuando
# el
#
#
#
#
# Poema Generado N° 235:
#
#  y aunque sepan de mí los pies del hombre,
# que me bebieron, me den muerte y me muero, y estoy tan triste y tan amante,*
# y de mirarme los ojos y los oídos, tan ansiosos, ansia,yo, sufro!
#
# me asombra de que no haya salvación, que sólo puedo huir:
# ¡no hay salvación
#
#
#
#
# Poema Generado N° 236:
#
#  en el valle de elqui,
# donde el río es un río
# y el mar es una costa,y un país, y un pueblo.
#
# en cada valle está el agua
# de mi cascada.vendrá en el aire la lluvia
# o saldrán a mi voz en la noche.¡y en cada puerto está la sed. ¡o me moriría!
#
#
#
#
# Poema Generado N° 237:
#
#  y me mostraron los dos
# los rostros de los dioses
# y los rostros del hijo y de ella.
#
# yo no la vi a la madre
# ni a su hijo, por ser niño,
# que por la leche no se la dio
# en la boca goteada de madre.yo, mi niño
# no la tuve, ya me lavaba
# por no ver a sus padres
#
#
#
#
# Poema Generado N° 238:
#
#  se juntan las flores
# del día y el solsticio;
# se trinan los ríos
# de la noche y la aurora.
# y se junten las fábulas
# en una sola y trémula. tú, el que te nombra,
# te di, que hablas, y te hables, di.*
#
# ¡ea, ceiba, e
#
#
#
#
# Poema Generado N° 239:
#
#  y ahora, rompiendo la pared,
# los vidrios, y subiendo
# a la cima, la estatua
# de la paz, no queda
# ni la llama de la escalas:
# sólo la tinta de los sueños
# que atraviesa la boca.
#
# apenas no hay un rayo de sol que los alcance,a las sienes
# del aire, de las aguas, del sonido, los
#
#
#
#
# Poema Generado N° 240:
#
#  aquí me estoy, señores,
# con mi cuerpo sin alma.
# sólo en las tinieblas
# me escucho un grito, un silbido.no sé, no sé qué me escupía. no más. ¡no más!
#
# yo sé que el que me hirió
# no me lo sabrás. sí, que era violento. sé lo que he vivido, eso es
#
#
#
#
# Poema Generado N° 241:
#
#  la pobre tierra es tuyo,
# la luna tuya y mía.
#
# de ti te extrajo mi alma
# y no quieres que me olvide
# mis deberes.muertes, la tierra
# es tu mía, es mía y todo. di. "te extrajeron mi pobre alma".sigue, escucha, no te mientes, mi tierra.
#
#
#
#
# Poema Generado N° 242:
#
#  no te ha querido, no,
# ni dedal te han querido.
# te ha dado el quejo, el llanto
# de los huertos y las praderas. no te los quiso.*
#
# no me acuerdo de tu rostro, que me muevo,* pero tu voz
# es la que da el sonido de vodka,a más largo que río.as
#
#
#
#
# Poema Generado N° 243:
#
#  y cuando, bajamos,
# nos encontramos con el viejo
# montegrande, y nos tenemos
# la memoria que da su nombre.
#
# yo le preguntaba ¡qué?
# y ella respondía,no:
# -"¿tú no lo sabes? dime: "muy bien".y me di. "me lo di".
# ¿qué es esto de que
#
#
#
#
# Poema Generado N° 244:
#
#  vamos a dormir a una cierta hora
# en el sueño que nos dieron,
# sin acidia ni cansancio
# y sin desvaríos, sin mudez, y sin escorzo
# de si o no lo encontramos en el aspiro.
#
# tal vez lo dejemos, tal vez no se precipitadamente, ya
# este destino, este sitio, esta aguja, todo
# lo
#
#
#
#
# Poema Generado N° 245:
#
#  -mama, no te aburres, mama,
# que ya no quieres pasarme solo.
# no te vale pasar con alguien de más
# largo.oye, sí, con los otros.
#
# -pero, ¿por qué siempre me pasa?
# dicen que por si quieres, di. ¿es eso?a veces, a veces
# es una cosa
#
#
#
#
# Poema Generado N° 246:
#
#  -pero si no te vas, te sigo.
#
# -sí, pero si estás, que te
# quiere mucho, estás bien.pido. ¿cómo te cantas?
# es para que no tengas miedo?oye, mama,
# sí. te digo que va a dar miedo.uno te va diciendo
# que va otra vez por los pinares
# y
#
#
#
#
# Poema Generado N° 247:
#
#  el viento loco va y venga
# con su aliento de rayo y trueno
# y va, sin tregua, cantando
# de nuevo el himno que le dieron
# para que ella cante.
#
# el canto nuevo le dio
# a la puerta de la posada
# que era su dueño.veo el tiempo,
# la posada, el campo, los huertos,almendra,
#
#
#
#
# Poema Generado N° 248:
#
#  -pero qué, mama, no dices
# que yo nunca fui costero.
# ¿por qué no me dijiste
# a la que me crió sin cara?
#
# -no te digo, chiquito, que veo
# un fantasma que es el fantasma de tu casa.¿y a qué me miras, di?y dilo, sí, como tú,
#
#
#
#
# Poema Generado N° 249:
#
#  olas de viento, flores
# del amor que nos dieron,
# y amapolas de la tarde, y el viento
# que nos llevónos, con nuestro amor.
#
# a la hora de partir, en la noche, el día
# de la aurora y la epifanía,cuando
# la auroras, cuando la tempestad
# nos devuelve y nos devuelva.
#
#
#
#
# Poema Generado N° 250:
#
#  yo no sé si es mejor canción que canción,
# y es peor que el mar.
#
# la canción estaba en los cuarzos
# de los mineros del cobre
# en la mina de cobre.puse el corazón en la estrofa
# para escuchar el himno mina.mil noches de oro, canciones
# se han mojado por la paz. nunca se apagarán. " seco,
#
#
#
#
# Poema Generado N° 251:
#
#  chile se sentó en la arena
# y ella no canta.
#
# se va a contar cuando
# en la noche, cuando ya
# la luna y la loba
# cantan las palmas reales...
# ¿y si no la canta,
# si no es que la oigan?me la quise, me la veo
# para que ella cante.y es más
#
#
#
#
# Poema Generado N° 252:
#
#  el día lunes, entre las calles,
# el de los niños y las muchachas
# ha pasado en la memoria
# como un puente entre sombras.
#
# los días de las grúas, las de la madera, el del vino, los de lana
# contuvieron la luz de su propia luz, y la espuma del día, hasta hoy, dentro delullo
# de la tierra, en el
#
#
#
#
# Poema Generado N° 253:
#
#  ya quiero irme a la estación
# y allí me quedaré con ella
# de la misma manera que el amor,
# sin relajo, sin palabra.
#
# llego así también con la lluvia
# a mi casa de donde iba:
# vamos caminando, y no hay nada.también se pierde el sentido. ya no tengo nada, ya nada:no estoy en el
#
#
#
#
# Poema Generado N° 254:
#
#  -mama, a veces, yo me dobla
# por decirme "madre de hielo".
# así, ya me voy a perder con hielo
# la cara con lágrimas o con el llanto.
#
# -no te cuentes más, no,
# con los otros niños, chiquito.es la vieja nieve
# que nos derriba, derribando
# los árboles que rompen el
#
#
#
#
# Poema Generado N° 255:
#
#  -no te digas nada.
# ¿qué de esto, mama, dices que?
#
# -es que yo no soy fantasma,
# que ya no quiero que me muera
# y que tampoco yo me serviles.es, que son dos
# convida y sin cierta fatiga
# de lo que amo y lo de lo amado. "
# yo sé que tú, fantasma
#
#
#
#
# Poema Generado N° 256:
#
#  yo soy el que te espera en las mañanas
# y espera y no se lo alcanza,
# pero que en tu noche de alegría
# se oyen tus campanas, tus crepúsculos.
#
# tú me enseñaste al hablar en inglés
# por los nuevos diccionarios, y en tres semanas
# me dio tu idioma, tu lengua me dio
# el poder de escribir tu panfleto
#
#
#
#
# Poema Generado N° 257:
#
#  es el cielo y la tierra
# que son mil y que son más,
# y que es la esperanza
# de mis vivos y mis muertos.
#
# el mundo es redonda y apretujada
# como una campana rota,tú y yo, juntos, en la estrella, con tus ojos, como dos relojes, iguales, de manera igual, igual:
# la balanza es inmensamente
#
#
#
#
# Poema Generado N° 258:
#
#  el viento negro, el viento
# blanca,
# y el calor, y el frío, todo
# es de mí un ser, un ave.
#
# no sé si es de nosotros un
# moto, es del otro, o es
# la otra emigración, una
# maniguas personas
# de las islas que me hicieron.me nació contigo
# como una isla y una
#
#
#
#
# Poema Generado N° 259:
#
#  se aprietan los coros
# que se apen por el mar
# y se hacen por la tierra.
#
# se van a tocar las plantas
# de la caña,
# las tejas, las tejas
# sino leñadores, y el canto
# del tambor indio
# allí llegó a la casa.a la verde, la blanca,elillo. el viento
# la
#
#
#
#
# Poema Generado N° 260:
#
#  y el papagayo san martín,
# pausadamente, desde el fondo del agua, y hasta mis ojos, como pájaros, se unen
# al rocío de mi cuerpo, cuando estirame las hojas de la tierra.
#
# y en la noche de san juan, la santa marta, volando, me siento
# un profundo dolor en mi corazón, un dolor
#
#
#
#
# Poema Generado N° 261:
#
#  -mama, pero eso que pasa
# no es cosa de jadeo.
# ¿cómo es que eso de ver
# y de no oír?
#
# -no más, no más.no hay nada. ¿cómo te oí?a ver si me lo oía. di. "yo no sé", di, "tú no".dejen que te lo di
#
#
#
#
# Poema Generado N° 262:
#
#  el aire de la tarde se ha vuelto
# más verde y limo,
# y el viento de las mañanas, me ha ido
# a su espalda, a su pecho, con mis ropas.
#
# el sol, como un enemigo, he ido, señor, nada más.hay en mi mano
# un hedor de piedra, un agujero en la tierra
# que me ciega y
#
#
#
#
# Poema Generado N° 263:
#
#  la noche es venida
# y yo no sé si ella llega
# o no llega.
# me dicen: "sube conmigo".
#
# la niebla se lo ha desgranado
# de su follaje caduco,
# pero yo me la tengo
# amor de la niebla.no he sido tu cabellera
# ni he tenido sed ni olvido.no tengo sed quieta
# sobre la
#
#
#
#
# Poema Generado N° 264:
#
#  la santa maría y blanca
# desde que cae en el alba,
# y en su pecho
# la virgen marías.
#
# los marineros
# me decían: "mira, ceiba, adóptame,axaca"...yo, sí, me dicen:
# mira la gracia
# de la santa noche, la de la sal.amé,amé
# el amor que dios
#
#
#
#
# Poema Generado N° 265:
#
#  fue ella quien mandó
# la muerte con sus manos,
# con su sangre, con su lengua, y con el polvo, por fin, en los días del solsticio
# y en la noche de san juan.
#
# fue la última ola lanzada
# sobre el mar que hería y que devolvía
# el mundo a la que yo cavé.otros vientos, otros
#
#
#
#
# Poema Generado N° 266:
#
#  y de vuelta, y en la mitad del aire
# se junta, como un anillo, la paloma.
#
# y aunque su forma es redonda,
# como un refrán, es verde.por eso, ¡es roja!o es que se niegue. ¡a la roja se la alcanza!
# ¡y cuando la llama de regreso
# la trae a su puerta ardiendo
#
#
#
#
# Poema Generado N° 267:
#
#
# -mira tú, chiquito,
# cómo es que no tienes miedo
# de que me la sigo?
#
# es que yo soy fantasma, ya
# ahora ya no tengo miedo.oye
# tan poco hasta que llevo
# para dormir contigo.
# ¿de quién más podría ser?emos querías
# ser diferentes a lo que tú eres, hermana?
#
#
#
#
# Poema Generado N° 268:
#
#  y cuando fui a buscarla, ella no la encontró.
# ¡y ella me dijo: "mira,
# mira quién la vio, quién ella encontró!
#
# el día fue un mes y un día
# y él fue sin descanso, sin parar, sólo
# sube en el transcurso del día. su amor dio su vida. su muerte fue una lucha. ¡nada!
#
#
#
#
# Poema Generado N° 269:
#
#  yo te exprimo un vaso de oro
# en el fondo del valle, y en la boca,
# yo exprimiste una llaga de serpientes.
#
# y al llegar la noche cuenta
# que suena de sed y de hambre
# no quiere vivir otra cosa.y no quiere ser hombre. ¡nada!veo en mi boca una flor. pero no esesta
#
#
#
#
# Poema Generado N° 270:
#
#  cae en la piedra, en el vaso,
# la sangre, la agonía, el llanto.
#
# pasan las manos, las venas, los huesos, y
# vuelven a ser reyes o reinas.ar sencillamente
# que los miren de una a otra, de otra vez.otros
# como a las rosas, a los higos, o a la lluvia.
#
#
#
#
# Poema Generado N° 271:
#
#  de la sangre humana,
# de los pies de hombre, de los animales, del agua, y de las cosas
# que no se oyen en vano los nombres de la tierra.
#
# mientras tanto la lluvia rompe
# el silencio del planeta, la luz del mundo rompe:
# la nieve rompe la barrera: la nieve de mi pueblo.un, cuánta nieve, qué nieve
#
#
#
#
#
# Poema Generado N° 272:
#
#  y cuando ya viene la noche
# en que hay un temblor de olas
# y un río de sal y olas,
# ya voy a entrar por la puerta
# sin llaves, sin murallas, con sólo
# gritoscentos:
# ¡ahora ya vienen las olas de la muerte
# que vienen, y van y vienen
# como ahogados en el agua!
#
# yo no sé
#
#
#
#
# Poema Generado N° 273:
#
#  yo no sé por qué
# me tocó vivir con su carne?
#
# yo tampoco sé qué dejo vivir
# con su piel que no ha de serena?escucha, grito, silencio,
# escuchas, silencios, que fue mi vida
# y ahora es mi muerte.y en mi agonía, en tu muerte,yo te exprimo.
# como la piedra
#
#
#
#
# Poema Generado N° 274:
#
#
# y el que te mece, que atarantan
# para no cansarse de amar.las mujeres que viven
# en sus casas te deben, te espero.
# yo te quiero, en cada casa,
# como una estrofa que va en un viento
# de dos sílabas, y que en mi voz ya
# canta una sola palabra: "sol", "río".
#
#
#
#
# Poema Generado N° 275:
#
#  la noche se puebla de pronto
# como un río y un arroyo,
# y mi sueño se hace triste
# cuando vuelvo al sol.
#
# yo sueño que aúlla en su camino
# no me escuche, que es cuentos
# de mí misma, y que no me doy
# su rostro de pedrisco.sí, me duermo en un agua
# des
#
#
#
#
# Poema Generado N° 276:
#
#  yo no soy la quedada tierra
# que recita el mismo cuento
# y solo alcanza palabras
# sécame en la pradera.
#
# no soy el quemeja que mece
# el que me llama el pecho,
# ni el nombre que le dieron
# los ojos de madre granada.de eso por el sueño
# en que dormí sin serte
# con el tiempo que
#
#
#
#
# Poema Generado N° 277:
#
#  ven conmigo.
#
# vi festejados los reyes
# y los guerreros
# en su día y día,
# crecerían y crecían
# los reyes y el mundo.páltica
# tendrían que celebrar
# como las palmas reales.
# pero
# no eran reyes, eran
# maderas, chiquito, y vivían
# de sus reinos en el humo.seguimos
#
#
#
#
#
# Poema Generado N° 278:
#
#  se alejarán los mozos
# de su casa y su huerta.
# el hambre que va a ver
# su casa será su muerte. saldrán los hombres
# la cara con lágrimas. será la vida. ¡nada!
#
# pero el hambre no quiere luchar
# y su sangre no va al grano.* caminan a campo raso
# sin adoptar un pan. no se
#
#
#
#
# Poema Generado N° 279:
#
#  en la torre de la escalera
# yo voy a contar todo lo que me pasa.
# quí me voy porque debo
# a mi señor que siempre quiso
# morir de cortadas y morir
# y ser fiel a su palabra.otras veces
# me voy por el costado
# o por la orilla del agua,
# por las heridas que no se ven
# en vez de morir. ¡
#
#
#
#
# Poema Generado N° 280:
#
#  -¿qué le miras, mamá,
# a ver si se va o no?
# son dos los archipiélagos.
# ¿por qué no paras? dilo.oye, dime. ¡qué cara!
#
# -mama, oye, mama, no te digo nada.no te sabes, chiquito, que
# no estás cantando para nosotros. ¿
#
#
#
#
# Poema Generado N° 281:
#
#  y la pobre llama demente
# dijo: -"¿cómo la llama ahora, di,
# cuando la red de la araña
# nos la alcanza?
#
# y después que la memoria
# se vuelvas, sin relajo, en la
# mano a la mano, los ojos
# de la rueda a menudo se confunden,y con el tiempo, con
# la boca a las
#
#
#
#
# Poema Generado N° 282:
#
#  -¿a dónde van?
# son veras y no son
# ciegas, de lo alborotada.
# ¿cómo se llamanentro? ¿para
# que no sepan las gentes.por eso
# yo me voy a contar lo que
# me dijeron cuando fui niña.*
#
# -¡ay, mama, no mires
# si la vas contando conmigo!
# ya me
#
#
#
#
# Poema Generado N° 283:
#
#  lejos de mi patria
# en que el hombre pasó
# y vi morir,
# me pasó por el mundo
# como una virgen.
#
# mi aldea era desolada
# de lo que me hacía
# por las tinieblas
# que por las entrañas
# no se perdía.todo era silencio
# ¡y de noche no se dormía!lo se acababa, todo estaba en tu alma
#
#
#
#
# Poema Generado N° 284:
#
#  nadie te habrá dicho de no serte
# que te ha olvidado el rostro,
# y que te hable con él cuando te encuentras.
#
# a veces pienso que el mundo te pareces
# para no te aburres con tu amor.sí, si te sabes, te dijiste:
# -"¡ay! juguemos, hijo mío, contuv
#
#
#
#
# Poema Generado N° 285:
#
#  y a la reina no le digas nada;
# le digan que al fin la deje
# conquistadora de la tierra.
#
# y no va a ser la niña que en la noche
# hizo el mundo con su canto,
# la reina sin canto la miró.no le quise enseñarles
# a la impostora, a los cómplices, al ladrón,
#
#
#
#
# Poema Generado N° 286:
#
#  -¿a dónde van?
# vivos, en montañas
# o en playas?¿y a dónde vienen? di.
#
# -para qué, di, mama loca? -sí.y eso es todo. dilo, sí, eso. yando va, ¡qué maldito! sí. no lo sé. ¡y lo quiero decir!
# ¡qué
#
#
#
#
# Poema Generado N° 287:
#
#  el que va a ser rey es el que vino
# a buscar la tierra, se sabe
# como el hijo que da la vida.
#
# el mago que con su rayo de luz
# volvió a las costas
# de su espuma de oro
# y su arrastre de almas
# se ha de llevar a cabo.el de mi sangre
# viene, y es la que trae
# su rayo
#
#
#
#
# Poema Generado N° 288:
#
#  de la piedra más antigua aún queda
# el rostro con lágrimas de la que amamos.
#
# sólo el puñado de huesos que tenemos
# en el largo silencio delol sediento,
# ni la cicatriz que es su nombre, ni la pared
# que la recuenta de sus huesos.y quiero no sólo ser silencio, sino
# un día silencioso, un día
# inmenso
#
#
#
#
# Poema Generado N° 289:
#
#  y de noche se van y vienen
# como los pájaros de la muerte,
# y a la mañana se les van
# con un canto roído y unas señas.
#
# no hay viento ni estrellas, y sólo son los árboles,
# pero son la sangre de los que asesinaron, los frutos
# que eran derramados por las tinieblas, las uvas
# de la tierra que dejaron como
#
#
#
#
# Poema Generado N° 290:
#
#  yo voy, escucha, mira. escucha
# el grito de los niños,
# y me dan el vuelta de la muerte.
#
# me dan la espalda vuelta la vida,
# ¡qué grande, qué pequeña!y la respuesta de mi frente
# para seguir en pie:
# -¡no! no es cierto. ¡no es bulto!
# no hay nada! es una
#
#
#
#
# Poema Generado N° 291:
#
#  el másantiguo nombre de esta patria,
# la patria mía, que todo lo salva, y toda lo ayuda.
#
# ¡qué dulce que es que lleva en su mano!
# es la patria que en sus venas guarda
# el aroma de la sangre que mató!sabe de ella el fulgor que sube por su ventana,y que aúlla en voz de alerta
#
#
#
#
#
# Poema Generado N° 292:
#
#  se juntan en torno a mí
# la noche alzadas de viejas vidas,
# y cada día siento
# sus raíces, sus vidas.
#
# en la noche de san juan
# recibí bautismo y bautismo
# del dios que amó a los hambrientos.el que caminó
# por su reino, por su espuma, y por sus muertos. olvidadizo
# su gloria
#
#
#
#
# Poema Generado N° 293:
#
#  fue mi enemigo el tiempo
# en que las ciudades se ven
# como hijas amadas,
# y cuando la sal y la sempiterno
# se arrugó su piel, sus ojos, y sus uñas
# fue como si fuera una paloma
# repartiendo su propia muerte.
#
# el chileno se vistió de azul, trenzados
# de lanzas y de metal, en elleo
#
#
#
#
#
# Poema Generado N° 294:
#
#  -mama, por qué, mama mía,
# no me gustan las flores.
#
# -es que, ¿por qué no me cansas?sí, ve, eso es lo que fuiste tú.me gusta el perfume, la luna, el agua, y el fuego, pero no la poesía. ¿sabe, di? sí, ya no sé. ¡sí
#
#
#
#
# Poema Generado N° 295:
#
#  el viento loco lo toma y lo lleva
# por el pastal de su ala rasgando
# la hondonada de sus alas.
#
# sobre el campo de mitmar,
# donde su greña oscura lo esconde,no hay nadie, sólo su alma, su cuerpo.otros caminan, van y vienen, sin saber que van
# los que vienen a ver y a
#
#
#
#
# Poema Generado N° 296:
#
#  la noche está estrellada
# como el hacha en la noche,
# y sosiega su rasgado aliento
# de abrasamiento.
#
# en el atardecer, sus ojos
# son de azul-ceniciento, como
# la lluvia de la puna.oh sentina
# spondylus, la paloma torcaz.¡oh loca
# alegría, azul torcida
#
#
#
#
# Poema Generado N° 297:
#
#  la tierra es como el agua,
# como el fuego, como la arena, y como un sol:
# es una sola cosa, una substancia.
#
# deja que la tierra se calle
# y que se haga visible
# la distancia, la distancia.es como si se cerrara
# el camino donde el trigo y la nieve
# cantan y hacen huir a las criaturas.
#
#
#
#
# Poema Generado N° 298:
#
#  se va a cruzar el puente
# en vez de pasar sin lograrlo,
# y no me va. no sé, yo sé si estoy oída.
#
# se van a pasar los caminos
# sin hallar a la que me dio la muerte,el oscuro, cantadora.voy por los patios
# de zapaterías, oh los tizones de las casas, yel olor
#
#
#
#
#
# Poema Generado N° 299:
#
#  la carne de hombre es la carne,
# y la muerte es el mundo, y la resurrección es un solo jadeo.
#
# yo soy el que cortó la grieta, el agujero
# que hizo la última hora, la paz
# de la vida, de la pupila abierta.mírame
# la blandura de mi mano, me han contado sus versos.todo lo
#
#
#
#
# Poema Generado N° 300:
#
#  -mama, mama. ¿por qué no te pones
# a la chiquita que no se ve?
#
# -¿y qué te llamas ahí, mama?es como que nada.no hay nadie.
# ¡qué lindas sílabas estás haciendo!siento patagón, estás cantando. ¡es la mama!
# ¿es que te dieron miedo? ¿
#
#
#
#
# Poema Generado N° 301:
#
#  ya a la tierra me encamino
# y la viví en mi corazón,
# como un árbol o un ave,a ti se allegue.
#
# ¡ea, ceiba, ea, se ean, oh
# a ei e ee!y tú que has de saber
# todo el mundo que nos mira, y en la nuca
# te di
#
#
#
#
# Poema Generado N° 302:
#
#  aquí me estoy, señor, con los ojos en la tierra
# y los labios en el mar:
# ¡qué dulce que es llegar de la mano del hombre!
#
# a las puertas de las casas
# se han de abrir, en vez de cerrar
# las ventanas rotas,
# el pan, el vino, las naranjas, los retratos.a la mesa, a las sillas
#
#
#
#
# Poema Generado N° 303:
#
#  no sé si es mejor vino o mejor fruta.
#
# bien vino a esta copa. vino
# al vino de malherida,
# la mejor del vino.oye
# debajo del árbol de la espina, y arriba
# del árbol del martirio, los frutos
# que caen son de milagro.cuando
# los frutos son un vino, un movimiento
# negro, oscuro, largo
#
#
#
#
# Poema Generado N° 304:
#
#  -¡ay, mama, la mama loca,
# ¿cómo no la robaron?
# ¡y la dejan caer, y la vuelven
# al pobre niño, que es de miedo!
#
# -mama, chiquito, pero dices
# que alguna vez la sabemos
# y que no es cierto, de que
# ya sabíamos la error. nunca se la la com
#
#
#
#
# Poema Generado N° 305:
#
#  yo no sé, pero tú dos hiciste
# tu voz y tu gesto,
# y tú tres me oyes la cara
# como a una selva o como a un río.
#
# pero como el agua
# no me turbe, no me canso, y me deja
# tras de ti, como la tierra.oírmete
# que no quieres bañarse
# con tu
#
#
#
#
# Poema Generado N° 306:
#
#  -¿qué haces ahí, mira?
#
# -es que yo quiero quedarme
# contigo, contigo.es una loca
# que sigue y que mata.
# ¿tanta tú la que va a llamar?mama, ve tú, mama,
# ya no tienes nada. ¿es cierto? ¿no estás contenta? corre
# y baja. corre como el
#
#
#
#
# Poema Generado N° 307:
#
#  -¿qué ves, mama, di?
#
# -es que tú eres bella
# y quieres encarar contigo.
# pero, ¿por qué no va delante?es como que miraban
# la miraba y la mirababa.no era así. era
# como que la viví en el huerto
# con las majadas y las calladas.
# ya me he
#
#
#
#
# Poema Generado N° 308:
#
#  yo no sé si es más suave la sombra,
# más delgada la piedra, o si ésta es la rosa?
#
# y si ella tiene un color de violetas, ciudad?a qué vino a mis casas después? a mi casa?a mi oración de regreso? al ruedo de la muerte?que yo me descanso una noche?, escucha, no.
# no me pregun
#
#
#
#
# Poema Generado N° 309:
#
#  alguna vez la cruz atribulada
# se levanta y cae por la puerta
# del templo, cayendo en gotas
# de lluvia o de polvo.
#
# cuando el río de la angustia
# elquiece, y se deshace,
# la barcaza se retuerce
# y se vuelca, en una rueda, a la
# mano dura del dios secreto,no queda
#
#
#
#
# Poema Generado N° 310:
#
#  en la mesa de mi casa,
# la brasa y el rocío, junto
# a mi mesa y a mi cama, sentados
# y durmiendo, mi madre me dice:
# -"¡gracias, gracias!
#
# no te vale el gesto que me da
# envío de manos como de niña;
# gracia,grava que tú tengas
# por darme gracias
#
#
#
#
# Poema Generado N° 311:
#
#  "la muerte no lo ha matado,
# la vida lo está muerta."
#
# "cuando me muera no me lo sabrás". nada.cuando te lo quiero, te sigo.
# ¡no lo tengo, no! no importa cuánto te muero, pero cuánto
# me lo a mí me lleva contigo...no me importara, por qué no has cambiado,
#
#
#
#
# Poema Generado N° 312:
#
#  y cuando los andes se alzan,
# y los ríos se ensombrean
# con su nombre, y se van a deshacer,
# que se hunden, que se deshacen,*
#
# enrollan los cerros en cascadas, en
# trenzan los pueblos de aguas tranquilas
# como el delfín en el agua.
# bajan, bajan, se cruzan, pasan
#
#
#
#
#
# Poema Generado N° 313:
#
#  -¿qué ves, mama, di?
# son unas flores de otoño
# que te buscan y no les traen
# y unas rosas de invierno.
#
# -porque tú, mi chiquillo, no eres "pequeña".
# ¿cómo te das unas plantas
# de flor no sembrada?no. ¿cómo? porque son
# tantos y son tiernas y cortadas.
#
#
#
#
# Poema Generado N° 314:
#
#  y se va yendo y viniendo
# por la raya de la vida,
# y sin tregua nos va, quedándose
# sin relajo, sin relaja, la madre
# que nos puso su nombre.
#
# yo no sé si es la misma
# o es el mismo nombre, di, que me dieron.o la mismos madre, insegura
# de quién soy, de quién me
#
#
#
#
# Poema Generado N° 315:
#
#  y la noche que me dieron
# en la que fui feliz
# y en la cual sin mí me vivi
# mi dios me dio la vuelta
# cuando ella volvió al umbral.
#
# me dieron las dos mil y un noches
# para que yo no muriera.mértame tú, mi dulce
# viejo que solo se muere,
# porque como todos
# dijo morir antes de que
#
#
#
#
# Poema Generado N° 316:
#
#  detrás de la casa
# levantas
# a través de los muros
# las puertas
# del hombre
# bailamos
# la ceniza
# y la sangre
# de los pobres.
#
# hemos crecido
# hasta hoy
# sin nombre, raza, credo,
# ni casta
# nombre, ni credo:
# el pueblo
# reclamo
# nombrando
# como una fábula.
#
#
#
#
# Poema Generado N° 317:
#
#  el hombre ciego mira inmensamente
# la luna llena,
# ya no hay soledad.
# el aire, el agua, la tierra no me ayudan.oye, sí, me ayudaran.
#
# yo soy el que te espera en las tinieblas, en el ocaso. te esperas en la noche
# con la espiga roja en los ojos, con el espino en
#
#
#
#
# Poema Generado N° 318:
#
#  -¿es que no hay nadie, que es?
#
# -pero si lo hallo, mama,
# no le digas nada.no, yo me lo di.
# he bajado la pollada. ¿por qué canté?chiquito, chiquito.¿hay nadie? ¿y si es que tú no lo miras
# para mí, para mí?
#
#
#
#
# Poema Generado N° 319:
#
#  y que el hombre que construye
# le robó el sueño suyo.
#
# y cuando ya me cubrió del sueño
# con mis manos,
# yo no sé qué de sueño.y me sé, de loca, ¡qué de día tenía!pero a veces pienso que eso era cierto. y eso es cierto, y ése cuenta que era, así. he bajado la noche
#
#
#
#
# Poema Generado N° 320:
#
#  -¡qué cara son tendrás
# las gentes extrañas!
#
# -tantas son que cuento,
# tantachas son, sí, también cantas.unas tienen miedo, algunas asustan.
# son las madrid y las trébol. "chiquito, chiquito".no lo asustas, mama. sí. ¿por qué no?es todo lo que
#
#
#
#
# Poema Generado N° 321:
#
#  el cordero está espesando
# el vellón que he de tejer.
# a veces un chalesol
# de puna y de resuellos
# y otras veces, un tordo
# relámpago de coquimbo.y no es la misma raza
# que he visto en la punada. ¡sí!
#
# yo te he sentado en el sillón
# del
#
#
#
#
# Poema Generado N° 322:
#
#  yo veo, yo cuento,
# y yo no sé qué de lo cuento
# que no se puede repetir
# en mi ausencia.
#
# ...
# me he tenido en mis manos.otros
# no me han contado mis carnes
# que
#
#
#
#
# Poema Generado N° 443:
#
#  no te quiero irme, no te voy.
# yo quiero estar en las montañas
# hasta que el viento con la lengua de mi alma
# me atarantaste al día en que te llamo.no quiero que me muera
# en medio de las cordilleras,
# que me dejen como un pozo de cenizas. ni quieres que yo muera, solamente
# eres tú,
#
#
#
#
# Poema Generado N° 444:
#
#  -¿qué ves, mama, con esa cara
# que la mira sin gestos?
#
# -porque de todo, tú la quieres. mama.
# ¿y por qué la ve, también,
# y no la miras, di?es como que
# me la vi, y no me la creer. mama!sí. sí. me parece. ¿por qué te
#
#
#
#
# Poema Generado N° 445:
#
#  la piedra rodada con sus manos
# de mirra-ala, la losa del martirio,
# se inclina, se va, y vuelve
# a buscar el rostro que nunca viste.
#
# y otra vez, el viento del deseo
# es un trueno de olas que se viene, llega, golpea
# la tierra, derriba el cemento, da pasos
# hacia el fin del mundo, hacia
#
#
#
#
# Poema Generado N° 446:
#
#  -a veces lo siento como si fuese
# un niño mío.
#
# -pero ahora ya no puedo
# míralo sin dar gritos.no puedo pararme
# por no oírle más la voz
# que va y que no se oye. ¿por qué no?sí, por eso. eso es
# mi alma, mi alma que va amando y
# pido castigo.
#
#
#
#
# Poema Generado N° 447:
#
#  os voy a encontrarla
# en un testuz de roca,
# y de pronto, al fin, llegará
# a mi lado, con un puñal.
#
# el calor de la noche
# se levanta a mis mejillas, y me abrigo
# con mis ojos abiertos hacia el mar.aquí, mi corazón está en calma
# hasta que un día de mi vida
# me rompe
#
#
#
#
# Poema Generado N° 448:
#
#  -no te turbes, no, chiquito.
#
# -¿qué haces ahí, mira, escucha?
# es la casa donde yo vivía.es una casa
# y ahí donde no se perdía. trajiste
# un caballito y un caballitos. ¿es así, mama?hay gente, nadie.¿es eso? ¿qué es eso, di? dilo
#
#
#
#
# Poema Generado N° 449:
#
#  el que cortó la mitad de la tierra,
# buscó el árbol más joven
# y se fue a encontrar con el tiempo
# el árbol madre, y ella nació
# en la noche de san juan.
#
# la que trajo a la madre la vida
# fue a sentarse en la mesa, a acostarla, al bañarla, besarla.era, no te vi, nunca
#
#
#
#
# Poema Generado N° 450:
#
#  en el llano y en las montañas
# se viví con el alma en calma.
# un día, siete,
# yo le falle. no sabía
# de quién lo esperaba. y ella lo quería
# por su hermosura y su belleza. al fin, en la noche
# su pecho guarda el mismo aire. el me lo oí, y él me dijo:
# -"
#
#
#
#
# Poema Generado N° 451:
#
#  la luz de la tarde, la de los andes,
# van enseñando al pie su camino
# y el camino se entera
# de un tronco que nos cruza
# por tierra y aire.
#
# en la estación, en el tren, con los niños,pene la línea, me trenza
# con el nombre de estación.otras palabras, tristes, lentas, rotas
#
#
#
#
# Poema Generado N° 452:
#
#   la noche se ha vuelto
# casi a la medianoche.
# la niebla ha hecho camino
# y la niebla es todo el mundo.y yo todavía camino.*
#
# hierba nupcial,
# recogiendo mis bodas, mis nacimientos, mi muerte,*la patria está en tu puño. dime quién eres, quién te llamaras, qué idioma te hablas,
#
#
#
#
# Poema Generado N° 453:
#
#  y cuando es que viene
# la virgen maría
# y marían y sonreía,
# ya no eran míos
# ni eran huertas
#
# en este día se ve
# que la virgen no es
# el mar, que es el mundo, talco, tú, el que amo, y a tu cuerpo
# yo te amo como un dios eterno.veo
# de
#
#
#
#
# Poema Generado N° 454:
#
#  y un hombre que dormía tenía
# un rostro negro y color de sangre.
#
# los que vino a tocarla,
# como es que se oye, no lo recibieron.daban lejos, lejos. y no se sabían.un hombre, hombre fuerte, grande, vino
# a tocar el corazón de una montaña.un era un árbol, era
# el árbol más grande de la
#
#
#
#
# Poema Generado N° 455:
#
#  y no me quedé sentado
# en el sillón del palafío.
#
# y metida de la sangre
# por el traidor,
# para que no se olvide
# su heroica muerte.a la patria, adonde
# fueron los asesinos
# de la lucha, la alegría, el signo
# del laurel que ardía.a mi patria en el viento
# que ardió
#
#
#
#
# Poema Generado N° 456:
#
#  se hizo un hueco en la pared
# y se hizo hueco el muro
# con pegarle, pegándole,
# envejecido, en el hueco
# que lo deja en maldecir.
#
# -a ver si se va a contar nada, mama, entonces
# no digas nada.no me digan nada...yo no lo sabías.*es la
#
#
#
#
# Poema Generado N° 457:
#
#  -¿no dices que yo soy fantasma?
#
# -me la quiero, pero no la tengo.es "compaña" y me gusta
# morder a fantasmas y fantasmas,
# y traerte de historias ciertas.
# me gustaría oír alguna de ellas
# que me dijeron cuando miraba.¿y a qué me decían?no sé. ¿qué sí, me
#
#
#
#
# Poema Generado N° 458:
#
#  en la noche tan grande
# y tan pequeña
# que no cabece en las olas
# nunca es la misma madre
# ni es el mismo nombre.
#
# ya no tengo soledad.yo no ha muerto. sólo la sombra. ha nacido. "la noche",
# canto rodado en mi corazón,
# tu nombre no se me dio. yo no la tengo. no me llame,
#
#
#
#
# Poema Generado N° 459:
#
#  -a veces tú me miras,
# y otras veces no, me lo di.
#
# -siempre, siempre serán mis besos.a la vez, mama, eso
# dejo que te pido con palabras. dime, mamá, cuánto
# es esto de que tú eres mis amigos. ¿ves?así, di, que son de palabras,como
# el
#
#
#
#
# Poema Generado N° 460:
#
#  el hombre asegura que su amor ha terminado
# y que es como si hubieran continuado
# lo mismo si no hubiesen continuadolo.
#
# el pobre peregrino en que no se ha dormido
# su amor por su costado y su entrega
# no se le ha sentado a la orilla del sendero
# ni se lo ha visto, ni se conoce su rostro.no hay más amor que el mío,
#
#
#
#
#
# Poema Generado N° 461:
#
#  -pero si eso me gusta
# morder mis hermanas,
# mírala, me oyes, y calla.
#
# -si es que tú me quieres
# aquí, sí, aquí.sí, también, alquí
# y a mí me gustaría estar contigo.
# será que te quiero. ¿por qué has de recomenzar
# para mí?
#
#
#
#
# Poema Generado N° 462:
#
#  -¿por qué no lo hallamos antes?
#
# -porque es invierno la zona.
# ¡tanto ellos la azorada!
# ¿y por qué la dejamos
# sin verte mejor que la albada?el, mama, la mama.oye, sí, párate. ¿cómo es que no la vieran
# y no se la oyen los
#
#
#
#
# Poema Generado N° 463:
#
#  yo no quiero que mi niño
# me descubra el rostro,
# porque de ti yo no sé
# que voy a morir de fiebre
# o deamiento de alma.
#
# yo quiero irme por las calles, hacer
# mi camino por los hospitales, y ver
# la luz de hoy, el agua, las niñas, la luz del día, la oscuridad de las puertas,
#
#
#
#
# Poema Generado N° 464:
#
#  ¡ay! juguemos, hijo mío,
# a la reina con el rey!
#
# y en el regazo de su pecho
# se leen los gestos de los hombres.ojos
# derey, rey, no lo vieron
# ¡y le alumbren los ojos de la llama
# que la noche no conoce!¡dios nunca viste a la luz
# ni a las entra
#
#
#
#
# Poema Generado N° 465:
#
#  yo quiero que tiremas en el estío,
# en el alto bálsamo, en las islas
# que me dieron la sabiduría.
#
# yo no quiero, de toda tierra, quedarme
# con un golpe de viento en mi cara,sí, con tu voz en la boca.yo dije: —no te quiero. dime: -"no quiero morir".
#
#
#
#
# Poema Generado N° 466:
#
#  -¿qué ganas de hacer?
# son unas flores que se encienden
# y unas que no se cansan.
# ¿cómo es que tú no las has visto
# las que comimos de sus huertas?no la quieres, no la.es como que
# me las estoy viendo y me las no. ¿por qué
# suena tú y yo las comes? ¿no
#
#
#
#
# Poema Generado N° 467:
#
#  aquí me estoy, señores,
# sin duda el mejor de los hombres.
# es el siglo y medio entre los años,*
# y en cuarto lugar el de la patria*.otros dolores, otros
# hechos, raíces, amores, son los títulos
# que recibe la vida.*niño
# recién nacido, pues, de madre granada. ¡nada
#
#
#
#
# Poema Generado N° 468:
#
#  te digo que me empuja
# por la raya de tu regazo
# y que no me olvide,
# que en la carrera siempre he sido tuyo.
#
# -pero qué mal, por qué
# siempre me persigue, siempre me lleva. bien, mama, me parece
# una fantasma sin rostro, como un fantasma
# o como la madre de un niño. ¿por qué no
#
#
#
#
# Poema Generado N° 469:
#
#  el viento loco de valparaíso
# mece la tierra.
#
# ciudades se han unido
# como una sola mano,
# central ojeada, ocupada
# por el hombre y el viento, como
# la luna o el sol, o la luz del día, y
# las estaciones del verano
# en tu boca, en tu garganta.a veces
# no quiero que nos ba
#
#
#
#
# Poema Generado N° 470:
#
#  -mama, me gusta tanto que no
# me gusta estarme viendo.
#
# -porque no me gustan los niños
# y no quieren que me hagan daño.no.te.les bien. ¿por qué no?es que ya no sé. sí. escucha. me asustas.¿por dónde, di?
# no le importan los tontos.*
#
#
#
#
#
# Poema Generado N° 471:
#
#  -¿a dónde van?
# ¿por qué no la dejan
# en la pampa o en el valle
# donde el invierno es más denso?¿y a qué va? ya la abandonan.
#
# -mama, ve cómo van
# los niños que no saben
# y no quieren que la vayan.jadeando, yo me la sigo. ¿no la
#
#
#
#
# Poema Generado N° 472:
#
#  la tarde del siglo veintiuno,
# en la taberna de san juan, el rey
# de los judíos, con la boca llena
# del pan, se acuerda
# con la gesto de un hijo
# y con el del otro hijo.
#
# cuando el tiempo es venida, y yo todavía
# quiere llevarme lejos, sigo, voy en su arena,otros
# como quien
#
#
#
#
# Poema Generado N° 473:
#
#  estoy como el pino de alepo,
# como el durazno de laterne,
# esto y como la salvias de las tórtolas,y la luna de miel, y el sol de mi sangre,*
#
# y en mi patria hay un puente que cruza
# con la luz de hoyos, con el de ayer, en la altura
# de la
#
#
#
#
# Poema Generado N° 474:
#
#  en el fondo de la tierra sombría
# que tú amasaré y que tú halle,
# y que yo no te entiendo, y te digo:
# -"¡gracias, gracias, mi gracias!
#
# no te dan mi palabra más linda.
# ¡fea, fea!fena es la palabra, la flor, el riego. feo, no
#
#
#
#
# Poema Generado N° 475:
#
#  en los caminos se despeñó
# y en las pobres bestias parecías,
# en las que el hambre se ha comido
# se reído de su carga.
#
# yo vi llegar, y vi venir, en la noche
# dejadme que me hubiese quedado
# sin cuerpo y sin alma.pues no me alcanzaban, no sabía
# qué de mí y de mi esqueleto
#
#
#
#
# Poema Generado N° 476:
#
#  amor que te sustenta en la tierra,
# amor en el mar que nos deja
# gorda y ciega, en que la noche no canta
# ni la aurora que ama.
#
# no hay paz duradera. te espero
# la luna llena de nieves, la luna sin párpados, el sol
# que sigue ardiendo en las colinas.espera
# al cielo sombrío,
#
#
#
#
# Poema Generado N° 477:
#
#  -es que yo sé, no me sé.
#
# -pero si me lo gimen
# será que me la tengo.no es así. ¿es eso?pero eso es lo que te gime. ¡dime!es mejor. poquito a todo. es tal vez nada. sí, eso.
#
# así, ya lo cuentomos, y lo
#
#
#
#
# Poema Generado N° 478:
#
#  se desparraman en grupos
# como estrellas o animales;
# y caen en bandadas
# en ovillos de las islas.
#
# pero al oeste, en el hemisferio
# de los andes,
# los rojos vitrales
# que conturden, y al sur, los rojos
# cuerpos,canos, andan
# si la luna es verde o azafranes.miguel
#
#
#
#
# Poema Generado N° 479:
#
#  la noche larga y fría
# que nos diste y nos lleva
# a la orilla del sendero.
#
# el sol de ocaso pone
# su luna de miel en la cara.es como si quisiera
# recordar la memoria,
# morder la canción, y deshacerla. "yo te lo creo".yo, tú, mi amor, me lo quisimos. ¡eso
#
#
#
#
# Poema Generado N° 480:
#
#  -¿qué, di, mama, no di
# que te pintan de alegrías?
#
# -porque son tuyas, chiquito.
# me gustan las flores que
# sonando caen a la grama
# y las hierbas que no sontañadas.y quiero cantar
# con ellos, y para ellos. ¿cómo quieren
# a cantar con esos que pasan
#
#
#
#
#
# Poema Generado N° 481:
#
#  en la mesa se sientan los rostros
# de los que en la pobreza
# dieron la mano de la envidia.
#
# en el fogón escucharon,
# y en el brasero escuché la palabra
# delfiada.y dije ¡ay!todo quedó en silencio. ¡no!
# ¡y todo quedó atrás, en las puertas, con
# lamentos de envidia y
#
#
#
#
# Poema Generado N° 482:
#
#  no quiero ser estatua de piedra,
# no quiso ser un árbol, no era un ser.
#
# este es tu país. esta es la tierra.sino tú, la claridad, el amor.a tu casa, a tu torre de campana, o a la casa de los niños,y a los vidrios, y a las escaleras, junto a tus minas, con los
#
#
#
#
# Poema Generado N° 483:
#
#  manitas de oro
# cantan las puertas
# de los hombres
# y hacen la escalera
# sin escalones.
#
# manita blanca
# que te sueltan
# las puertas de tu pueblo.mérmete,
# mama, te amo, pero no te mueras. escucha:
# por eso, en todo
# el mundo, llegas
# a tu gente.m
#
#
#
#
# Poema Generado N° 484:
#
#
# cuando es que desaparece
# la madre que lo vio
# y lo deja en el sueño
# con su cuerpo y su alma,
# se vuelve a su sitio
# en donde hasta su muerte
# recabarren dioses y héroes
# ¡y tú me lo sabes
# que soy el que te dio!¡!
#
# de su sueño tiene todavía
# su rostro en la ventana,
#
#
#
#
# Poema Generado N° 485:
#
#  me la tengo todavía
# en medio de las ásperas arenas
# y una frente suavizada
# de la suavidad de la arena.
# la madre, la que te ha herido
# por amor, me la quiero. ¡no!
#
# yo te voy, sí, a tu casa,
# al campo del légamo, al campo de tu gracia,¡no, no!
#
#
#
#
# Poema Generado N° 486:
#
#  de tanto andar sueño mío,
# que he vivido una noche
# en que no he visto ni visto
# ni por qué tan triste me siento.
#
# pero tal vez tal como fui,si yo hubiera sido, sería
# algo así:
# parecía ser una sola cosa, una
# curva de hojas, un paraguas.alguien vendría.no me podría
# saber
#
#
#
#
# Poema Generado N° 487:
#
#  te recuerdo también,
# que antes de la muerte
# de los hombres, yo los hallas
# protegiendo y confesando
# y cuando te me oyes, por
# sangre y sangre, y lejos, lejos.
#
# yo me voy, no a buscar
# ni para mí ni para los otros, ni
# para mí mismo, para todos, porque
# no debo ser
#
#
#
#
# Poema Generado N° 488:
#
#  y el que te diste, que no te hable,
# que no nos tuerza, y que nos pareces,*
# ¡y la pobre que duerme, la dádiva, así tan pobre!
#
# y no a la luz nunca más, de nuevo,y en esta ocasión, como una larga llaga, o una aguda hebe
# de ver
#
#
#
#
# Poema Generado N° 489:
#
#  rodaron las pobres bestias
# que por sus faldas
# compartimos en el bosque.
#
# fábulas y verbenas
# se han puesto a bailar
# en la posada.oh sentina
# la que da sombra
# y la que entrega en la noche.no es verdad. me la dan. sí. es mentira. ¡qué de eso es que está contando!
#
#
#
#
# Poema Generado N° 490:
#
#  -yo soy el que te mece,
# y soy otro el loco que está vivo.
#
# -¿por qué no lo hallamos antes?veo, mama, a qué.él es loco, y es
# de los que más le gusta ver
# los que están ciegos, los demás, yo. ¡no importa!y para que yo cante
# su más
#
#
#
#
# Poema Generado N° 491:
#
#  yo no la quise, chiquito.
# sólo un ojo torneaba mi cara,
# y era una muerte de dos años
# que me la aúpame, y era
# una muerte mía, una vida.otros son los que las mandaron. ¡no!
#
# la noche se llena de silencio. mi sueño es vano. no más. es rigidez!
#
#
#
#
# Poema Generado N° 492:
#
#  -ahora, ¿por qué no se cansa
# que no tiene tiempo?
#
# -no, no. ¿cómo se llama?es una fantasma,
# una fantasma llamada.no tengo tiempo.
# ¿cómo me llama ahora? ¿a qué? dilo. sí, sí. mama. di.qué me llames ahora.pero, mama, dime.
#
#
#
#
# Poema Generado N° 493:
#
#  ay cuándo
# ay cuando
# y cuándo,
# con tu puro amor, amor mío, con tus propios ojos, perfume
# desnudos, sabores, olas, timbres, la noche
# de tus grandes flores y tus dulces relojes.
#
# no se cansa en este golfo
# la canción de cuna
# que me dieron tu amor.me dio tu cuerpo, tu alma, todo
#
#
#
#
# Poema Generado N° 494:
#
#  el señor de los cielos,
# el que te espera en tus ojos, es el que recita.
#
# en tus labios, en tu boca, será la dulzura. te esperas en mis manos.
# tú me esperará en el corazón. te alcanzará con tus palabras.hilemos a mi alma, a la tierra, al mar. ¿por qué
#
#
#
#
# Poema Generado N° 495:
#
#  -¿y qué si es que yo he de mentar
# y solamente en las noches hirió?
#
# -mama, ve que no me gustan
# que a los nacidos de madre granada
# me les doy el seno, y no les vuelva
# la madre-pregunta, que es balbuceada.¿por qué no dices nada?¡qué ganas
#
#
#
#
# Poema Generado N° 496:
#
#  -no te acerques, no.
#
# -¿y qué te pasa, di?chiquito,
# es una fantasma sin cuerpo.es el fantasma de la corza, la fantasma del puma. ¿es así? ¿qué es ella, mama?
# ¿es la que te dice y la contesta? es fantasma. ¡ay! ¿de quién más podría ser?
#
#
#
#
# Poema Generado N° 497:
#
#  -¿qué ves, mamá, que estás sola
# y eres la misma cosa que los otros?
#
# -sí, me creo que el amor es el arte.
# pero no la poesía.sí.dice. sí. es la edad. ¡nada!no! es mi edad!
# sólo eso, eso no es nadie!no. te oigo, chiquito
#
#
#
#
# Poema Generado N° 498:
#
#  -es que yo quiero ver
# con tu pálida cabellera.
# ¿y no me cuentes?
#
# -¡ay, mama, déjame.estaba, ella canta
# al mismo ritmo que el niño. ¿por qué no?no es cierto. ¡sí!
# pero es que tú no quieres
# morder a los tres o a la vez
#
#
#
#
#
# Poema Generado N° 499:
#
#  el río desatado rompe a llorar y a veces
# se vuelve más vivo cuando se aleja.
#
# huracanes de avestruces cruzan las praderas.no volverán a ver,
# y mi padre, que es dueño de los muertos, me va a contarlos.no compré un pan ni un vino
# ni un árbol de cedro rojo. ¡no tiritan de

# %%
generated_poems = []

for i, sample_output in enumerate(sample_outputs):
  if tipo_tokenizer == "tiktoken":
            generated_poems.append(tokenizer.decode(sample_output.tolist()))
  else:
            generated_poems.append(tokenizer.decode(sample_output, skip_special_tokens=True))

output_file_path = f'ModeloC_prompt_libre_T_{int(TEMPERATURA*100)}.txt'

with open(output_file_path, 'w', encoding='utf-8') as file:
    for poem in generated_poems:
        file.write(poem + '\n\n\n')

print(f"Generated outputs are saved to: {output_file_path}")
# Out:
# Generated outputs are saved to: ModeloC_prompt_libre_T_60.txt

# %%
archivo_path = f'ModeloC_prompt_libre_T_{int(TEMPERATURA*100)}.txt'

with open(archivo_path, 'r', encoding='utf-8') as file:
    contenido = file.read()

wordcloud = WordCloud(width=800, height=400, background_color="white", stopwords = stopwords_espanol).generate(contenido)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
creatividad_altaT = evaluate_creativity(model_sologpt, tokenizer, poemas, temperatura = 0.9, num_context_inputs=100)
creatividad_bajaT = evaluate_creativity(model_sologpt, tokenizer, poemas, temperatura = 0.2, num_context_inputs=100)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 0
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 1
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 2
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 3
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 4
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 5
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 6
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 7
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 8
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 9
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 10
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 11
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 12
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 13
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 14
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 15
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 16
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 17
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 18
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 19
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 20
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 21
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 22
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 23
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 24
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 25
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 26
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 27
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 28
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 29
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 30
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 31
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 32
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 33
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 34
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 35
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 36
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 37
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 38
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 39
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 40
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 41
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 42
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 43
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 44
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 45
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 46
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 47
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 48
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 49
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 50
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 51
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 52
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 53
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 54
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 55
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 56
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 57
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 58
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 59
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 60
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 61
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 62
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 63
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 64
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 65
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 66
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 67
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 68
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 69
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 70
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 71
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 72
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 73
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 74
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 75
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 76
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 77
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 78
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 79
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 80
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 81
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 82
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 83
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 84
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 85
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 86
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 87
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 88
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 89
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 90
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 91
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 92
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 93
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 94
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 95
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 96
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 97
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 98
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 99
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 0
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 1
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 2
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 3
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 4
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 5
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 6
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 7
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 8
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 9
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 10
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 11
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 12
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 13
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 14
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 15
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 16
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 17
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 18
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 19
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 20
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 21
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 22
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 23
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 24
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 25
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 26
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 27
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 28
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 29
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 30
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 31
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 32
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 33
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 34
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 35
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 36
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 37
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 38
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 39
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 40
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 41
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 42
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 43
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 44
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 45
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 46
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 47
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 48
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 49
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 50
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 51
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 52
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 53
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 54
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 55
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 56
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 57
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 58
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 59
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 60
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 61
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 62
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 63
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 64
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 65
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 66
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 67
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 68
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 69
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 70
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 71
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 72
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 73
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 74
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 75
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 76
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 77
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 78
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 79
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 80
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 81
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 82
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 83
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 84
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 85
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 86
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 87
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 88
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 89
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 90
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 91
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 92
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 93
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 94
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 95
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 96
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 97
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 98
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Contexto número: 99

# %%
print(f"El puntaje de creatividad del modelo con alta T es: {np.round(creatividad_altaT, 2)}")
print(f"El puntaje de creatividad del modelo con baja T es: {np.round(creatividad_bajaT, 2)}")
# Out:
# El puntaje de creatividad del modelo con alta T es: 0.88
# El puntaje de creatividad del modelo con baja T es: 0.84
